# %% [markdown]
# # 1. Importações de bibliotecas e carregamento de dados

# %%
# Importando bibliotecas necessárias
import json
import numpy as np
import pandas as pd
import math
import sys
import os
import seaborn as sns
import tensorflow as tf
from numpy import zeros, array, asarray
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
from matplotlib import pyplot
from matplotlib.pyplot import figure
from keras import metrics
from keras.models import Sequential
from keras.layers import Bidirectional, LSTM, Dense, Dropout, Activation
from keras.layers import Flatten
from keras.layers.embeddings import Embedding

# %%
# Parametros modificados com frequência
debug = True
col_switch = ('summary', 'description')
xcol = col_switch[1]
translate_enabled = False
reuse_translated = True

# Esses são importantes
rstate = 7
docs_length = 'mean'
z_score_threshold = 1
z_score_times = 5
embedding_size = 64
emb_model_learning_rate = 0.007
wind = 15
mcount = 30
norm_vectors = True
lstm = True
dense_layers = False
dropout = True
dropout_default_value = 0.8
opt_lr = 0.01164
ctered = True
num_epochs = 100
batch_size = 128
validation_size = 0.3

# %%
# Abrindo dados como ndarray
if not reuse_translated:
  data = []
  path = './drive/MyDrive/ColabNotebooks/data/'
  filelist = os.listdir(path)
  filelist.sort()
  repo_num = len(filelist)
  print("Numero de repositorios: {}".format(repo_num))
  for filename in filelist:
    with open(path + filename, 'r') as file:
      repo = json.load(file)
      data += repo
  ndata = pd.DataFrame(data).values
  pd_data = pd.DataFrame(data)
  if debug:
    print(ndata)
    print(ndata.shape)

# %%
# Funções auxiliares
def print_all(df):
  with pd.option_context('display.max_rows', None):
    print(df)

def my_zscore(x):
  return ((x - x.mean())/x.std())

# %% [markdown]
# # 2. Limpeza dos dados

# %%
if not reuse_translated:  
  # Removendo linhas com description null
  bool_series = pd.notnull(pd_data['description']) 
  pd_data = pd_data[bool_series]

  nan_value = float("NaN")

  pd_data.replace("", nan_value, inplace=True)
  pd_data.replace(" ", nan_value, inplace=True)
  pd_data.replace("nan", nan_value, inplace=True)

  pd_data.dropna(subset = ["description"], inplace=True)

  # Removendo linhas com summary null
  bool_series = pd.notnull(pd_data['summary']) 
  pd_data = pd_data[bool_series]

  # Removendo linhas com timespent null
  bool_series = pd.notnull(pd_data['timespent']) 
  pd_data = pd_data[bool_series]

# %%
# Funções para realizar limpeza nos textos
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

def id_removes(text):
  return re.sub('\[(\w|\W)*\]', '', text)

def link_removes(text):
  return re.sub('(http:|https:)\/\/(\w+|\W+\.\w+\W+(\.\w+\W+)*)(\/\w+|\W+|\w+)*', '', text)

def remove_stop_words(text):
  stop_words = set(stopwords.words('english'))
  word_tokens = word_tokenize(text)
  filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]
  return ' '.join(filtered_sentence)

def stemming(text):
  ps = PorterStemmer()
  words = word_tokenize(text)
  stemmed_sentence = [ps.stem(w) for w in words]
  return ' '.join(stemmed_sentence)

def lemmatize(text):
  words = word_tokenize(text)
  le = WordNetLemmatizer()
  lemmatized_sentence = [le.lemmatize(w) for w in words]
  return ' '.join(lemmatized_sentence)

def num_remove(text):
  word_tokens = word_tokenize(text)
  non_num_seq = []
  for word in word_tokens:
    if re.match('\d+', word):
      non_num_seq.append(re.sub('\d+', '', word))
    else:
      non_num_seq.append(word)
  return ' '.join(non_num_seq)

def len_cut(text):
  word_tokens = word_tokenize(text)
  cutted = [w for w in word_tokens if not len(w) == 1]
  return ' '.join(cutted)

def list_to_str(text_list):
  sentence_agg = ''
  for item in text_list:
    sentence_agg += item
    sentence_agg += ' '
  return sentence_agg.rstrip()

def clean_str(my_str):
  clean_list = ["'", "(", ")"]
  space_list = [".", "-", "/", "#", ":", "<", ">", "_", "[", "]", "+", "{", "}", "!", "@", "$", "%", "*", "=", "…", "?", "`", ",", "\r", "\n", "\d", '"', "~", "^", "PR", "|", "&"]
  for ccrt in clean_list:
    if(ccrt in my_str):
      my_str = my_str.replace(ccrt,"")  
  for scrt in space_list:
    if(scrt in my_str):
      my_str = my_str.replace(scrt," ")
  return my_str.lower()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
if not reuse_translated:
  # Aplicando funções de limpeza textual
  resumo = pd_data['summary'].apply(list_to_str) 
  resumo = resumo.apply(id_removes)  
  resumo = resumo.apply(clean_str)
  resumo = resumo.apply(remove_stop_words)
  resumo = resumo.apply(lemmatize)
  # resumo = resumo.apply(stemming)
  resumo = resumo.apply(num_remove)
  resumo = resumo.apply(len_cut)
  resumo.replace('', np.nan, inplace=True)
  resumo.astype(str)

  tempo = pd_data['timespent']

  descricao = pd_data['description'].apply(list_to_str)  
  descricao = descricao.apply(id_removes)
  descricao = descricao.apply(link_removes)
  descricao = descricao.apply(clean_str)
  descricao = descricao.apply(remove_stop_words)
  descricao = descricao.apply(lemmatize)
  # descricao = descricao.apply(stemming)
  descricao = descricao.apply(num_remove)
  descricao = descricao.apply(len_cut)
  descricao.replace('', np.nan, inplace=True)

# %%
if not reuse_translated:
  # Recriando o dataset somente com as colunas necessárias
  pd_data = pd.DataFrame()
  pd_data['summary'] = resumo
  pd_data['description'] = descricao
  pd_data['timespent'] = tempo

# %%
if not reuse_translated:  
  # Convertendo o timespent para float
  pd_data['timespent'] = pd_data.timespent.astype(float)

  # Removendo linhas com description null
  bool_series = pd.notnull(pd_data['description']) 
  pd_data = pd_data[bool_series]

  nan_value = float("NaN")

  pd_data.replace("", nan_value, inplace=True)
  pd_data.replace(" ", nan_value, inplace=True)
  pd_data.replace("nan", nan_value, inplace=True)

  pd_data.dropna(subset = ["description"], inplace=True)

  # Removendo linhas com summary null
  bool_series = pd.notnull(pd_data['summary']) 
  pd_data = pd_data[bool_series]

  # Removendo linhas com timespent null
  bool_series = pd.notnull(pd_data['timespent']) 
  pd_data = pd_data[bool_series]
  pd_data

# %% [markdown]
# # 3. Remoção inicial de outliers

# %%
if not reuse_translated: 
  # Aplicando o zscore para remoção dos outliers
  cara =  my_zscore(pd_data['timespent'])
  df_sem_outlier_z = pd.DataFrame(
      pd_data[(abs(cara) < z_score_threshold)])

  for i in range(z_score_times):
    cara =  my_zscore(df_sem_outlier_z['timespent'])
    df_sem_outlier_z = pd.DataFrame(
        df_sem_outlier_z[(abs(cara) < z_score_threshold)])

  df_sem_outlier_z.boxplot('timespent')

# %%
if not reuse_translated: 
  df_sem_outlier_z.hist('timespent')

# %%
if not reuse_translated: 
  df_sem_outlier_z

# %%
if not reuse_translated: 
  data = df_sem_outlier_z

# %%
if not reuse_translated: 
  import os
  os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "./drive/MyDrive/ColabNotebooks/mlsdee-1584025432698-0d10d20cb49c.json"
  print(os.environ['GOOGLE_APPLICATION_CREDENTIALS'])

# %%
# Função para tradução
from google.cloud import translate_v3beta1 as translate

def translate_text(text="YOUR_TEXT_TO_TRANSLATE", src_lang='pt', project_id="YOUR_PROJECT_ID"):
    """Translating Text."""

    client = translate.TranslationServiceClient()

    location = "global"

    parent = f"projects/{project_id}/locations/{location}"

    response = client.translate_text(parent=parent,
            contents=[text],
            mime_type="text/plain",
            source_language_code=src_lang,
            target_language_code="en-US"
    )

    return response.translations[0].translated_text

def detect_language(text="YOUR_TEXT_TO_DETECT", project_id="YOUR_PROJECT_ID"):
    """Detecting the language of a text string."""

    client = translate.TranslationServiceClient()

    location = "global"

    parent = f"projects/{project_id}/locations/{location}"

    response = client.detect_language(
        content=text,
        parent=parent,
        mime_type="text/plain"
    )

    return response.languages[0].language_code

# %%
# Traduzir tudo para o inglês
translated_count = 0

def detect_and_translate(text):
  global translated_count

  detected = detect_language(text, 'mlsdee-1584025432698')

  if detected == 'en' or detected == 'en-US' or detected == 'und':
    return text

  translated_count += 1
  print(translated_count)
  print(detected)
  print(text)
  result = translate_text(text, detected, 'mlsdee-1584025432698')
  print(result)
  return result

# %%
if translate_enabled:
  data['summary'] = data['summary'].apply(detect_and_translate)
  data['description'] = data['description'].apply(detect_and_translate)
  data.to_csv('data.csv', index=False)

# %%
# Garantir que obtem os dados traduzidos
if reuse_translated: 
  data = pd.read_csv('./drive/MyDrive/ColabNotebooks/data.csv')

# %% [markdown]
# # 4. Análise exploratória dos dados

# %%
data
# Out:
#                                                  summary  \
# 0      contrib graphic remove body attribute example ...
# 1                                  unused color variable
# 2      grunt task runner dev task copy json change build
# 3                                    narrative component
# 4      play ended completion event dont work source v...
# ...                                                  ...
# 12036                             log time previous work
# 12037   build server continuous integration based bamboo
# 12038                source code management based github
# 12039                           javafx utils new project
# 12040                                build server broken
#
#                                              description  timespent
# 0      know core model attribute actually used compon...     1800.0
# 1                         remove color le file use theme     1800.0
# 2      watch task run grunt dev watch change config j...     1800.0
# 3      heading component item stacked top see button ...     1800.0
# 4      look like mediaelement doesnt broadcast event ...     1800.0
# ...                                                  ...        ...
# 12036  import working hour per year per user andi uli...     2400.0
# 12037  setup bamboo server xenoage utils create job b...     1800.0
# 12038  install stash move zong xenoage utils reposito...     1800.0
# 12039  move generally useful javafx utils new project...     2700.0
# 12040  build server work restart fix classpath proble...     1890.0
#
# [12041 rows x 3 columns]

# %%
# Verificando quais os tempos estimados existentes e observando algumas estatísticas
uniq = data['timespent'].unique()
uniq.sort(axis=0)
print(uniq)
print(len(uniq))

mode = data['timespent'].mode()[0]
median = data['timespent'].median()
mean = data['timespent'].describe()['mean']
std = data['timespent'].describe()['std']

pyplot.figure(figsize=(10,5))
pyplot.plot(uniq, label="timespent values")
pyplot.axhline(y=mode, label="mode", color="#e6440e", linestyle="dashed", linewidth=1.2)
pyplot.axhline(y=median, label="median", color="#7ae60e", linestyle="dashed", linewidth=1.2)
pyplot.axhline(y=mean, label="mean", color="#e6960e", linestyle="dashed", linewidth=1.2)
pyplot.axhline(y=std, label="std", color="#5d0ee6", linestyle="dashed", linewidth=1.2)
pyplot.legend()
pyplot.show()
# Boxplot ou diagrama de distribuiçao
# Out:
# [1320. 1380. 1440. 1488. 1500. 1560. 1620. 1680. 1692. 1740. 1800. 1815.
#  1830. 1860. 1890. 1920. 1980. 2040. 2052. 2088. 2100. 2160. 2220. 2268.
#  2280. 2340. 2400. 2412. 2448. 2460. 2520. 2580. 2628. 2640. 2700. 2715.
#  2760. 2820. 2880. 2940. 3000. 3012. 3048. 3060. 3120. 3168. 3180. 3240.
#  3276. 3300. 3312. 3360. 3420. 3480.]
# 54

# %%
data['timespent'].describe()
# Out:
# count    12041.000000
# mean      2186.462835
# std        480.078739
# min       1320.000000
# 25%       1800.000000
# 50%       1800.000000
# 75%       2400.000000
# max       3480.000000
# Name: timespent, dtype: float64

# %% [markdown]
# # Criação do modelo

# %%
# Obtendo todas as palavras das description e summary para serem treinadas
all_text = []
for des_str in data['description'].values:
  des_str = clean_str(des_str)
  all_text.append(des_str.split())

for sum_str in data['summary'].values:
  sum_str = clean_str(sum_str)
  all_text.append(sum_str.split())

if debug:
  print(len(all_text))
# Out:
# 24082

# %%
# Definindo o modelo de word embeddings
# Variar o embedding size
emb_model = Word2Vec(all_text,
                     seed=rstate, 
                     sg=1,
                     hs=0, 
                     iter=num_epochs, 
                     window=wind, 
                     min_count=mcount, 
                     size=embedding_size, 
                     alpha=emb_model_learning_rate)
if norm_vectors:
  emb_model.init_sims(replace=True)
# Resumo do modelo
if debug:
  print(emb_model)
words = list(emb_model.wv.vocab)
if debug:
  print(words)

vocab_size = len(words) + 1
if debug:
  print(vocab_size)
# Out:
# Word2Vec(vocab=1987, size=64, alpha=0.007)
# ['know', 'core', 'model', 'attribute', 'actually', 'used', 'component', 'little', 'list', 'example', 'json', 'remove', 'color', 'le', 'file', 'use', 'theme', 'watch', 'task', 'run', 'dev', 'change', 'config', 'copy', 'build', 'changed', 'saved', 'replicate', 'make', 'save', 'command', 'line', 'say', 'src', 'course', 'go', 'updated', 'item', 'top', 'see', 'button', 'work', 'doesnt', 'also', 'occurs', 'behaviour', 'nexus', 'android', 'look', 'like', 'event', 'source', 'might', 'well', 'need', 'testing', 'assume', 'could', 'probably', 'way', 'around', 'user', 'click', 'video', 'completion', 'easy', 'though', 'support', 'drop', 'slider', 'icon', 'attached', 'requires', 'choose', 'image', 'option', 'description', 'text', 'question', 'end', 'link', 'every', 'select', 'whole', 'side', 'necessary', 'reached', 'content', 'review', 'quality', 'feedback', 'push', 'github', 'wiki', 'instruction', 'left', 'forward', 'right', 'back', 'occurred', 'merging', 'following', 'pr', 'arrow', 'always', 'present', 'even', 'first', 'take', 'last', 'loop', 'wrong', 'validation', 'variable', 'returning', 'main', 'menu', 'topic', 'page', 'taken', 'must', 'tab', 'however', 'difficult', 'find', 'indicate', 'whether', 'view', 'answer', 'incorrectly', 'incorrect', 'state', 'sorry', 'thats', 'open', 'project', 'pool', 'time', 'writing', 'total', 'official', 'correct', 'display', 'instead', 'mentioned', 'blue', 'element', 'bit', 'broken', 'screenshot', 'show', 'title', 'load', 'initially', 'scroll', 'medium', 'padding', 'currently', 'touch', 'edge', 'box', 'submitted', 'background', 'next', 'looking', 'sense', 'order', 'navigate', 'using', 'close', 'nothing', 'happens', 'selected', 'two', 'different', 'attempt', 'bar', 'full', 'width', 'flush', 'bottom', 'screen', 'completed', 'progress', 'completely', 'filled', 'fill', 'showing', 'white', 'either', 'entry', 'get', 'requested', 'smaller', 'size', 'add', 'disabled', 'code', 'repos', 'checking', 'branch', 'delete', 'equivalent', 'listed', 'locked', 'believe', 'sink', 'demo', 'status', 'read', 'sure', 'blank', 'check', 'enabled', 'within', 'identify', 'instance', 'assessment', 'keyboard', 'navigation', 'selecting', 'proceed', 'result', 'area', 'displayed', 'visible', 'related', 'turned', 'appear', 'style', 'rather', 'much', 'often', 'accessible', 'found', 'individual', 'input', 'field', 'although', 'marked', 'may', 'originally', 'failed', 'passed', 'second', 'verify', 'subsequent', 'platform', 'address', 'closed', 'section', 'selection', 'required', 'ipad', 'io', 'opening', 'away', 'return', 'im', 'test', 'unless', 'set', 'pull', 'multiple', 'consider', 'adding', 'track', 'already', 'would', 'life', 'easier', 'seem', 'across', 'session', 'mark', 'complete', 'moodle', 'console', 'started', 'level', 'incomplete', 'current', 'develop', 'base', 'triggered', 'cause', 'mean', 'added', 'runtime', 'issue', 'device', 'linked', 'turn', 'possible', 'causing', 'hard', 'depending', 'browser', 'affected', 'community', 'updating', 'recent', 'allow', 'html', 'character', 'body', 'readme', 'attempting', 'clone', 'existing', 'portlet', 'stack', 'trace', 'error', 'rendering', 'map', 'exception', 'trying', 'process', 'action', 'problem', 'window', 'caused', 'java', 'lang', 'specified', 'exist', 'start', 'tomcat', 'environment', 'point', 'directory', 'install', 'bin', 'common', 'server', 'minimum', 'separate', 'include', 'shared', 'temp', 'allows', 'hence', 'host', 'running', 'application', 'machine', 'additional', 'information', 'deployment', 'convention', 'property', 'usually', 'home', 'ok', 'portal', 'initialized', 'jar', 'copied', 'really', 'propose', 'introduced', 'give', 'ability', 'value', 'target', 'xml', 'deploy', 'inclusion', 'term', 'appropriate', 'license', 'release', 'displaying', 'definition', 'correctly', 'one', 'name', 'sort', 'viewing', 'modified', 'fall', 'id', 'equal', 'free', 'search', 'engine', 'administrator', 'integration', 'system', 'great', 'tool', 'student', 'important', 'otherwise', 'missed', 'custom', 'fee ...
# 1988

# %%
# Brincando com o modelo py
print(emb_model.wv.similarity('python', 'py'))
emb_model.wv.most_similar(positive=['graph'], topn=10)
# Out:
# 0.6260648
# [('serialized', 0.49029260873794556),
#  ('small', 0.4883952736854553),
#  ('topology', 0.45100170373916626),
#  ('copied', 0.447024941444397),
#  ('every', 0.4263036251068115),
#  ('collection', 0.4252890944480896),
#  ('worker', 0.4232950210571289),
#  ('backport', 0.42307084798812866),
#  ('indexing', 0.422788143157959),
#  ('calling', 0.4217054843902588)]

# %%
# Comparando vetores de palavras
# Scatter dos vetores em 2d
pyplot.figure(figsize=(10,3))
w1 = 'ide'
w2 = 'netbeans'
w1v = emb_model.wv.get_vector(w1)
w2v = emb_model.wv.get_vector(w2)
pyplot.plot(w1v, label=w1)
pyplot.plot(w2v, label=w2)
pyplot.legend()
pyplot.show()

# %%
# Obtendo a lista de docs concatenando summary + description
docs = []
for i in range(len(data)):
  summ = data['summary'].values[i]
  desc = data['description'].values[i]
  docs.append(summ + " " + desc)
for i in range(10):
  print(docs[i])
print(len(docs))
# Out:
# contrib graphic remove body attribute example json know core model attribute actually used component little misleading list example json
# unused color variable remove color le file use theme
# grunt task runner dev task copy json change build watch task run grunt dev watch change config json copy config json build file changed saved replicate run grunt dev make change save file observe command line say file src course config json changed copy coursejson task run go observe config json updated
# narrative component heading component item stacked top see button work button doesnt also occurs behaviour nexus android
# play ended completion event dont work source vimeo look like mediaelement doesnt broadcast event source vimeo might well youtube need testing assume could probably hack way around play event firing user click video completion event unlikely easy though
# slider doesnt support drop shadow slider icon effectively invisible see attached
# question accessible mcq requires user choose image image option need description image option alt text question answerable visually impaired
# query unnecessary element resource tabbing cycle end list link every drawer tabbing select drawer whole side necessary could confuse user thinking theyve reached end drawer content
# review readme review accuracy quality feedback go chuck reassign chuck chuck push adapt github wiki
# review contrib pagelevelprogress readme review accuracy quality feedback go chuck reassign chuck chuck push adapt github wiki
# 12041

# %%
# Criando coluna com o tamanho dos docs
docs_len = []
for doc in docs:
  docs_len.append(len(doc.split()))
print(docs_len[0:10])
# Out:
# [19, 9, 52, 17, 38, 11, 19, 26, 15, 17]

# %%
df_sem_outlier_z = data

# %%
df_sem_outlier_z['docs_lens'] = docs_len

# %%
df_sem_outlier_z
# Out:
#                                                  summary  \
# 0      contrib graphic remove body attribute example ...
# 1                                  unused color variable
# 2      grunt task runner dev task copy json change build
# 3                                    narrative component
# 4      play ended completion event dont work source v...
# ...                                                  ...
# 12036                             log time previous work
# 12037   build server continuous integration based bamboo
# 12038                source code management based github
# 12039                           javafx utils new project
# 12040                                build server broken
#
#                                              description  timespent  docs_lens
# 0      know core model attribute actually used compon...     1800.0         19
# 1                         remove color le file use theme     1800.0          9
# 2      watch task run grunt dev watch change config j...     1800.0         52
# 3      heading component item stacked top see button ...     1800.0         17
# 4      look like mediaelement doesnt broadcast event ...     1800.0         38
# ...                                                  ...        ...        ...
# 12036  import working hour per year per user andi uli...     2400.0         18
# 12037  setup bamboo server xenoage utils create job b...     1800.0         34
# 12038  install stash move zong xenoage utils reposito...     1800.0         30
# 12039  move generally useful javafx utils new project...     2700.0         21
# 12040  build server work restart fix classpath proble...     1890.0         12
#
# [12041 rows x 4 columns]

# %%
df_sem_outlier_z.boxplot('docs_lens')

# %%
# Definindo o tamanho máximo dos docs
max_length_des = 0
if docs_length == 'mean':
  max_length_des = int(df_sem_outlier_z['docs_lens'].mean())
  if debug:
    print(max_length_des)
elif docs_length == 'min':
  max_length_des = int(df_sem_outlier_z['docs_lens'].min())
  if debug:
    print(max_length_des)
else:
  for desc in data[xcol].values:
    sentence_size = 0
    for sentence in desc:
      sentence_size += len(sentence.split())
    if sentence_size > max_length_des:
      max_length_des = sentence_size
  if debug:
    print(max_length_des)
  # Guardar resultado com min, media e max
# Out:
# 33

# %%
for word in words:
  print(word[0:100])
# Out:
# know
# core
# model
# attribute
# actually
# used
# component
# little
# list
# example
# json
# remove
# color
# le
# file
# use
# theme
# watch
# task
# run
# dev
# change
# config
# copy
# build
# changed
# saved
# replicate
# make
# save
# command
# line
# say
# src
# course
# go
# updated
# item
# top
# see
# button
# work
# doesnt
# also
# occurs
# behaviour
# nexus
# android
# look
# like
# event
# source
# might
# well
# need
# testing
# assume
# could
# probably
# way
# around
# user
# click
# video
# completion
# easy
# though
# support
# drop
# slider
# icon
# attached
# requires
# choose
# image
# option
# description
# text
# question
# end
# link
# every
# select
# whole
# side
# necessary
# reached
# content
# review
# quality
# feedback
# push
# github
# wiki
# instruction
# left
# forward
# right
# back
# occurred
# merging
# following
# pr
# arrow
# always
# present
# even
# first
# take
# last
# loop
# wrong
# validation
# variable
# returning
# main
# menu
# topic
# page
# taken
# must
# tab
# however
# difficult
# find
# indicate
# whether
# view
# answer
# incorrectly
# incorrect
# state
# sorry
# thats
# open
# project
# pool
# time
# writing
# total
# official
# correct
# display
# instead
# mentioned
# blue
# element
# bit
# broken
# screenshot
# show
# title
# load
# initially
# scroll
# medium
# padding
# currently
# touch
# edge
# box
# submitted
# background
# next
# looking
# sense
# order
# navigate
# using
# close
# nothing
# happens
# selected
# two
# different
# attempt
# bar
# full
# width
# flush
# bottom
# screen
# completed
# progress
# completely
# filled
# fill
# showing
# white
# either
# entry
# get
# requested
# smaller
# size
# add
# disabled
# code
# repos
# checking
# branch
# delete
# equivalent
# listed
# locked
# believe
# sink
# demo
# status
# read
# sure
# blank
# check
# enabled
# within
# identify
# instance
# assessment
# keyboard
# navigation
# selecting
# proceed
# result
# area
# displayed
# visible
# related
# turned
# appear
# style
# rather
# much
# often
# accessible
# found
# individual
# input
# field
# although
# marked
# may
# originally
# failed
# passed
# second
# verify
# subsequent
# platform
# address
# closed
# section
# selection
# required
# ipad
# io
# opening
# away
# return
# im
# test
# unless
# set
# pull
# multiple
# consider
# adding
# track
# already
# would
# life
# easier
# seem
# across
# session
# mark
# complete
# moodle
# console
# started
# level
# incomplete
# current
# develop
# base
# triggered
# cause
# mean
# added
# runtime
# issue
# device
# linked
# turn
# possible
# causing
# hard
# depending
# browser
# affected
# community
# updating
# recent
# allow
# html
# character
# body
# readme
# attempting
# clone
# existing
# portlet
# stack
# trace
# error
# rendering
# map
# exception
# trying
# process
# action
# problem
# window
# caused
# java
# lang
# specified
# exist
# start
# tomcat
# environment
# point
# directory
# install
# bin
# common
# server
# minimum
# separate
# include
# shared
# temp
# allows
# hence
# host
# running
# application
# machine
# additional
# information
# deployment
# convention
# property
# usually
# home
# ok
# portal
# initialized
# jar
# copied
# really
# propose
# introduced
# give
# ability
# value
# target
# xml
# deploy
# inclusion
# term
# appropriate
# license
# release
# displaying
# definition
# correctly
# one
# name
# sort
# viewing
# modified
# fall
# id
# equal
# free
# search
# engine
# administrator
# integration
# system
# great
# tool
# student
# important
# otherwise
# missed
# custom
# feed
# place
# listing
# version
# match
# offer
# facebook
# info
# document
# contact
# website
# implementation
# created
# create
# class
# api
# handler
# rest
# client
# concurrent
# queue
# object
# scheduled
# method
# called
# via
# footer
# nice
# hide
# default
# provide
# control
# scenario
# explorer
# log
# active
# plan
# shown
# opened
# request
# sso
# got
# clear
# merge
# move
# financial
# group
# together
# red
# keep
# please
# note
# far
# row
# hour
# edit
# new
# dashboard
# still
# several
# ticket
# program
# restriction
# require
# conflict
# observed
# sync
# year
# min
# max
# constraint
# discussed
# reported
# pdf
# assigned
# resource
# cell
# appears
# unable
# reproduce
# form
# able
# least
# similar
# behavior
# assignment
# admin
# deleted
# special
# service
# fails
# chrome
# suspect
# reference
# data
# type
# possibly
# priority
# given
# low
# phone
# number
# rule
# record
# format
# removed
# debug
# parameter
# algorithm
# logged
# message
# going
# duplicate
# since
# therefore
# replaced
# seen
# step
# sample
# follow
# role
# managed
# checked
# update
# put
# regression
# saml
# working
# anymore
# latest
# something
# weve
# sp
# authentication
# login
# successful
# redirects
# response
# contains
# assertion
# redirect
# final
# expected
# url
# took
# real
# properly
# encoded
# uri
# maybe
# query
# path
# generate
# quite
# warning
# call
# token
# endpoint
# output
# remaining
# according
# gateway
# fail
# validate
# cookie
# longer
# function
# try
# execute
# tell
# header
# generates
# realm
# part
# bad
# alias
# configured
# domain
# access
# apis
# safari
# submit
# hover
# applied
# us
# logging
# moving
# web
# container
# noticed
# startup
# context
# setting
# true
# matching
# deployed
# war
# configuration
# generated
# enabling
# javascript
# download
# agent
# nightly
# pattern
# regular
# structure
# occur
# case
# port
# syntax
# functionality
# auth
# module
# reason
# logic
# none
# missing
# configure
# enforce
# ip
# processing
# incoming
# ideally
# help
# provided
# valid
# describe
# const
# declaration
# compilation
# long
# macro
# defined
# empty
# false
# due
# compiler
# fix
# simple
# word
# another
# bug
# affect
# released
# private
# label
# package
# binary
# thus
# job
# situation
# comment
# report
# seems
# setup
# sh
# configuring
# scheduler
# desired
# script
# modification
# rename
# folder
# good
# contain
# sql
# table
# implemented
# so
# tag
# attachment
# com
# actual
# global
# node
# specific
# continue
# specify
# chain
# let
# usage
# clause
# without
# argument
# workaround
# banner
# filename
# txt
# location
# scala
# jvm
# mail
# want
# store
# interface
# schema
# params
# if
# a
# on
# and
# this
# is
# should
# the
# for
# indicates
# that
# available
# at
# it
# socket
# connected
# there
# because
# an
# in
# network
# be
# remains
# compatible
# implement
# string
# relative
# live
# including
# starting
# sleep
# enough
# clicking
# installing
# installed
# confirmation
# distributed
# executing
# replacement
# replace
# dont
# leaving
# database
# local
# unsupported
# documentation
# repository
# precondition
# ignored
# post
# linux
# fatal
# allowed
# downloading
# zip
# space
# series
# viewer
# launched
# directly
# fine
# creating
# quick
# filter
# ui
# building
# alert
# administration
# encoding
# illegalargumentexception
# invalid
# come
# understand
# done
# undefined
# sometimes
# master
# maven
# fixed
# expired
# register
# assign
# publish
# wait
# visit
# permission
# connect
# site
# enter
# production
# credential
# card
# activity
# newer
# better
# associated
# included
# conversation
# upgrade
# stored
# feature
# extension
# avoid
# potential
# moved
# registered
# deprecated
# exists
# introduce
# known
# breaking
# plugins
# detail
# guest
# fee
# criterion
# mapping
# team
# high
# customer
# external
# owner
# reporting
# desktop
# mobile
# app
# email
# password
# tested
# getting
# past
# cs
# investigate
# soon
# effort
# unknown
# overview
# booking
# account
# receive
# null
# acceptance
# coming
# array
# adjust
# modify
# employee
# internal
# payment
# receiving
# transfer
# three
# manual
# made
# wanted
# pas
# along
# thank
# confirm
# layout
# ensure
# lead
# original
# amount
# transaction
# profile
# sale
# idea
# dictionary
# glossary
# guide
# naming
# org
# entered
# customize
# photo
# editing
# management
# initial
# rate
# creation
# trigger
# builder
# stage
# previous
# ob
# thought
# referenced
# git
# send
# modal
# determine
# best
# approach
# various
# recently
# prevents
# certain
# experience
# performance
# product
# resolution
# old
# yet
# converted
# wizard
# shot
# ready
# stopped
# upload
# received
# week
# tax
# day
# stay
# etc
# care
# accept
# condition
# maximum
# loading
# compare
# business
# automatically
# apply
# qa
# applying
# impact
# launch
# checkbox
# security
# override
# regarding
# critical
# disable
# needed
# many
# includes
# allowing
# configurable
# failure
# concern
# calendar
# date
# refresh
# inactive
# distribution
# route
# yes
# stop
# built
# hit
# index
# count
# accepted
# ill
# feel
# went
# goal
# later
# book
# aws
# limit
# bucket
# handle
# doc
# int
# sent
# seeing
# resolve
# tracking
# purpose
# failing
# removing
# cancel
# quote
# dropdown
# finished
# meeting
# split
# removal
# future
# mostly
# clean
# finish
# based
# everything
# basically
# signature
# specifically
# potentially
# simply
# expect
# suite
# making
# thrown
# returned
# channel
# discount
# calculated
# billing
# solution
# creates
# immediately
# pm
# never
# manually
# expression
# column
# unexpected
# development
# decimal
# reflect
# operation
# previously
# happen
# summary
# range
# price
# per
# sending
# normal
# follows
# collection
# addition
# single
# deprecate
# practice
# annotation
# metadata
# suggestion
# absence
# month
# useful
# hello
# switch
# today
# impossible
# success
# requirement
# ive
# repeat
# repeated
# importing
# csv
# manager
# possibility
# dot
# inside
# username
# thanks
# cant
# firefox
# controller
# improvement
# tried
# earlier
# explicit
# php
# provider
# forum
# jira
# parent
# supposed
# didnt
# hi
# member
# regard
# maintain
# think
# personal
# scheme
# general
# deleting
# period
# press
# whereas
# http
# older
# thing
# someone
# super
# software
# anonymous
# connection
# jump
# standard
# mode
# helpful
# notification
# dialog
# prefix
# installation
# relevant
# kind
# moment
# couple
# minute
# notice
# faster
# miss
# lock
# hold
# direct
# reset
# published
# accordingly
# framework
# named
# verification
# subject
# confusing
# registering
# contained
# entering
# break
# suggest
# third
# of
# has
# with
# length
# ldap
# to
# other
# sequence
# consistent
# popup
# logo
# region
# tooltip
# eg
# came
# symbol
# compared
# accessing
# stream
# others
# cast
# relation
# unique
# bulk
# clicked
# confluence
# sorted
# key
# monitor
# regardless
# calling
# catch
# corresponding
# authorization
# workflow
# loaded
# timestamp
# social
# identified
# logout
# hint
# flow
# consumer
# unit
# coverage
# pom
# optional
# internally
# plugin
# scan
# vulnerability
# isnt
# developer
# recovery
# expose
# spring
# bean
# throw
# define
# underlying
# successfully
# serialized
# wont
# entity
# jetty
# driver
# fixing
# people
# byte
# generic
# invoke
# invoked
# mechanism
# recipient
# constructor
# trunk
# mysql
# major
# block
# nullpointerexception
# child
# looked
# stacktrace
# jcr
# apache
# listener
# repo
# perform
# non
# cm
# documented
# handled
# handling
# sub
# author
# closing
# forgot
# lot
# char
# normally
# refer
# execution
# minor
# initialization
# vm
# heap
# invoking
# editor
# skipped
# elapsed
# sec
# enable
# force
# easily
# outside
# scope
# namespace
# pretty
# improved
# namespaces
# described
# uploading
# else
# browse
# except
# hidden
# throwing
# template
# overhead
# commits
# reproduced
# depend
# discovery
# language
# proper
# descriptor
# exclude
# svn
# commit
# anything
# resolver
# factory
# ad
# connector
# static
# binding
# timeout
# root
# basic
# idp
# convert
# nested
# extra
# thread
# cache
# extract
# library
# cc
# lo
# written
# hostname
# net
# lookup
# artifact
# generally
# auto
# duplicated
# mixed
# blocked
# improve
# legacy
# dir
# finally
# copying
# native
# logger
# worked
# align
# retrieve
# shibboleth
# produce
# considered
# proposed
# becomes
# temporary
# diff
# specifying
# leading
# insert
# trivial
# discovered
# containing
# sends
# transform
# db
# likely
# memory
# operator
# patch
# tree
# counter
# protocol
# subclass
# reuse
# big
# deal
# snippet
# reduce
# apparently
# dependency
# utility
# ask
# bump
# stable
# certificate
# cert
# prevent
# warn
# invocation
# destroy
# inner
# mistake
# lower
# fact
# dump
# npe
# pipeline
# shouldnt
# particular
# identifier
# strategy
# sensitive
# federation
# capability
# reading
# oracle
# arent
# effect
# extend
# discussion
# import
# scott
# implementing
# revision
# checkstyle
# archive
# upgraded
# taking
# figure
# installer
# party
# ca
# encountered
# init
# flag
# inherited
# provides
# parsing
# duration
# pick
# bring
# short
# ant
# choice
# located
# audit
# retry
# giving
# anywhere
# twice
# principal
# resolved
# guess
# inform
# complex
# lack
# recommendation
# hand
# eventually
# tl
# restart
# resulting
# openssl
# bundle
# similarly
# generation
# storage
# timer
# unused
# classpath
# predicate
# redundant
# primary
# reverse
# passing
# perhaps
# dynamic
# safe
# mention
# segfault
# explicitly
# interval
# backup
# remote
# limited
# pass
# callback
# supplied
# ssl
# batch
# catalog
# spec
# shell
# wrapper
# small
# macos
# unnecessary
# policy
# issued
# destination
# rid
# hook
# entire
# registration
# writes
# registry
# conversion
# write
# leave
# poll
# proxy
# protected
# mar
# pid
# phase
# ran
# timed
# prior
# random
# outgoing
# ubuntu
# indicating
# lost
# fetch
# unfortunately
# analysis
# mismatch
# pixel
# larger
# difference
# compatibility
# print
# supported
# matter
# public
# cover
# statement
# share
# crash
# parser
# bound
# slow
# large
# modifying
# executed
# google
# dropped
# exactly
# md
# evaluation
# explain
# head
# silently
# hang
# reader
# writer
# mailing
# ignore
# detect
# intended
# parallel
# shutdown
# jenkins
# eclipse
# cli
# exit
# category
# filtering
# performed
# serialization
# constant
# sign
# providing
# typo
# traceback
# hashcode
# guarantee
# alternative
# indexing
# javadoc
# generator
# boolean
# inconsistent
# stuck
# converting
# caching
# codebase
# leak
# keyword
# copyright
# changing
# mvn
# mac
# refactor
# rely
# cost
# prepare
# manage
# tom
# javadocs
# informed
# placed
# double
# deprecation
# printing
# expand
# debugging
# ignores
# applicable
# cached
# cycle
# cleaned
# increase
# cut
# treat
# outcome
# locally
# translation
# central
# authenticate
# persistent
# publishing
# detected
# higher
# happening
# serializer
# happened
# daemon
# violation
# drive
# online
# filesystem
# generating
# inline
# localhost
# position
# configs
# speed
# ctx
# compiled
# suggested
# boost
# ie
# virtual
# reach
# fully
# letter
# migrate
# conf
# typing
# privilege
# chat
# panel
# deletion
# upon
# disk
# printed
# snapshot
# gmt
# attach
# standalone
# focus
# early
# fast
# balance
# wrap
# scm
# uploaded
# hash
# newly
# integrate
# especially
# chunk
# export
# dead
# saw
# stock
# downloaded
# expire
# pop
# noformat
# advanced
# radio
# grid
# age
# shut
# reproducible
# stopping
# clickable
# backend
# locator
# merged
# packaging
# upgrading
# become
# schedule
# performing
# waiting
# saving
# posting
# wrapped
# cloud
# refactoring
# design
# png
# jdk
# hbase
# heartbeat
# jackson
# specification
# netbeans
# simplify
# py
# storm
# cassandra
# nimbus
# travis
# ci
# nifi
# center
# bootstrap
# selector
# misaligned
# cpp
# livy
# collect
# migration
# groovy
# primitive
# hive
# hdfs
# flink
# caught
# zero
# carbondata
# spark
# carbon
# sdk
# calcite
# gradle
# cran
# frame
# depends
# ambari
# hadoop
# cluster
# interpreter
# compile
# zeppelin
# processor
# topology
# spout
# partition
# offset
# kill
# kafka
# buffer
# mouse
# ide
# declared
# beam
# cleanup
# knox
# ignite
# wal
# pointer
# jmx
# baseline
# checkpoint
# tx
# flaky
# datanode
# volume
# benchmark
# closure
# meta
# integer
# geode
# membership
# gfsh
# deadlock
# expectation
# jdbc
# streaming
# python
# broker
# notebook
# executor
# worker
# compaction
# alter
# metastore
# optimization
# performs
# comparison
# join
# aggregate
# grouping
# rat
# self
# metric
# runner
# atlas
# offline
# pyarrow
# lib
# vector
# dataset
# panda
# cmake
# gcc
# raise
# parquet
# plasma
# signed
# unsigned
# mingw
# parse
# accumulo
# compression
# zookeeper
# replication
# netty
# blocking
# zk
# cpu
# race
# yarn
# docker
# checkout
# font
# junit
# void
# allocated
# aligned
# calculation
# segment
# thrift
# kerberos
# restarted
# slot
# blob
# supervisor
# recommended
# greater
# submission
# pending
# async
# compiling
# seed
# leader
# solr
# understanding
# history
# iteration
# iterator
# pack
# coordinator
# phoenix
# consumption
# manifest
# skip
# quickly
# pay
# flowfiles
# flowfile
# relationship
# processed
# exchange
# escape
# enum
# asf
# embedded
# lambda
# executes
# dataflow
# hdp
# assembly
# optimize
# lucene
# supplier
# graph
# ml
# scale
# affinity
# tablet
# statistic
# average
# partitioned
# ozone
# om
# backport
# gc
# stats
# sender
# pdx
# linking
# shift
# chart
# supply
# logical
# inconsistency
# english
# chinese
# negative
# aggregation
# restore
# camel
# rel
# planner
# sum
# physical
# collecting
# str
# overflow
# numeric
# flight
# grpc
# rust
# wheel
# credit
# gandiva
# badge
# ha
# ipc
# correction
# blueprint
# logsearch
# div
# nn
# ranger
# km
# namenode
# widget
# mpack
# exec
# tserver
# accepts
# reconnect
# blog
# campaign
# analytics
# slave
# grade
# sampler
# mariadb
# subscription
# preview
# po
# edited
# uicomponent
# changeset
# privacy
# expanded
# preference
# john
# movement
# landing
# participant
# delivery
# receipt
# errorprone
# datafusion
# homepage
# was
# as
# are
# intranet
# from
# exo
# french
# plf
# gadget
# quantity
# after
# you
# featured
# fisheye
# crucible
# can
# by
# quiz
# inventory
# cashier
# invoice
# paid
# lakeshore
# promotion
# teacher
# shipping
# gsa
# cuat
# accessory
# coupon
# qty
# cart
# shopping
# pdp
# sold
# gift
# paypal
# any
# ada
# have
# been
# when
# which
# all
# same
# will
# but
# some
# i
# through
# they
# we
# only
# values
# being
# where
# than
# out
# fields
# or
# reports
# between
# displays
# contributions
# sped
# fuel
# customers
# cnpj
# cash
# accounts
# pos
# notes
# products
# voucher
# more
# bank
# titles
# pdv
# sales
# nfe
# movements
# lmc
# records
# fiscal
# webposto
# nfce
# tour
# estate
# atlanta
# relay

# %%
# Teste de sanitização para verificar quantas palavras não estão nas embeddings
count = 0
for word in words:
  w_vec = emb_model.wv.get_vector(word)
  if w_vec is None:
    count += 1
print(count)
# Out:
# 0

# %%
# Criando a matriz de embeddings
words_index = dict()
embedding_matrix = zeros((vocab_size, embedding_size))
for i, word in enumerate(words, start=1):
	embedding_vector = emb_model.wv.get_vector(word)
	if embedding_vector is not None:
		embedding_matrix[i] = embedding_vector
		words_index[word] = i

# %%
# Criando array para receber os docs codificados
doc_encoded = zeros((max_length_des))
print(doc_encoded.shape)
# Out:
# (33,)

# %%
# Codificando os documentos
padded_docs = zeros((len(docs), max_length_des))
for i, doc in enumerate(docs):
  doc_word_list = doc.split()
  doc_encoded = zeros((max_length_des))
  for j, word in enumerate(doc_word_list):
    if j < max_length_des:
      w_index = words_index.get(word)
      if w_index is not None:
        doc_encoded[j] = w_index
  padded_docs[i] = doc_encoded
padded_docs
# Out:
# array([[   0.,    0.,   12., ...,    0.,    0.,    0.],
#        [1402.,   13.,  114., ...,    0.,    0.,    0.],
#        [   0.,   19., 1735., ...,   22.,   30.,   15.],
#        ...,
#        [  52.,  198.,  873., ...,    0.,    0.,    0.],
#        [   0.,    0.,  454., ...,    0.,    0.,    0.],
#        [  25.,  336.,  149., ...,    0.,    0.,    0.]])

# %%
print(padded_docs.shape)
# Out:
# (12041, 33)

# %%
# Particionando conjunto de teste e treino para avaliação
# Usar um cid no hipertunning
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(padded_docs, data['timespent'].values, test_size=validation_size, random_state=rstate)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (8428, 33)
# (3613, 33)
# (8428,)
# (3613,)

# %%
# Verificando o y do conjunto de treino 
ytp = pd.Series(y_train)
ytp.hist()
len(y_train)
# Out:
# 8428

# %%
# Verificando o y do conjunto de teste
ytt = pd.Series(y_test)
ytt.hist()
len(y_test)
# Out:
# 3613

# %%
# Definindo o modelo
from tensorflow import keras

def compile_model():
  model = Sequential()
  e = Embedding(vocab_size, embedding_size, weights=[embedding_matrix], input_length=max_length_des, trainable=False)
  model.add(e)
  model.add(Bidirectional(LSTM(max_length_des)))
  model.add(Dropout(dropout_default_value))
  if dense_layers:
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(dropout_default_value))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(dropout_default_value))
  model.add(Dense(64, activation='relu'))
  model.add(Dropout(dropout_default_value))
  model.add(Dense(1))
  opt = keras.optimizers.RMSprop(learning_rate=opt_lr, 
                                 centered=ctered)
  model.compile(loss='mean_squared_error', optimizer=opt, metrics=['mae', 'mean_squared_error'])
  # Resumo do modelo
  print(model.input_shape)
  print(model.summary())
  return model

# %% [markdown]
# # Treinando e avaliando o modelo

# %%
# Treinando com todos os datasets
# Validation set
from keras.backend import clear_session
clear_session()

model = compile_model()
history = model.fit(x_train, y_train, epochs=num_epochs, batch_size=batch_size, validation_split=validation_size, verbose=1)

pyplot.plot(history.history['mae'])
pyplot.plot(history.history['val_mae'])
pyplot.title('model mae')
pyplot.ylabel('mae')
pyplot.xlabel('epoch')
pyplot.legend(['train', 'test'], loc='upper left')
pyplot.show()
# Out:
# (None, 33)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 33, 64)            127232
#
#  bidirectional (Bidirectiona  (None, 66)               25872
#  l)
#
#  dropout (Dropout)           (None, 66)                0
#
#  dense (Dense)               (None, 64)                4288
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 157,457
# Trainable params: 30,225
# Non-trainable params: 127,232
# _________________________________________________________________
# None
# Epoch 1/100
# 47/47 [==============================] - 9s 82ms/step - loss: 2362860.5000 - mae: 1331.2771 - mean_squared_error: 2362860.5000 - val_loss: 344167.0938 - val_mae: 408.5618 - val_mean_squared_error: 344167.0938
# Epoch 2/100
# 47/47 [==============================] - 3s 56ms/step - loss: 918835.4375 - mae: 771.7069 - mean_squared_error: 918835.4375 - val_loss: 322881.5312 - val_mae: 410.2127 - val_mean_squared_error: 322881.5312
# Epoch 3/100
# 47/47 [==============================] - 2s 53ms/step - loss: 869937.0625 - mae: 746.3636 - mean_squared_error: 869937.0625 - val_loss: 331225.9688 - val_mae: 409.4408 - val_mean_squared_error: 331225.9688
# Epoch 4/100
# 47/47 [==============================] - 2s 50ms/step - loss: 867692.2500 - mae: 743.9017 - mean_squared_error: 867692.2500 - val_loss: 283763.0312 - val_mae: 414.1178 - val_mean_squared_error: 283763.0312
# Epoch 5/100
# 47/47 [==============================] - 2s 49ms/step - loss: 818815.0000 - mae: 722.4329 - mean_squared_error: 818815.0000 - val_loss: 327141.7188 - val_mae: 409.2593 - val_mean_squared_error: 327141.7188
# Epoch 6/100
# 47/47 [==============================] - 2s 53ms/step - loss: 803620.9375 - mae: 718.7764 - mean_squared_error: 803620.9375 - val_loss: 272345.2812 - val_mae: 415.5356 - val_mean_squared_error: 272345.2812
# Epoch 7/100
# 47/47 [==============================] - 3s 60ms/step - loss: 813499.3750 - mae: 722.5117 - mean_squared_error: 813499.3750 - val_loss: 328997.7188 - val_mae: 407.3605 - val_mean_squared_error: 328997.7188
# Epoch 8/100
# 47/47 [==============================] - 3s 61ms/step - loss: 811580.6875 - mae: 721.6815 - mean_squared_error: 811580.6875 - val_loss: 327665.8438 - val_mae: 405.9768 - val_mean_squared_error: 327665.8438
# Epoch 9/100
# 47/47 [==============================] - 3s 57ms/step - loss: 803600.3750 - mae: 712.5794 - mean_squared_error: 803600.3750 - val_loss: 317404.0625 - val_mae: 406.2165 - val_mean_squared_error: 317404.0625
# Epoch 10/100
# 47/47 [==============================] - 3s 59ms/step - loss: 770166.1250 - mae: 701.3513 - mean_squared_error: 770166.1250 - val_loss: 404258.2812 - val_mae: 442.6852 - val_mean_squared_error: 404258.2812
# Epoch 11/100
# 47/47 [==============================] - 3s 57ms/step - loss: 766604.8750 - mae: 699.8286 - mean_squared_error: 766604.8750 - val_loss: 282242.6562 - val_mae: 406.3175 - val_mean_squared_error: 282242.6562
# Epoch 12/100
# 47/47 [==============================] - 3s 57ms/step - loss: 740601.1875 - mae: 687.2391 - mean_squared_error: 740601.1875 - val_loss: 245717.0781 - val_mae: 415.4413 - val_mean_squared_error: 245717.0781
# Epoch 13/100
# 47/47 [==============================] - 2s 53ms/step - loss: 768629.9375 - mae: 700.8799 - mean_squared_error: 768629.9375 - val_loss: 329145.4375 - val_mae: 413.0016 - val_mean_squared_error: 329145.4375
# Epoch 14/100
# 47/47 [==============================] - 3s 58ms/step - loss: 761332.8125 - mae: 695.0059 - mean_squared_error: 761332.8125 - val_loss: 260991.8750 - val_mae: 407.7423 - val_mean_squared_error: 260991.8750
# Epoch 15/100
# 47/47 [==============================] - 2s 52ms/step - loss: 747740.6875 - mae: 693.8047 - mean_squared_error: 747740.6875 - val_loss: 409498.7500 - val_mae: 450.2610 - val_mean_squared_error: 409498.7500
# Epoch 16/100
# 47/47 [==============================] - 3s 56ms/step - loss: 737949.4375 - mae: 684.3182 - mean_squared_error: 737949.4375 - val_loss: 320233.9688 - val_mae: 410.2421 - val_mean_squared_error: 320233.9688
# Epoch 17/100
# 47/47 [==============================] - 3s 57ms/step - loss: 738722.1875 - mae: 685.5342 - mean_squared_error: 738722.1875 - val_loss: 258777.4844 - val_mae: 407.3542 - val_mean_squared_error: 258777.4844
# Epoch 18/100
# 47/47 [==============================] - 3s 54ms/step - loss: 736581.3125 - mae: 685.7947 - mean_squared_error: 736581.3125 - val_loss: 376797.2500 - val_mae: 432.4146 - val_mean_squared_error: 376797.2500
# Epoch 19/100
# 47/47 [==============================] - 3s 54ms/step - loss: 724016.7500 - mae: 680.5519 - mean_squared_error: 724016.7500 - val_loss: 334898.0000 - val_mae: 415.7244 - val_mean_squared_error: 334898.0000
# Epoch 20/100
# 47/47 [==============================] - 3s 57ms/step - loss: 700987.8750 - mae: 668.1586 - mean_squared_error: 700987.8750 - val_loss: 392902.1875 - val_mae: 442.4199 - val_mean_squared_error: 392902.1875
# Epoch 21/100
# 47/47 [==============================] - 3s 60ms/step - loss: 701164.1875 - mae: 668.2022 - mean_squared_error: 701164.1875 - val_loss: 395435.8438 - val_mae: 443.8409 - val_mean_squared_error: 395435.8438
# Epoch 22/100
# 47/47 [==============================] - 3s 57ms/step - loss: 681067.0000 - mae: 658.5164 - mean_squared_error: 681067.0000 - val_loss: 234293.3438 - val_mae: 420.9290 - val_mean_squared_error: 234293.3438
# Epoch 23/100
# 47/47 [==============================] - 3s 53ms/step - loss: 663178.0000 - mae: 652.1567 - mean_squared_error: 663178.0000 - val_loss: 345741.8125 - val_mae: 417.6982 - val_mean_squared_error: 345741.8125
# Epoch 24/100
# 47/47 [==============================] - 2s 51ms/step - loss: 661433.1250 - mae: 647.9039 - mean_squared_error: 661433.1250 - val_loss: 319958.0312 - val_mae: 410.5717 - val_mean_squared_error: 319958.0312
# Epoch 25/100
# 47/47 [==============================] - 2s 49ms/step - loss: 645866.3125 - mae: 638.3069 - mean_squared_error: 645866.3125 - val_loss: 286880.0312 - val_mae: 405.9352 - val_mean_squared_error: 286880.0312
# Epoch 26/100
# 47/47 [==============================] - 3s 56ms/step - loss: 644202.6875 - mae: 639.9222 - mean_squared_error: 644202.6875 - val_loss: 307310.0312 - val_mae: 408.3628 - val_mean_squared_error: 307310.0312
# Epoch 27/100
# 47/47 [==============================] - 2s 52ms/step - loss: 647711.1875 - mae: 639.1684 - mean_squared_error: 647711.1875 - val_loss: 290697.0938 - val_mae: 407.2273 - val_mean_squared_error: 290697.0938
# Epoch 28/100
# 47/47 [==============================] - 2s 50ms/step - loss: 618875.1875 - mae: 624.8253 - mean_squared_error: 618875.1875 - val_loss: 252895.5625 - val_mae: 407.6799 - val_mean_squared_error: 252895.5625
# Epoch 29/100
# 47/47 [==============================] - 3s 55ms/step - loss: 605218.1875 - mae: 621.3990 - mean_squared_error: 605218.1875 - val_loss: 289831.9375 - val_mae: 406.7502 - val_mean_squared_error: 289831.9375
# Epoch 30/100
# 47/47 [==============================] - 3s 56ms/step - loss: 586372.6875 - mae: 609.9735 - mean_squared_error: 586372.6875 - val_loss: 265524.3750 - val_mae: 406.0930 - val_mean_squared_error: 265524.3750
# Epoch 31/100
# 47/47 [==============================] - 3s 55ms/step - loss: 592123.3750 - mae: 612.4948 - mean_squared_error: 592123.3750 - val_loss: 289343.3125 - val_mae: 407.0947 - val_mean_squared_error: 289343.3125
# Epoch 32/100
# 47/47 [==============================] - 3s 54ms/step - loss: 569969.3750 - mae: 600.3485 - mean_squared_error: 569969.3750 - val_loss: 309770.4062 - val_mae: 405.6630 - val_mean_squared_error: 309770.4062
# Epoch 33/100
# 47/47 [==============================] - 2s 49ms/step - loss: 569137.1250 - mae: 596.6937 - mean_squared_error: 569137.1250 - val_loss: 260177.6406 - val_mae: 401.6866 - val_mean_squared_error: 260177.6406
# Epoch 34/100
# 47/47 [==============================] - 2s 50ms/step - loss: 565572.6250 - mae: 596.4039 - mean_squared_error: 565572.6250 - val_loss: 234952.7344 - val_mae: 407.9598 - val_mean_squared_error: 234952.7344
# Epoch 35/100
# 47/47 [==============================] - 3s 53ms/step - loss: 546538.3125 - mae: 586.8489 - mean_squared_error: 546538.3125 - val_loss: 242539.4688 - val_mae: 402.1432 - val_mean_squared_error: 242539.4688
# Epoch 36/100
# 47/47 [==============================] - 3s 56ms/step - loss: 528207.3750 - mae: 576.6880 - mean_squared_error: 528207.3750 - val_loss: 261332.2656 - val_mae: 407.9111 - val_mean_squared_error: 261332.2656
# Epoch 37/100
# 47/47 [==============================] - 3s 55ms/step - loss: 554850.0625 - mae: 590.5319 - mean_squared_error: 554850.0625 - val_loss: 287848.9375 - val_mae: 406.2167 - val_mean_squared_error: 287848.9375
# Epoch 38/100
# 47/47 [==============================] - 3s 58ms/step - loss: 536672.7500 - mae: 580.1792 - mean_squared_error: 536672.7500 - val_loss: 242810.4375 - val_mae: 404.3615 - val_mean_squared_error: 242810.4375
# Epoch 39/100
# 47/47 [==============================] - 3s 55ms/step - loss: 539443.1875 - mae: 584.3993 - mean_squared_error: 539443.1875 - val_loss: 241686.6250 - val_mae: 408.1692 - val_mean_squared_error: 241686.6250
# Epoch 40/100
# 47/47 [==============================] - 2s 49ms/step - loss: 522427.7500 - mae: 573.7348 - mean_squared_error: 522427.7500 - val_loss: 235610.6250 - val_mae: 409.7120 - val_mean_squared_error: 235610.6250
# Epoch 41/100
# 47/47 [==============================] - 3s 54ms/step - loss: 516435.5000 - mae: 573.3897 - mean_squared_error: 516435.5000 - val_loss: 245656.7969 - val_mae: 400.2540 - val_mean_squared_error: 245656.7969
# Epoch 42/100
# 47/47 [==============================] - 2s 52ms/step - loss: 521489.9688 - mae: 573.3071 - mean_squared_error: 521489.9688 - val_loss: 266367.5312 - val_mae: 405.9003 - val_mean_squared_error: 266367.5312
# Epoch 43/100
# 47/47 [==============================] - 3s 60ms/step - loss: 527544.6875 - mae: 575.0844 - mean_squared_error: 527544.6875 - val_loss: 244704.3594 - val_mae: 401.6124 - val_mean_squared_error: 244704.3594
# Epoch 44/100
# 47/47 [==============================] - 3s 54ms/step - loss: 523307.1250 - mae: 574.7524 - mean_squared_error: 523307.1250 - val_loss: 247689.3906 - val_mae: 404.3306 - val_mean_squared_error: 247689.3906
# Epoch 45/100
# 47/47 [==============================] - 3s 59ms/step - loss: 513375.5938 - mae: 568.9954 - mean_squared_error: 513375.5938 - val_loss: 251946.9219 - val_mae: 402.6633 - val_mean_squared_error: 251946.9219
# Epoch 46/100
# 47/47 [==============================] - 2s 52ms/step - loss: 523566.9688 - mae: 572.2407 - mean_squared_error: 523566.9688 - val_loss: 229240.9844 - val_mae: 401.8479 - val_mean_squared_error: 229240.9844
# Epoch 47/100
# 47/47 [==============================] - 2s 50ms/step - loss: 503144.7500 - mae: 561.3275 - mean_squared_error: 503144.7500 - val_loss: 244887.0000 - val_mae: 402.7294 - val_mean_squared_error: 244887.0000
# Epoch 48/100
# 47/47 [==============================] - 3s 55ms/step - loss: 507505.7812 - mae: 566.8417 - mean_squared_error: 507505.7812 - val_loss: 249581.6562 - val_mae: 405.8531 - val_mean_squared_error: 249581.6562
# Epoch 49/100
# 47/47 [==============================] - 3s 55ms/step - loss: 504451.0312 - mae: 566.9440 - mean_squared_error: 504451.0312 - val_loss: 254279.3125 - val_mae: 401.4384 - val_mean_squared_error: 254279.3125
# Epoch 50/100
# 47/47 [==============================] - 3s 54ms/step - loss: 497815.6250 - mae: 560.4615 - mean_squared_error: 497815.6250 - val_loss: 235745.9688 - val_mae: 401.7930 - val_mean_squared_error: 235745.9688
# Epoch 51/100
# 47/47 [==============================] - 3s 57ms/step - loss: 492545.5312 - mae: 558.1088 - mean_squared_error: 492545.5312 - val_loss: 242965.6406 - val_mae: 401.7744 - val_mean_squared_error: 242965.6406
# Epoch 52/100
# 47/47 [==============================] - 3s 61ms/step - loss: 496471.8438 - mae: 559.2650 - mean_squared_error: 496471.8438 - val_loss: 248746.1094 - val_mae: 403.3175 - val_mean_squared_error: 248746.1094
# Epoch 53/100
# 47/47 [==============================] - 3s 54ms/step - loss: 490140.8438 - mae: 555.3184 - mean_squared_error: 490140.8438 - val_loss: 251831.4219 - val_mae: 400.8708 - val_mean_squared_error: 251831.4219
# Epoch 54/100
# 47/47 [==============================] - 2s 52ms/step - loss: 473929.8750 - mae: 546.6350 - mean_squared_error: 473929.8750 - val_loss: 231408.3906 - val_mae: 404.5244 - val_mean_squared_error: 231408.3906
# Epoch 55/100
# 47/47 [==============================] - 3s 56ms/step - loss: 492835.3125 - mae: 560.8157 - mean_squared_error: 492835.3125 - val_loss: 263426.3750 - val_mae: 397.6266 - val_mean_squared_error: 263426.3750
# Epoch 56/100
# 47/47 [==============================] - 3s 54ms/step - loss: 497744.2500 - mae: 560.1153 - mean_squared_error: 497744.2500 - val_loss: 240324.1250 - val_mae: 401.1569 - val_mean_squared_error: 240324.1250
# Epoch 57/100
# 47/47 [==============================] - 2s 50ms/step - loss: 493059.4375 - mae: 557.3055 - mean_squared_error: 493059.4375 - val_loss: 270658.1875 - val_mae: 393.9313 - val_mean_squared_error: 270658.1875
# Epoch 58/100
# 47/47 [==============================] - 2s 50ms/step - loss: 489960.6875 - mae: 554.0939 - mean_squared_error: 489960.6875 - val_loss: 236026.7812 - val_mae: 398.6061 - val_mean_squared_error: 236026.7812
# Epoch 59/100
# 47/47 [==============================] - 3s 55ms/step - loss: 469854.3125 - mae: 543.4329 - mean_squared_error: 469854.3125 - val_loss: 242925.2656 - val_mae: 398.7567 - val_mean_squared_error: 242925.2656
# Epoch 60/100
# 47/47 [==============================] - 2s 51ms/step - loss: 471427.0938 - mae: 546.6740 - mean_squared_error: 471427.0938 - val_loss: 233734.4219 - val_mae: 402.9809 - val_mean_squared_error: 233734.4219
# Epoch 61/100
# 47/47 [==============================] - 2s 52ms/step - loss: 474532.8125 - mae: 549.2521 - mean_squared_error: 474532.8125 - val_loss: 229302.9219 - val_mae: 404.9016 - val_mean_squared_error: 229302.9219
# Epoch 62/100
# 47/47 [==============================] - 3s 56ms/step - loss: 479974.4062 - mae: 551.5461 - mean_squared_error: 479974.4062 - val_loss: 265134.6250 - val_mae: 396.4534 - val_mean_squared_error: 265134.6250
# Epoch 63/100
# 47/47 [==============================] - 3s 58ms/step - loss: 471104.0000 - mae: 545.3647 - mean_squared_error: 471104.0000 - val_loss: 253055.3906 - val_mae: 397.4155 - val_mean_squared_error: 253055.3906
# Epoch 64/100
# 47/47 [==============================] - 3s 57ms/step - loss: 472015.5312 - mae: 546.8395 - mean_squared_error: 472015.5312 - val_loss: 259827.2656 - val_mae: 398.4885 - val_mean_squared_error: 259827.2656
# Epoch 65/100
# 47/47 [==============================] - 2s 53ms/step - loss: 454024.0938 - mae: 533.7225 - mean_squared_error: 454024.0938 - val_loss: 247569.7656 - val_mae: 397.9474 - val_mean_squared_error: 247569.7656
# Epoch 66/100
# 47/47 [==============================] - 3s 56ms/step - loss: 486162.1250 - mae: 552.7540 - mean_squared_error: 486162.1250 - val_loss: 246421.1562 - val_mae: 399.8765 - val_mean_squared_error: 246421.1562
# Epoch 67/100
# 47/47 [==============================] - 3s 55ms/step - loss: 467409.1875 - mae: 542.1876 - mean_squared_error: 467409.1875 - val_loss: 263733.5625 - val_mae: 398.4431 - val_mean_squared_error: 263733.5625
# Epoch 68/100
# 47/47 [==============================] - 2s 52ms/step - loss: 467527.9375 - mae: 541.6390 - mean_squared_error: 467527.9375 - val_loss: 243764.8906 - val_mae: 399.8180 - val_mean_squared_error: 243764.8906
# Epoch 69/100
# 47/47 [==============================] - 2s 51ms/step - loss: 466291.4062 - mae: 539.7571 - mean_squared_error: 466291.4062 - val_loss: 250987.9375 - val_mae: 397.8691 - val_mean_squared_error: 250987.9375
# Epoch 70/100
# 47/47 [==============================] - 2s 51ms/step - loss: 464860.7500 - mae: 544.0022 - mean_squared_error: 464860.7500 - val_loss: 255601.3438 - val_mae: 400.3947 - val_mean_squared_error: 255601.3438
# Epoch 71/100
# 47/47 [==============================] - 3s 55ms/step - loss: 453593.1250 - mae: 530.4681 - mean_squared_error: 453593.1250 - val_loss: 253597.8594 - val_mae: 400.7113 - val_mean_squared_error: 253597.8594
# Epoch 72/100
# 47/47 [==============================] - 3s 59ms/step - loss: 441640.6562 - mae: 526.8048 - mean_squared_error: 441640.6562 - val_loss: 249694.8281 - val_mae: 408.7219 - val_mean_squared_error: 249694.8281
# Epoch 73/100
# 47/47 [==============================] - 3s 56ms/step - loss: 461232.0625 - mae: 539.9587 - mean_squared_error: 461232.0625 - val_loss: 253245.0625 - val_mae: 397.7873 - val_mean_squared_error: 253245.0625
# Epoch 74/100
# 47/47 [==============================] - 3s 55ms/step - loss: 442259.7812 - mae: 526.3610 - mean_squared_error: 442259.7812 - val_loss: 249668.7344 - val_mae: 401.6401 - val_mean_squared_error: 249668.7344
# Epoch 75/100
# 47/47 [==============================] - 3s 55ms/step - loss: 452810.4375 - mae: 533.3726 - mean_squared_error: 452810.4375 - val_loss: 243683.7656 - val_mae: 405.8649 - val_mean_squared_error: 243683.7656
# Epoch 76/100
# 47/47 [==============================] - 2s 52ms/step - loss: 446873.6250 - mae: 529.1167 - mean_squared_error: 446873.6250 - val_loss: 279776.7500 - val_mae: 398.0275 - val_mean_squared_error: 279776.7500
# Epoch 77/100
# 47/47 [==============================] - 3s 55ms/step - loss: 454968.2500 - mae: 534.7781 - mean_squared_error: 454968.2500 - val_loss: 257596.4375 - val_mae: 400.2981 - val_mean_squared_error: 257596.4375
# Epoch 78/100
# 47/47 [==============================] - 3s 54ms/step - loss: 445133.3125 - mae: 526.7028 - mean_squared_error: 445133.3125 - val_loss: 250633.2188 - val_mae: 398.6054 - val_mean_squared_error: 250633.2188
# Epoch 79/100
# 47/47 [==============================] - 2s 53ms/step - loss: 442270.5625 - mae: 530.2085 - mean_squared_error: 442270.5625 - val_loss: 261553.5000 - val_mae: 398.2277 - val_mean_squared_error: 261553.5000
# Epoch 80/100
# 47/47 [==============================] - 2s 52ms/step - loss: 446218.5000 - mae: 526.9791 - mean_squared_error: 446218.5000 - val_loss: 250830.7812 - val_mae: 406.0242 - val_mean_squared_error: 250830.7812
# Epoch 81/100
# 47/47 [==============================] - 3s 55ms/step - loss: 452228.9375 - mae: 533.0363 - mean_squared_error: 452228.9375 - val_loss: 249116.7188 - val_mae: 403.8195 - val_mean_squared_error: 249116.7188
# Epoch 82/100
# 47/47 [==============================] - 2s 53ms/step - loss: 432356.3438 - mae: 521.2692 - mean_squared_error: 432356.3438 - val_loss: 257243.0781 - val_mae: 404.2330 - val_mean_squared_error: 257243.0781
# Epoch 83/100
# 47/47 [==============================] - 3s 60ms/step - loss: 443007.3125 - mae: 522.6484 - mean_squared_error: 443007.3125 - val_loss: 254056.8750 - val_mae: 407.1685 - val_mean_squared_error: 254056.8750
# Epoch 84/100
# 47/47 [==============================] - 3s 56ms/step - loss: 441259.2500 - mae: 522.8620 - mean_squared_error: 441259.2500 - val_loss: 263708.5000 - val_mae: 407.1761 - val_mean_squared_error: 263708.5000
# Epoch 85/100
# 47/47 [==============================] - 3s 55ms/step - loss: 436588.3750 - mae: 524.7447 - mean_squared_error: 436588.3750 - val_loss: 255040.6875 - val_mae: 407.1602 - val_mean_squared_error: 255040.6875
# Epoch 86/100
# 47/47 [==============================] - 3s 55ms/step - loss: 445031.9688 - mae: 529.2980 - mean_squared_error: 445031.9688 - val_loss: 290982.1250 - val_mae: 401.9644 - val_mean_squared_error: 290982.1250
# Epoch 87/100
# 47/47 [==============================] - 2s 50ms/step - loss: 438575.4375 - mae: 523.1461 - mean_squared_error: 438575.4375 - val_loss: 291307.4062 - val_mae: 402.4342 - val_mean_squared_error: 291307.4062
# Epoch 88/100
# 47/47 [==============================] - 3s 57ms/step - loss: 436945.7500 - mae: 523.5099 - mean_squared_error: 436945.7500 - val_loss: 273883.0000 - val_mae: 405.5394 - val_mean_squared_error: 273883.0000
# Epoch 89/100
# 47/47 [==============================] - 2s 52ms/step - loss: 425069.0000 - mae: 514.9810 - mean_squared_error: 425069.0000 - val_loss: 278261.8750 - val_mae: 399.6988 - val_mean_squared_error: 278261.8750
# Epoch 90/100
# 47/47 [==============================] - 3s 55ms/step - loss: 434255.4688 - mae: 517.2975 - mean_squared_error: 434255.4688 - val_loss: 258002.5781 - val_mae: 403.7147 - val_mean_squared_error: 258002.5781
# Epoch 91/100
# 47/47 [==============================] - 3s 55ms/step - loss: 435826.9062 - mae: 519.0224 - mean_squared_error: 435826.9062 - val_loss: 256545.4375 - val_mae: 404.7796 - val_mean_squared_error: 256545.4375
# Epoch 92/100
# 47/47 [==============================] - 2s 52ms/step - loss: 430831.3750 - mae: 516.5346 - mean_squared_error: 430831.3750 - val_loss: 262720.5938 - val_mae: 409.7592 - val_mean_squared_error: 262720.5938
# Epoch 93/100
# 47/47 [==============================] - 3s 55ms/step - loss: 433445.4375 - mae: 518.3188 - mean_squared_error: 433445.4375 - val_loss: 267199.8438 - val_mae: 406.7237 - val_mean_squared_error: 267199.8438
# Epoch 94/100
# 47/47 [==============================] - 2s 50ms/step - loss: 419132.6562 - mae: 508.2273 - mean_squared_error: 419132.6562 - val_loss: 258460.9062 - val_mae: 412.1090 - val_mean_squared_error: 258460.9062
# Epoch 95/100
# 47/47 [==============================] - 3s 60ms/step - loss: 427853.2812 - mae: 512.3577 - mean_squared_error: 427853.2812 - val_loss: 278937.7500 - val_mae: 400.5004 - val_mean_squared_error: 278937.7500
# Epoch 96/100
# 47/47 [==============================] - 2s 51ms/step - loss: 423004.0312 - mae: 515.0408 - mean_squared_error: 423004.0312 - val_loss: 269785.7500 - val_mae: 418.4812 - val_mean_squared_error: 269785.7500
# Epoch 97/100
# 47/47 [==============================] - 3s 57ms/step - loss: 419414.5625 - mae: 511.1405 - mean_squared_error: 419414.5625 - val_loss: 253092.3906 - val_mae: 409.7186 - val_mean_squared_error: 253092.3906
# Epoch 98/100
# 47/47 [==============================] - 3s 53ms/step - loss: 421389.3750 - mae: 514.1368 - mean_squared_error: 421389.3750 - val_loss: 267789.4062 - val_mae: 405.3886 - val_mean_squared_error: 267789.4062
# Epoch 99/100
# 47/47 [==============================] - 3s 61ms/step - loss: 409994.9688 - mae: 503.7848 - mean_squared_error: 409994.9688 - val_loss: 264647.0000 - val_mae: 408.4624 - val_mean_squared_error: 264647.0000
# Epoch 100/100
# 47/47 [==============================] - 2s 51ms/step - loss: 426529.5000 - mae: 513.8814 - mean_squared_error: 426529.5000 - val_loss: 275411.4688 - val_mae: 399.3589 - val_mean_squared_error: 275411.4688

# %%
# Fazendo e avaliando previsões com o melhor modelo
predictions = model.predict(x_test)
print(predictions[0:10])
# Out:
# [[1836.8833]
#  [1802.3785]
#  [1886.3989]
#  [1737.6633]
#  [1873.1633]
#  [2217.4023]
#  [1905.2009]
#  [2039.6199]
#  [2630.948 ]
#  [1878.6458]]

# %%
psize = 200
pyplot.figure(figsize=(20,3))
pyplot.plot(predictions[0:psize], label='predicted')
pyplot.plot(y_test[0:psize], label='real')
pyplot.legend()
pyplot.show()

# %%
def plot_results(y_test, predictions):
  x_lim = max(y_test.max(), predictions.max()) + 500
  y_lim = min(y_test.min(), predictions.min()) - 500
  pyplot.figure(figsize=(10,10))
  pyplot.scatter(y_test, predictions, marker='x', alpha=0.5)
  pyplot.scatter(y_test, y_test, marker='o', alpha=0.5)
  pyplot.xlim(y_lim, x_lim)
  pyplot.ylim(y_lim, x_lim)
  pyplot.xlabel("real")
  pyplot.ylabel("predicted")
  pyplot.show()
plot_results(y_test, predictions)

# %%
y_test.max()
# Out:
# 3480.0

# %%
predictions.max()
# Out:
# 3214.6873

# %%
y_test.min()
# Out:
# 1320.0

# %%
predictions.min()
# Out:
# 1490.8265

# %%
# Calculando mmre and mae para validação
from sklearn.metrics import mean_absolute_error

def mre(actual, pred):
  actual += 1
  pred += 1
  mre = (abs(actual - pred)) / actual
  return mre

def mmre(y, pred):
  sum = 0.0
  for i, actual in enumerate(y):
    sum += mre(actual, pred[i])
  mmre = (sum / (len(y))) 
  return mmre

print("PARÂMETROS")
print("--------------------------------------------------------")
print("number of docs: {}".format(len(docs)))
print("vocab size: {}".format(vocab_size))
print("docs_length = {}".format(docs_length))
print("embedding_size = {}".format(embedding_size))
print("z_score_threshold = {}".format(z_score_threshold))
print("z_score_times = {}".format(z_score_times))
print("lstm = {}".format(lstm))
print("dense_layers = {}".format(dense_layers))
print("dropout  = {}".format(dropout ))
print("dropout_default_value = {}".format(dropout_default_value))
print("emb_model_learning_rate = {}".format(emb_model_learning_rate))
print("num_epochs = {}".format(num_epochs))
print("batch_size = {}".format(batch_size))
print(" ")
print("RESULTADO")
print("--------------------------------------------------------")
print("MMRE: {}".format(mmre(y_test, predictions)))
print("MAE: {}".format(mean_absolute_error(y_test, predictions)))
# Out:
# PARÂMETROS
# --------------------------------------------------------
# number of docs: 12041
# vocab size: 1988
# docs_length = mean
# embedding_size = 64
# z_score_threshold = 1
# z_score_times = 5
# lstm = True
# dense_layers = False
# dropout  = True
# dropout_default_value = 0.8
# emb_model_learning_rate = 0.007
# num_epochs = 100
# batch_size = 128
#
# RESULTADO
# --------------------------------------------------------
# MMRE: [0.16586566]
# MAE: 393.4478455687902

# %%
mean = np.full(y_test.size, np.mean(y_test))
median = np.full(y_test.size, np.median(y_test))

# %%
mean_mae = mean_absolute_error(y_test, mean)
median_mae = mean_absolute_error(y_test, median)
model_mae = mean_absolute_error(y_test, predictions)

# %%
by = 0
ly = by + 0.005
pyplot.scatter(mean_mae, by, marker='s', c='#000000')
pyplot.annotate("Mean Mae", (mean_mae, ly - 0.013))
pyplot.scatter(median_mae, by, marker='s', c='#000000')
pyplot.annotate("Median Mae", (median_mae, ly))
if model_mae < mean_mae and model_mae < median_mae:
  mpcolor = '#27ba02'
elif model_mae <= mean_mae and model_mae >= median_mae:
  mpcolor = '#e7eb00'
elif model_mae > mean_mae and model_mae > median_mae:
  mpcolor = '#eb1000'
pyplot.scatter(model_mae, by, marker='s', c=mpcolor)
pyplot.annotate("Model Mae", (model_mae, ly))
pyplot.show()
# Fazer o do quadrático
# Adicionar a nuvem de palavras

# %%
ta = 1.118
td = 1.089
base_y = 0
leg_y = base_y + 0.005
fa = mean_mae/model_mae
fd = median_mae/model_mae
pyplot.scatter([fa, fd, ta, td], np.full(4, base_y), marker='s')
pyplot.annotate("Aa", (fa, leg_y))
pyplot.annotate("Ad", (fd, leg_y))
pyplot.annotate("Ta", (ta, leg_y))
pyplot.annotate("Td", (td, leg_y))
pyplot.show()

# %% [markdown]
# # Células que ainda podem ser úteis

# %%
# from datetime import datetime
# def time_calc(date1, date2):
#   pattern = "%Y-%m-%d %I:%M %p"
#   d1 = datetime.strptime(date1, pattern)
#   d2 = datetime.strptime(date2, pattern)

#   delta = d2 - d1
#   return delta.total_seconds() / 60

# %%
# if not tubelis:  
#   path = './drive/MyDrive/ColabNotebooks/tasks/'
#   filelist = os.listdir(path)

#   pd_data = pd.read_csv(path + filelist[0])
#   for i in range(1, len(filelist)):
#     pd_data2 = pd.read_csv(path + filelist[i])
#     pd_data = pd.concat([pd_data, pd_data2], ignore_index=True)

#   # Removendo linhas com Resolvido null
#   bool_series = pd.notnull(pd_data['Resolvido']) 
#   pd_data = pd_data[bool_series]

#   # Removendo linhas com Criado null
#   bool_series = pd.notnull(pd_data['Criado']) 
#   pd_data = pd_data[bool_series]

# %%
# Abrindo dados como ndarray
# data = []
# path = './drive/MyDrive/ColabNotebooks/data/'
# filelist = os.listdir(path)
# filelist.sort()
# # filelist = ['EVL_lab_clean.json']
# repo_num = len(filelist)
# print("Numero de repositorios: {}".format(repo_num))
# for filename in filelist:
#   with open(path + filename, 'r') as file:
#     repo = json.load(file)
#     data += repo
# ndata = pd.DataFrame(data).values
# pd_data = pd.DataFrame(data)
# if debug:
#   print(ndata)
#   print(ndata.shape)

# %%
# dvc = data['timespent'].value_counts()
# dvcs = dvc.sort_index()
# dvcs.index.to_numpy().astype(str)

# pyplot.figure(figsize=(10,10))
# pyplot.bar(dvcs.index.to_numpy().astype(str), dvcs.values)
# pyplot.show()

# %%
# uniq = data['timespent'].unique()
# uniq.sort(axis=0)
# print(uniq)
# print(len(uniq))

# mode = data['timespent'].mode()[0]
# median = data['timespent'].median()
# mean = data['timespent'].describe()['mean']
# std = data['timespent'].describe()['std']

# pyplot.figure(figsize=(10,5))
# pyplot.plot(uniq, label="timespent values")
# pyplot.axhline(y=mode, label="mode", color="#e6440e", linestyle="dashed", linewidth=1.2)
# pyplot.axhline(y=median, label="median", color="#7ae60e", linestyle="dashed", linewidth=1.2)
# pyplot.axhline(y=mean, label="mean", color="#e6960e", linestyle="dashed", linewidth=1.2)
# pyplot.axhline(y=std, label="std", color="#5d0ee6", linestyle="dashed", linewidth=1.2)
# pyplot.legend()
# pyplot.show()

# %%
# Arquivos das embeddings pré-treinadas
# emb_file = dict()
# emb_file[50] = './drive/MyDrive/ColabNotebooks/glove.6B.50d.txt'
# emb_file[100] = './drive/MyDrive/ColabNotebooks/glove.6B.100d.txt'
# emb_file[200] = './drive/MyDrive/ColabNotebooks/glove.6B.200d.txt'
# emb_file[300] = './drive/MyDrive/ColabNotebooks/glove.6B.300d.txt'

# %%
# Carregando as embeddings pré-treinadas
# embeddings_index = dict()
# f = open(emb_file.get(embedding_size))
# for line in f:
# 	values = line.split()
# 	word = values[0]
# 	coefs = asarray(values[1:], dtype='float32')
# 	embeddings_index[word] = coefs
# f.close()
# print('Loaded %s word vectors.' % len(embeddings_index))

# Quantas palavras não estão na embeddings pré treinadas
# count = 0
# for word in words:
#   if word not in embeddings_index:
#     count += 1
#     #print(word)
# print(count)

# %%
# Criando a matriz de embeddings [pré-treinadas]
# words_index = dict()
# embedding_matrix = zeros((vocab_size, embedding_size))
# for i, word in enumerate(words, start=1):
# 	embedding_vector = embeddings_index.get(word)
# 	if embedding_vector is not None:
# 		embedding_matrix[i] = embedding_vector
# 		words_index[word] = i

# %%
# bool_series = dvc[data["timespent"]] >= minimum_number_of_records
# data = data[bool_series.values]

# %%
# # Treinando com kfolds
# from keras.backend import clear_session
# clear_session()

# from sklearn.model_selection import KFold

# kf = KFold(n_splits=3)
# foldn = 1
# acc_hist = []
# acc_val_hist = []
# models = []
# for train_index, val_index in kf.split(x_train):
 
#   x_train_new = x_train[train_index]
#   y_train_new = y_train[train_index]

#   x_val = x_train[val_index]
#   y_val = y_train[val_index]

#   print("Fold {} ".format(foldn))
#   foldn += 1

#   model = compile_model(print_summary=False)
#   history = model.fit(x_train_new, y_train_new, epochs=10, batch_size=256, validation_data=(x_val, y_val), verbose=1)

#   models.append(model)
#   pyplot.plot(history.history['mae'])
#   pyplot.plot(history.history['val_mae'])
#   pyplot.title('model mae')
#   pyplot.ylabel('mae')
#   pyplot.xlabel('epoch')
#   pyplot.legend(['train', 'test'], loc='upper left')
#   pyplot.show()

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt    
# from sklearn.metrics import confusion_matrix

# cm = confusion_matrix(y_test, pred_class) 

# ax = plt.subplot()
# sns.heatmap(cm, annot=True, fmt='g', ax=ax);  #annot=True to annotate cells, ftm='g' to disable scientific notation

# # labels, title and ticks
# ax.set_xlabel('Predicted labels')
# ax.set_ylabel('True labels') 
# ax.set_title('Confusion Matrix') 
# ax.xaxis.set_ticklabels(categories) 
# ax.yaxis.set_ticklabels(categories)

# %%
# dvc = data['timespent'].value_counts()
# dvcs = dvc.sort_index()
# dvcs.index.to_numpy().astype(str)

# pyplot.figure(figsize=(10,10))
# pyplot.bar(dvcs.index.to_numpy().astype(str), dvcs.values)
# pyplot.show()

# %%
# Avaliando os modelos
# for i, model in enumerate(models):
#   print("MODELO {}".format(i))
#   print('Treino')
#   loss, metric = model.evaluate(x_train, y_train)
#   print('Loss: {}'.format(loss))
#   print('Metric: {}'.format(metric))
#   print('Test')
#   loss, metric = model.evaluate(x_test, y_test)
#   print('Loss: {}'.format(loss))
#   print('Metric: {}'.format(metric))

# %%
# Old figure of confusion matrix
# fig = pyplot.figure()
# ax = fig.add_subplot(111)
# cax = ax.matshow(cm)
# pyplot.title('Confusion matrix of the classifier')
# fig.colorbar(cax)
# ax.set_xticklabels([''] + labels)
# ax.set_yticklabels([''] + labels)
# pyplot.xlabel('Predicted')
# pyplot.ylabel('True')
# pyplot.show()

# %%
# pyplot.plot(history.history['mae'])
# pyplot.plot(history.history['val_mae'])
# pyplot.title('model accuracy')
# pyplot.ylabel('mae')
# pyplot.xlabel('epoch')
# pyplot.legend(['train', 'test'], loc='upper left')
# pyplot.show()

# %%
# # Primeiro Quartil
# Q1 = pd_data['timespent'].quantile(0.25)
# print("Q1: {}".format(Q1))
# # Segundo Quartil
# Q2 = pd_data['timespent'].quantile(0.50)
# print("Q2: {}".format(Q2))
# # Terceiro Quartil
# Q3 = pd_data['timespent'].quantile(0.75)
# print("Q3: {}".format(Q3))
# # Amplitude Interquartil
# IQR = Q3 - Q1
# print("IQR: {}".format(IQR))
# # Limite Superior
# LI = Q1 - (1.5 * IQR)
# print("LI: {}".format(LI))
# # Limite Inferior
# LS = Q3 + (1.5 * IQR)
# print("LS: {}".format(LS))

# %%
# df_sem_outlier = pd.DataFrame(
#     pd_data[(
#         (pd_data['timespent'] >= LI) 
#         & (pd_data['timespent'] <= LS)
#     )])

# sns.boxplot(df_sem_outlier['timespent'])

# %%
# for pred in predictions:
#     if pred != 1089.0886 and pred != 1089.0885:
#       print(pred)

# %%
# # Visualizando o word embedding
# X = emb_model[emb_model.wv.vocab]
# pca = PCA(n_components=2)
# result = pca.fit_transform(X)
# fig, ax = pyplot.subplots()
# ax.scatter(result[:, 0], result[:, 1])
# xlim1 = -0.200
# xlim2 = -0.125
# ylim1 = -0.02
# ylim2 = 0.02
# limits = False

# words = list(emb_model.wv.vocab)
# for i, word in enumerate(words):
#   x = result[i, 0]
#   y = result[i, 1]
#   if limits:
#     if x >= xlim1 and x <= xlim2 and y >= ylim1 and y <= ylim2: 
# 	    ax.annotate(word, xy=(x, y))
#   else:
#     ax.annotate(word, xy=(x, y))

# if limits:
#   ax.set_xlim(xlim1, xlim2)
#   ax.set_ylim(ylim1, ylim2)opt_lr

# %%
# prepare tokenizer
# t = Tokenizer()
# t.fit_on_texts(summary_list)
# vocab_size = len(t.word_index) + 1
# print(vocab_size)

# %%
# integer encode the documents
# encoded_docs = t.texts_to_sequences(summary_list)
# print(encoded_docs)

# %%
# padded_docs = pad_sequences(encoded_docs, maxlen=max_summary_length, padding='post')
# print(padded_docs)

# %%
# ss = StandardScaler()
# sclWord = ss.fit(emb_model.wv.vectors)
# vectors_normalized = sclWord.transform(vocab_dict.values())

# vectors_list = []
# for word in emb_model.wv.vocab:
#   vectors_list.append(emb_model.wv.get_vector(word))

# print(type(emb_model.wv.vocab))
# embeddings_index = dict()
# for i, word in enumerate(list(emb_model.wv.vocab)[0:10]):
#   print(emb_model.wv.vectors[i])
#   print(vectors_list[i])
	#embeddings_index[word] = vectors_normalized[i]

# %%
# count = 0
# for cara in embedding_matrix:
#   if cara[0] == 0:
#     count+=1
# print(count)
