# %% [markdown]
# # 1. Importações de bibliotecas e carregamento de dados

# %%
# !pip install -q -U keras-tuner
# Out:
#      |████████████████████████████████| 135 kB 6.5 MB/s
#      |████████████████████████████████| 1.6 MB 9.8 MB/s

# %%
# Importando bibliotecas necessárias
import json
import numpy as np
import pandas as pd
import math
import sys
import os
import seaborn as sns
import tensorflow as tf
import keras_tuner as kt
from numpy import zeros, array, asarray
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
from matplotlib import pyplot
from matplotlib.pyplot import figure
from keras import metrics
from keras.models import Sequential
from keras.layers import Bidirectional, LSTM, Dense, Dropout, Activation
from keras.layers import Flatten
from keras.layers import Embedding
from wordcloud import WordCloud

# %%
# Parametros modificados com frequência
debug = True
col_switch = ('summary', 'description')
xcol = col_switch[1]
translate_enabled = False
reuse_translated = True

# Esses são importantes
rstate = 7
docs_length = 'mean'
custom_doc_len = 96
z_score_threshold = 1
z_score_times = 5
embedding_size = 64
emb_model_learning_rate = 0.007
wind = 15
mcount = 5
norm_vectors = True
lstm = True
dense_layers = False
dropout = True
dropout_default_value = 0.8
opt_lr = 0.01164
ctered = True
num_epochs = 100
batch_size = 128
validation_size = 0.3

# %%
# Abrindo dados como ndarray
if not reuse_translated:
  data = []
  path = './drive/MyDrive/ColabNotebooks/data/'
  filelist = os.listdir(path)
  filelist.sort()
  repo_num = len(filelist)
  print("Numero de repositorios: {}".format(repo_num))
  for filename in filelist:
    with open(path + filename, 'r') as file:
      repo = json.load(file)
      data += repo
  ndata = pd.DataFrame(data).values
  pd_data = pd.DataFrame(data)
  if debug:
    print(ndata)
    print(ndata.shape)

# %%
# Funções auxiliares
def print_all(df):
  with pd.option_context('display.max_rows', None):
    print(df)

def my_zscore(x):
  return ((x - x.mean())/x.std())

# %% [markdown]
# # 2. Limpeza dos dados

# %%
if not reuse_translated:  
  # Removendo linhas com description null
  bool_series = pd.notnull(pd_data['description']) 
  pd_data = pd_data[bool_series]

  nan_value = float("NaN")

  pd_data.replace("", nan_value, inplace=True)
  pd_data.replace(" ", nan_value, inplace=True)
  pd_data.replace("nan", nan_value, inplace=True)

  pd_data.dropna(subset = ["description"], inplace=True)

  # Removendo linhas com summary null
  bool_series = pd.notnull(pd_data['summary']) 
  pd_data = pd_data[bool_series]

  # Removendo linhas com timespent null
  bool_series = pd.notnull(pd_data['timespent']) 
  pd_data = pd_data[bool_series]

# %%
# Funções para realizar limpeza nos textos
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

def id_removes(text):
  return re.sub('\[(\w|\W)*\]', '', text)

def link_removes(text):
  return re.sub('(http:|https:)\/\/(\w+|\W+\.\w+\W+(\.\w+\W+)*)(\/\w+|\W+|\w+)*', '', text)

def remove_stop_words(text):
  stop_words = set(stopwords.words('english'))
  word_tokens = word_tokenize(text)
  filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]
  return ' '.join(filtered_sentence)

def stemming(text):
  ps = PorterStemmer()
  words = word_tokenize(text)
  stemmed_sentence = [ps.stem(w) for w in words]
  return ' '.join(stemmed_sentence)

def lemmatize(text):
  words = word_tokenize(text)
  le = WordNetLemmatizer()
  lemmatized_sentence = [le.lemmatize(w) for w in words]
  return ' '.join(lemmatized_sentence)

def num_remove(text):
  word_tokens = word_tokenize(text)
  non_num_seq = []
  for word in word_tokens:
    if re.match('\d+', word):
      non_num_seq.append(re.sub('\d+', '', word))
    else:
      non_num_seq.append(word)
  return ' '.join(non_num_seq)

def len_cut(text):
  word_tokens = word_tokenize(text)
  cutted = [w for w in word_tokens if not len(w) == 1]
  return ' '.join(cutted)

def list_to_str(text_list):
  sentence_agg = ''
  for item in text_list:
    sentence_agg += item
    sentence_agg += ' '
  return sentence_agg.rstrip()

def clean_str(my_str):
  clean_list = ["'", "(", ")"]
  space_list = [".", "-", "/", "#", ":", "<", ">", "_", "[", "]", "+", "{", "}", "!", "@", "$", "%", "*", "=", "…", "?", "`", ",", "\r", "\n", "\d", '"', "~", "^", "PR", "|", "&"]
  for ccrt in clean_list:
    if(ccrt in my_str):
      my_str = my_str.replace(ccrt,"")  
  for scrt in space_list:
    if(scrt in my_str):
      my_str = my_str.replace(scrt," ")
  return my_str.lower()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
if not reuse_translated:
  # Aplicando funções de limpeza textual
  resumo = pd_data['summary'].apply(list_to_str) 
  resumo = resumo.apply(id_removes)  
  resumo = resumo.apply(clean_str)
  resumo = resumo.apply(remove_stop_words)
  resumo = resumo.apply(lemmatize)
  # resumo = resumo.apply(stemming)
  resumo = resumo.apply(num_remove)
  resumo = resumo.apply(len_cut)
  resumo.replace('', np.nan, inplace=True)
  resumo.astype(str)

  tempo = pd_data['timespent']

  descricao = pd_data['description'].apply(list_to_str)  
  descricao = descricao.apply(id_removes)
  descricao = descricao.apply(link_removes)
  descricao = descricao.apply(clean_str)
  descricao = descricao.apply(remove_stop_words)
  descricao = descricao.apply(lemmatize)
  # descricao = descricao.apply(stemming)
  descricao = descricao.apply(num_remove)
  descricao = descricao.apply(len_cut)
  descricao.replace('', np.nan, inplace=True)

# %%
if not reuse_translated:
  # Recriando o dataset somente com as colunas necessárias
  pd_data = pd.DataFrame()
  pd_data['summary'] = resumo
  pd_data['description'] = descricao
  pd_data['timespent'] = tempo

# %%
if not reuse_translated:  
  # Convertendo o timespent para float
  pd_data['timespent'] = pd_data.timespent.astype(float)

  # Removendo linhas com description null
  bool_series = pd.notnull(pd_data['description']) 
  pd_data = pd_data[bool_series]

  nan_value = float("NaN")

  pd_data.replace("", nan_value, inplace=True)
  pd_data.replace(" ", nan_value, inplace=True)
  pd_data.replace("nan", nan_value, inplace=True)

  pd_data.dropna(subset = ["description"], inplace=True)

  # Removendo linhas com summary null
  bool_series = pd.notnull(pd_data['summary']) 
  pd_data = pd_data[bool_series]

  # Removendo linhas com timespent null
  bool_series = pd.notnull(pd_data['timespent']) 
  pd_data = pd_data[bool_series]
  pd_data

# %%
# Nuvem de palavra das stopwords
import random
word_dict = {}
for ww in stopwords.words('english'):
  word_dict[ww] = random.randint(1, 10)
wordcloud = WordCloud(width = 800, height = 800,
                        collocations=False,
                  background_color ='white',
                  relative_scaling=0.5,
                  min_font_size = 10).generate_from_frequencies(word_dict)

pyplot.figure(figsize = (8, 8), facecolor = None)
pyplot.imshow(wordcloud)
pyplot.axis("off")
pyplot.tight_layout(pad = 0)

pyplot.show()

# %% [markdown]
# # 3. Remoção inicial de outliers

# %%
if not reuse_translated: 
  # Aplicando o zscore para remoção dos outliers
  cara =  my_zscore(pd_data['timespent'])
  df_sem_outlier_z = pd.DataFrame(
      pd_data[(abs(cara) < z_score_threshold)])

  for i in range(z_score_times):
    cara =  my_zscore(df_sem_outlier_z['timespent'])
    df_sem_outlier_z = pd.DataFrame(
        df_sem_outlier_z[(abs(cara) < z_score_threshold)])

  df_sem_outlier_z.boxplot('timespent')

# %%
if not reuse_translated: 
  df_sem_outlier_z.hist('timespent')

# %%
if not reuse_translated: 
  df_sem_outlier_z

# %%
if not reuse_translated: 
  data = df_sem_outlier_z

# %%
if not reuse_translated: 
  import os
  os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "./drive/MyDrive/ColabNotebooks/mlsdee-1584025432698-0d10d20cb49c.json"
  print(os.environ['GOOGLE_APPLICATION_CREDENTIALS'])

# %%
# Função para tradução
from google.cloud import translate_v3beta1 as translate

def translate_text(text="YOUR_TEXT_TO_TRANSLATE", src_lang='pt', project_id="YOUR_PROJECT_ID"):
    """Translating Text."""

    client = translate.TranslationServiceClient()

    location = "global"

    parent = f"projects/{project_id}/locations/{location}"

    response = client.translate_text(parent=parent,
            contents=[text],
            mime_type="text/plain",
            source_language_code=src_lang,
            target_language_code="en-US"
    )

    return response.translations[0].translated_text

def detect_language(text="YOUR_TEXT_TO_DETECT", project_id="YOUR_PROJECT_ID"):
    """Detecting the language of a text string."""

    client = translate.TranslationServiceClient()

    location = "global"

    parent = f"projects/{project_id}/locations/{location}"

    response = client.detect_language(
        content=text,
        parent=parent,
        mime_type="text/plain"
    )

    return response.languages[0].language_code

# %%
# Traduzir tudo para o inglês
translated_count = 0

def detect_and_translate(text):
  global translated_count

  detected = detect_language(text, 'mlsdee-1584025432698')

  if detected == 'en' or detected == 'en-US' or detected == 'und':
    return text

  translated_count += 1
  print(translated_count)
  print(detected)
  print(text)
  result = translate_text(text, detected, 'mlsdee-1584025432698')
  print(result)
  return result

# %%
if translate_enabled:
  data['summary'] = data['summary'].apply(detect_and_translate)
  data['description'] = data['description'].apply(detect_and_translate)
  data.to_csv('data.csv', index=False)

# %%
# Garantir que obtem os dados traduzidos
if reuse_translated: 
  data = pd.read_csv('./drive/MyDrive/ColabNotebooks/data.csv')

# %% [markdown]
# # 4. Análise exploratória dos dados

# %%
data
# Out:
#                                                  summary  \
# 0      contrib graphic remove body attribute example ...
# 1                                  unused color variable
# 2      grunt task runner dev task copy json change build
# 3                                    narrative component
# 4      play ended completion event dont work source v...
# ...                                                  ...
# 12036                             log time previous work
# 12037   build server continuous integration based bamboo
# 12038                source code management based github
# 12039                           javafx utils new project
# 12040                                build server broken
#
#                                              description  timespent
# 0      know core model attribute actually used compon...     1800.0
# 1                         remove color le file use theme     1800.0
# 2      watch task run grunt dev watch change config j...     1800.0
# 3      heading component item stacked top see button ...     1800.0
# 4      look like mediaelement doesnt broadcast event ...     1800.0
# ...                                                  ...        ...
# 12036  import working hour per year per user andi uli...     2400.0
# 12037  setup bamboo server xenoage utils create job b...     1800.0
# 12038  install stash move zong xenoage utils reposito...     1800.0
# 12039  move generally useful javafx utils new project...     2700.0
# 12040  build server work restart fix classpath proble...     1890.0
#
# [12041 rows x 3 columns]

# %%
for taf in data.iterrows():
  if('grunt task' in taf[1]['summary']):
    print(taf[1]['summary'])
    print(taf[1]['description'])
# Out:
# grunt task runner dev task copy json change build
# watch task run grunt dev watch change config json copy config json build file changed saved replicate run grunt dev make change save file observe command line say file src course config json changed copy coursejson task run go observe config json updated

# %%
# Verificando quais os tempos estimados existentes e observando algumas estatísticas
uniq = data['timespent'].unique()
uniq.sort(axis=0)
print(uniq)
print(len(uniq))

mode = data['timespent'].mode()[0]
median = data['timespent'].median()
mean = data['timespent'].describe()['mean']
std = data['timespent'].describe()['std']

data['timespent'].hist()
# Boxplot ou diagrama de distribuiçao
# Out:
# [1320. 1380. 1440. 1488. 1500. 1560. 1620. 1680. 1692. 1740. 1800. 1815.
#  1830. 1860. 1890. 1920. 1980. 2040. 2052. 2088. 2100. 2160. 2220. 2268.
#  2280. 2340. 2400. 2412. 2448. 2460. 2520. 2580. 2628. 2640. 2700. 2715.
#  2760. 2820. 2880. 2940. 3000. 3012. 3048. 3060. 3120. 3168. 3180. 3240.
#  3276. 3300. 3312. 3360. 3420. 3480.]
# 54

# %%
pyplot.hist(data['timespent'])
ax = pyplot.axes()
ax.yaxis.grid(True)
pyplot.ylabel("Total de tarefas")
pyplot.xlabel("Tempo de execução em minutos")
pyplot.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
data['timespent'].describe()
# Out:
# count    12041.000000
# mean      2186.462835
# std        480.078739
# min       1320.000000
# 25%       1800.000000
# 50%       1800.000000
# 75%       2400.000000
# max       3480.000000
# Name: timespent, dtype: float64

# %% [markdown]
# # Criação do modelo

# %%
# Obtendo todos os docs das description e summary para serem treinadas
all_text = []
for des_str in data['description'].values:
  des_str = clean_str(des_str)
  all_text.append(des_str.split())

for sum_str in data['summary'].values:
  sum_str = clean_str(sum_str)
  all_text.append(sum_str.split())

if debug:
  print(len(all_text))
# Out:
# 24082

# %%
# Criando a nuvem de palavras do texto antes de treinar o modelo
def plot_word_cloud(words):
  text_joined = ' '.join(words)
  wordcloud = WordCloud(width = 800, height = 800,
                        collocations=False,
                  background_color ='white',
                  min_font_size = 10).generate(text_joined)

  pyplot.figure(figsize = (8, 8), facecolor = None)
  pyplot.imshow(wordcloud)
  pyplot.axis("off")
  pyplot.tight_layout(pad = 0)
  
  pyplot.show()

all_words = []
for doc in all_text:
  for word in doc:
    all_words.append(word)
    
plot_word_cloud(all_words)

# %%
# Definindo o modelo de word embeddings
emb_model = Word2Vec(all_text,
                     seed=rstate, 
                     sg=1,
                     hs=0, 
                     iter=num_epochs, 
                     window=wind, 
                     min_count=mcount, 
                     size=embedding_size, 
                     alpha=emb_model_learning_rate)
if norm_vectors:
  emb_model.init_sims(replace=True)
# Resumo do modelo
if debug:
  print(emb_model)
words = list(emb_model.wv.vocab)
if debug:
  print(words)

vocab_size = len(words) + 1
if debug:
  print(vocab_size)
# Out:
# Word2Vec(vocab=6014, size=64, alpha=0.007)
# ['know', 'core', 'model', 'attribute', 'actually', 'used', 'component', 'little', 'misleading', 'list', 'example', 'json', 'remove', 'color', 'le', 'file', 'use', 'theme', 'watch', 'task', 'run', 'grunt', 'dev', 'change', 'config', 'copy', 'build', 'changed', 'saved', 'replicate', 'make', 'save', 'observe', 'command', 'line', 'say', 'src', 'course', 'go', 'updated', 'heading', 'item', 'top', 'see', 'button', 'work', 'doesnt', 'also', 'occurs', 'behaviour', 'nexus', 'android', 'look', 'like', 'broadcast', 'event', 'source', 'vimeo', 'might', 'well', 'need', 'testing', 'assume', 'could', 'probably', 'hack', 'way', 'around', 'play', 'firing', 'user', 'click', 'video', 'completion', 'unlikely', 'easy', 'though', 'support', 'drop', 'shadow', 'slider', 'icon', 'effectively', 'invisible', 'attached', 'requires', 'choose', 'image', 'option', 'description', 'alt', 'text', 'question', 'visually', 'end', 'link', 'every', 'drawer', 'tabbing', 'select', 'whole', 'side', 'necessary', 'confuse', 'thinking', 'reached', 'content', 'review', 'accuracy', 'quality', 'feedback', 'chuck', 'reassign', 'push', 'adapt', 'github', 'wiki', 'instruction', 'left', 'forward', 'swipe', 'right', 'back', 'round', 'practise', 'occurred', 'merging', 'following', 'pr', 'arrow', 'always', 'present', 'even', 'beginning', 'first', 'take', 'last', 'loop', 'infinitely', 'wrong', 'validation', 'variable', 'returning', 'main', 'menu', 'topic', 'page', 'taken', 'must', 'tab', 'visited', 'however', 'difficult', 'find', 'indicate', 'whether', 'view', 'answer', 'incorrectly', 'incorrect', 'state', 'excerpt', 'sorry', 'thats', 'open', 'project', 'established', 'city', 'learning', 'pool', 'time', 'writing', 'total', 'official', 'collaborator', 'correct', 'display', 'instead', 'mentioned', 'viewed', 'blue', 'outline', 'accordion', 'element', 'bit', 'broken', 'corner', 'screenshot', 'overrun', 'centre', 'show', 'title', 'load', 'initially', 'scroll', 'medium', 'transcript', 'padding', 'currently', 'touch', 'edge', 'box', 'submitted', 'grey', 'background', 'tick', 'cross', 'next', 'looking', 'colour', 'sense', 'order', 'navigate', 'using', 'plp', 'close', 'nothing', 'happens', 'selected', 'navigates', 'two', 'different', 'attempt', 'bar', 'full', 'width', 'flush', 'bottom', 'screen', 'completed', 'overall', 'progress', 'completely', 'filled', 'fill', 'slightly', 'showing', 'white', 'either', 'entry', 'get', 'resizing', 'beyond', 'requested', 'stretch', 'smaller', 'size', 'fed', 'add', 'disabled', 'code', 'freeze', 'repos', 'checking', 'branch', 'aim', 'delete', 'stale', 'equivalent', 'listed', 'locked', 'behind', 'trickle', 'unavailable', 'indication', 'believe', 'kitchen', 'sink', 'demo', 'status', 'read', 'sure', 'obviously', 'blank', 'check', 'inspector', 'enabled', 'within', 'identify', 'instance', 'completing', 'assessment', 'keyboard', 'navigation', 'selecting', 'proceed', 'result', 'area', 'displayed', 'visible', 'backed', 'related', 'turned', 'cursor', 'highlight', 'appear', 'thin', 'style', 'rather', 'much', 'obvious', 'yellow', 'often', 'accessible', 'found', 'marking', 'individual', 'input', 'field', 'although', 'marked', 'nb', 'may', 'originally', 'failed', 'passed', 'second', 'verify', 'subsequent', 'platform', 'landscape', 'address', 'narrow', 'closed', 'border', 'surrounding', 'section', 'selection', 'required', 'pc', 'ipad', 'io', 'iphone', 'opening', 'designed', 'away', 'return', 'selectable', 'despite', 'im', 'test', 'unless', 'set', 'pull', 'multiple', 'article', 'consider', 'adding', 'track', 'already', 'perspective', 'would', 'life', 'easier', 'seem', 'across', 'session', 'mark', 'complete', 'moodle', 'console', 'started', 'level', 'incomplete', 'continues', 'current', 'develop', 'base', 'triggered', 'cause', 'mean', 'added', 'dom', 'runtime', 'issue', 'device', 'linked', 'turn', 'light', 'research', 'possible', 'causing', 'hard', 'depending', 'styled', 'browser', 'affected', 'community', 'updating', 'recent', 'allow', 'html', 'character', 'body', 'readme', ...
# 6015

# %%
# Verificando as 20 palavras mais frequentes do modelo
freq_dict = dict()
for w in sorted(emb_model.wv.vocab, key=emb_model.wv.vocab.get)[-20:]:
     freq_dict[w] = emb_model.wv.vocab[w].count

pyplot.figure(figsize=(8,10))
pyplot.barh(range(len(freq_dict)), list(freq_dict.values()), align='center')
ax = pyplot.axes()
ax.xaxis.grid(True)
pyplot.ylabel("Palavras")
pyplot.xlabel("Ocorrências")
pyplot.yticks(range(len(freq_dict)), list(freq_dict.keys()))
pyplot.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
# Verificando as 20 palavras menos frequentes do modelo
freq_dict = dict()
for w in sorted(emb_model.wv.vocab, key=emb_model.wv.vocab.get)[:20]:
     freq_dict[w] = emb_model.wv.vocab[w].count

pyplot.figure(figsize=(8,10))
pyplot.barh(range(len(freq_dict)), list(freq_dict.values()), align='center')
ax = pyplot.axes()
ax.xaxis.grid(True)
pyplot.ylabel("Palavras")
pyplot.xlabel("Ocorrências")
pyplot.yticks(range(len(freq_dict)), list(freq_dict.keys()))
pyplot.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
# Pegando o vocabulário do modelo e colocando numa lista para criar a nuvem de palavras novamente
words_freq = []
for word in words:
  size = emb_model.wv.vocab[word].count
  for i in range(0, size):
    words_freq.append(word)

# %%
# Criando a nuvem de palavras do texto depois de treinar o modelo
plot_word_cloud(words_freq)

# %%
# Mostrando os vertores das palavras reduzidos para 2D
X = emb_model[emb_model.wv.vocab]
pca = PCA(n_components=2)
result = pca.fit_transform(X)
pyplot.figure(figsize=(8,8))
# pyplot.scatter(result[:, 0], result[:, 1])
word_list = ['python', 
             'java',
             'class',
             'code',
             'error', 
             'bug', 
             'ide', 
             'intellij',
             'netbeans',
             'feature', 
             'idea', 
             'development', 
             'maven', 
             'gradle', 
             'android', 
             'mobile',
             'phone',
             'device',
             'html',
             'style', 
             'yarn',
             'repo', 
             'github',
             'git',
             'commit',
             'pull',
             'request',
             'review',
             'tcp',
             'websocket',
             'connection',
             'method',
             'function',
             'javascript',
             'gcp',
             'aws',
             'file',
             'frontend']
for i, word in enumerate(words):
  if word in word_list:
    pyplot.scatter(result[i, 0], result[i, 1])
    pyplot.annotate(word, xy=(result[i, 0], result[i, 1]))
pyplot.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
# Brincando com o modelo py
print(emb_model.wv.similarity('python', 'java'))
emb_model.wv.most_similar(positive=['graph'], topn=10)
# Out:
# 0.5054506
# [('grow', 0.6343837976455688),
#  ('oltp', 0.6137920022010803),
#  ('grows', 0.5974690914154053),
#  ('bolt', 0.5767568349838257),
#  ('ro', 0.5480466485023499),
#  ('ajax', 0.5426905751228333),
#  ('estimate', 0.530433177947998),
#  ('fired', 0.5263370275497437),
#  ('smooth', 0.5237424969673157),
#  ('bridge', 0.5177011489868164)]

# %%
# Comparando vetores de palavras
pyplot.figure(figsize=(10,3))
w1 = 'python'
w2 = 'java'
w1v = emb_model.wv.get_vector(w1)
w2v = emb_model.wv.get_vector(w2)
pyplot.plot(w1v, label=w1)
pyplot.plot(w2v, label=w2)
pyplot.legend()
pyplot.show()

# %%
# Comparando vetores de palavras
print(emb_model.wv.similarity('python', 'android'))
pyplot.figure(figsize=(10,3))
w1 = 'python'
w2 = 'android'
w1v = emb_model.wv.get_vector(w1)
w2v = emb_model.wv.get_vector(w2)
pyplot.plot(w1v, label=w1)
pyplot.plot(w2v, label=w2)
pyplot.legend()
pyplot.show()
# Out:
# 0.103930146

# %%
# Obtendo a lista de docs concatenando summary + description
docs = []
for i in range(len(data)):
  summ = data['summary'].values[i]
  desc = data['description'].values[i]
  docs.append(summ + " " + desc)
for i in range(10):
  print(docs[i])
print(len(docs))
# Out:
# contrib graphic remove body attribute example json know core model attribute actually used component little misleading list example json
# unused color variable remove color le file use theme
# grunt task runner dev task copy json change build watch task run grunt dev watch change config json copy config json build file changed saved replicate run grunt dev make change save file observe command line say file src course config json changed copy coursejson task run go observe config json updated
# narrative component heading component item stacked top see button work button doesnt also occurs behaviour nexus android
# play ended completion event dont work source vimeo look like mediaelement doesnt broadcast event source vimeo might well youtube need testing assume could probably hack way around play event firing user click video completion event unlikely easy though
# slider doesnt support drop shadow slider icon effectively invisible see attached
# question accessible mcq requires user choose image image option need description image option alt text question answerable visually impaired
# query unnecessary element resource tabbing cycle end list link every drawer tabbing select drawer whole side necessary could confuse user thinking theyve reached end drawer content
# review readme review accuracy quality feedback go chuck reassign chuck chuck push adapt github wiki
# review contrib pagelevelprogress readme review accuracy quality feedback go chuck reassign chuck chuck push adapt github wiki
# 12041

# %%
# Criando coluna com o tamanho dos docs
docs_len = []
for doc in docs:
  docs_len.append(len(doc.split()))
print(docs_len[0:10])
# Out:
# [19, 9, 52, 17, 38, 11, 19, 26, 15, 17]

# %%
df_sem_outlier_z = data

# %%
df_sem_outlier_z['docs_lens'] = docs_len

# %%
df_sem_outlier_z
# Out:
#                                                  summary  \
# 0      contrib graphic remove body attribute example ...
# 1                                  unused color variable
# 2      grunt task runner dev task copy json change build
# 3                                    narrative component
# 4      play ended completion event dont work source v...
# ...                                                  ...
# 12036                             log time previous work
# 12037   build server continuous integration based bamboo
# 12038                source code management based github
# 12039                           javafx utils new project
# 12040                                build server broken
#
#                                              description  timespent  docs_lens
# 0      know core model attribute actually used compon...     1800.0         19
# 1                         remove color le file use theme     1800.0          9
# 2      watch task run grunt dev watch change config j...     1800.0         52
# 3      heading component item stacked top see button ...     1800.0         17
# 4      look like mediaelement doesnt broadcast event ...     1800.0         38
# ...                                                  ...        ...        ...
# 12036  import working hour per year per user andi uli...     2400.0         18
# 12037  setup bamboo server xenoage utils create job b...     1800.0         34
# 12038  install stash move zong xenoage utils reposito...     1800.0         30
# 12039  move generally useful javafx utils new project...     2700.0         21
# 12040  build server work restart fix classpath proble...     1890.0         12
#
# [12041 rows x 4 columns]

# %%
df_sem_outlier_z.boxplot('docs_lens')

# %%
# Definindo o tamanho máximo dos docs
max_length_des = 0
if docs_length == 'mean':
  max_length_des = int(df_sem_outlier_z['docs_lens'].mean())
  if debug:
    print(max_length_des)
elif docs_length == 'min':
  max_length_des = int(df_sem_outlier_z['docs_lens'].min())
  if debug:
    print(max_length_des)
else:
  max_length_des = custom_doc_len
  if debug:
    print(max_length_des)
# Out:
# 33

# %%
# Teste de sanitização para verificar quantas palavras não estão nas embeddings
count = 0
for word in words:
  w_vec = emb_model.wv.get_vector(word)
  if w_vec is None:
    count += 1
print(count)
# Out:
# 0

# %%
# Criando a matriz de embeddings
words_index = dict()
embedding_matrix = zeros((vocab_size, embedding_size))
for i, word in enumerate(words, start=1):
	embedding_vector = emb_model.wv.get_vector(word)
	if embedding_vector is not None:
		embedding_matrix[i] = embedding_vector
		words_index[word] = i

# %%
# Criando array para receber os docs codificados
doc_encoded = zeros((max_length_des))
print(doc_encoded.shape)
# Out:
# (33,)

# %%
# Codificando os documentos
padded_docs = zeros((len(docs), max_length_des))
for i, doc in enumerate(docs):
  doc_word_list = doc.split()
  doc_encoded = zeros((max_length_des))
  for j, word in enumerate(doc_word_list):
    if j < max_length_des:
      w_index = words_index.get(word)
      if w_index is not None:
        doc_encoded[j] = w_index
  padded_docs[i] = doc_encoded
padded_docs
# Out:
# array([[4035., 4391.,   13., ...,    0.,    0.,    0.],
#        [2252.,   14.,  142., ...,    0.,    0.,    0.],
#        [  22.,   20., 3426., ...,   24.,   32.,   16.],
#        ...,
#        [  57.,  251., 1162., ...,    0.,    0.,    0.],
#        [   0., 3538.,  573., ...,    0.,    0.,    0.],
#        [  27.,  426.,  186., ...,    0.,    0.,    0.]])

# %%
print(padded_docs.shape)
# Out:
# (12041, 33)

# %%
# Particionando conjunto usado no hipertunning e o que sera usado para treino e teste
from sklearn.model_selection import train_test_split

x_search, x_val, y_search, y_val = train_test_split(padded_docs, data['timespent'].values, test_size=validation_size, random_state=rstate)
print(x_search.shape)
print(x_val.shape)
print(y_search.shape)
print(y_val.shape)
# Out:
# (8428, 33)
# (3613, 33)
# (8428,)
# (3613,)

# %%
# Verificando o y do conjunto de treino 
ytp = pd.Series(y_search)
ytp.hist()
len(y_search)
# Out:
# 8428

# %%
# Verificando o y do conjunto de teste
ytt = pd.Series(y_val)
ytt.hist()
len(y_val)
# Out:
# 3613

# %%
# Definindo o modelo
from tensorflow import keras

def compile_model(hp):
  model = Sequential()
  e = Embedding(vocab_size, embedding_size, weights=[embedding_matrix], input_length=max_length_des, trainable=False)
  hp_l1 = hp.Choice('layer_1', [16, 32, 64])
  hp_l2 = hp.Choice('layer_2', [32, 64, 128])
  model.add(e)
  model.add(Bidirectional(LSTM(hp_l1)))
  model.add(Dropout(dropout_default_value))
  model.add(Dense(hp_l2, activation='relu'))
  model.add(Dropout(dropout_default_value))
  model.add(Dense(1))
  opt = keras.optimizers.RMSprop(learning_rate=opt_lr, 
                                 centered=ctered)
  model.compile(loss='mean_squared_error', optimizer=opt, metrics=['mae', 'mean_squared_error'])
  # Resumo do modelo
  print(model.input_shape)
  print(model.summary())
  return model

# %%
# Definindo o tuner
tuner = kt.RandomSearch(compile_model,
                     objective='val_mae',
                     max_trials=9,
                     seed=rstate,
                     overwrite=True)

stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_mae', patience=10)

tuner.search(x_search, y_search, epochs=20, batch_size=batch_size, validation_split=validation_size, callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=9)[0]
# Out:
# Trial 7 Complete [00h 00m 46s]
# val_mae: 404.3664245605469
#
# Best val_mae So Far: 401.45098876953125
# Total elapsed time: 00h 07m 02s

# %%
best_hps.values
# Out:
# {'layer_1': 32, 'layer_2': 128}

# %%
hp_val = {'layer_1': 16, 'layer_2': 64}

# %% [markdown]
# # Treinando e avaliando o modelo

# %%
# Separando o conjunto de validação em treino e teste
x_train, x_test, y_train, y_test = train_test_split(x_val, y_val, test_size=validation_size, random_state=rstate)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (2529, 33)
# (1084, 33)
# (2529,)
# (1084,)

# %%
# Treinando com os valores encontrados no hypertuning
from keras.backend import clear_session
clear_session()

model = tuner.hypermodel.build(best_hps)
history = model.fit(x_train, y_train, epochs=num_epochs, batch_size=batch_size, validation_split=validation_size, verbose=1)

pyplot.plot(history.history['mae'])
pyplot.plot(history.history['val_mae'])
pyplot.title('model mae')
pyplot.ylabel('mae')
pyplot.xlabel('epoch')
pyplot.legend(['train', 'validation'], loc='upper left')
pyplot.show()

pyplot.plot(history.history['mean_squared_error'])
pyplot.plot(history.history['val_mean_squared_error'])
pyplot.title('model mean_squared_error')
pyplot.ylabel('mean_squared_error')
pyplot.xlabel('epoch')
pyplot.legend(['train', 'validation'], loc='upper left')
pyplot.show()
# Out:
# (None, 33)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 33, 64)            384960
#
#  bidirectional (Bidirectiona  (None, 64)               24832
#  l)
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 128)               8320
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 418,241
# Trainable params: 33,281
# Non-trainable params: 384,960
# _________________________________________________________________
# None
# Epoch 1/100
# 14/14 [==============================] - 7s 117ms/step - loss: 3949900.0000 - mae: 1908.6207 - mean_squared_error: 3949900.0000 - val_loss: 2014357.7500 - val_mae: 1334.0259 - val_mean_squared_error: 2014357.7500
# Epoch 2/100
# 14/14 [==============================] - 1s 43ms/step - loss: 1083010.0000 - mae: 864.1251 - mean_squared_error: 1083010.0000 - val_loss: 309085.0625 - val_mae: 423.2215 - val_mean_squared_error: 309085.0625
# Epoch 3/100
# 14/14 [==============================] - 1s 43ms/step - loss: 673703.8750 - mae: 651.7421 - mean_squared_error: 673703.8750 - val_loss: 296112.2500 - val_mae: 423.2524 - val_mean_squared_error: 296112.2500
# Epoch 4/100
# 14/14 [==============================] - 1s 43ms/step - loss: 700236.3125 - mae: 668.9740 - mean_squared_error: 700236.3125 - val_loss: 284196.8750 - val_mae: 423.3013 - val_mean_squared_error: 284196.8750
# Epoch 5/100
# 14/14 [==============================] - 1s 48ms/step - loss: 684011.8125 - mae: 663.4031 - mean_squared_error: 684011.8125 - val_loss: 313707.3438 - val_mae: 423.1752 - val_mean_squared_error: 313707.3438
# Epoch 6/100
# 14/14 [==============================] - 1s 52ms/step - loss: 639718.1875 - mae: 640.7388 - mean_squared_error: 639718.1875 - val_loss: 315602.3125 - val_mae: 423.1458 - val_mean_squared_error: 315602.3125
# Epoch 7/100
# 14/14 [==============================] - 1s 50ms/step - loss: 667423.4375 - mae: 650.6498 - mean_squared_error: 667423.4375 - val_loss: 332495.4375 - val_mae: 423.1125 - val_mean_squared_error: 332495.4375
# Epoch 8/100
# 14/14 [==============================] - 1s 46ms/step - loss: 669034.3125 - mae: 649.0197 - mean_squared_error: 669034.3125 - val_loss: 278615.5938 - val_mae: 423.2152 - val_mean_squared_error: 278615.5938
# Epoch 9/100
# 14/14 [==============================] - 1s 45ms/step - loss: 683094.3750 - mae: 652.0468 - mean_squared_error: 683094.3750 - val_loss: 272031.8438 - val_mae: 423.2234 - val_mean_squared_error: 272031.8438
# Epoch 10/100
# 14/14 [==============================] - 1s 48ms/step - loss: 640586.7500 - mae: 645.3511 - mean_squared_error: 640586.7500 - val_loss: 264182.5938 - val_mae: 423.3754 - val_mean_squared_error: 264182.5938
# Epoch 11/100
# 14/14 [==============================] - 1s 47ms/step - loss: 662098.5000 - mae: 648.8306 - mean_squared_error: 662098.5000 - val_loss: 291985.7812 - val_mae: 422.8134 - val_mean_squared_error: 291985.7812
# Epoch 12/100
# 14/14 [==============================] - 1s 43ms/step - loss: 626751.8125 - mae: 626.1423 - mean_squared_error: 626751.8125 - val_loss: 261120.2969 - val_mae: 423.1019 - val_mean_squared_error: 261120.2969
# Epoch 13/100
# 14/14 [==============================] - 1s 42ms/step - loss: 614993.6875 - mae: 625.8475 - mean_squared_error: 614993.6875 - val_loss: 300948.6250 - val_mae: 422.3193 - val_mean_squared_error: 300948.6250
# Epoch 14/100
# 14/14 [==============================] - 1s 42ms/step - loss: 622315.1875 - mae: 629.6984 - mean_squared_error: 622315.1875 - val_loss: 295690.2500 - val_mae: 422.3492 - val_mean_squared_error: 295690.2500
# Epoch 15/100
# 14/14 [==============================] - 1s 49ms/step - loss: 621374.8125 - mae: 618.4094 - mean_squared_error: 621374.8125 - val_loss: 267953.9375 - val_mae: 422.4557 - val_mean_squared_error: 267953.9375
# Epoch 16/100
# Epoch 30/100
# 14/14 [==============================] - 1s 50ms/step - loss: 564155.8125 - mae: 591.2472 - mean_squared_error: 564155.8125 - val_loss: 257001.2344 - val_mae: 413.5990 - val_mean_squared_error: 257001.2344
# Epoch 31/100
# 14/14 [==============================] - 1s 51ms/step - loss: 586206.0000 - mae: 609.4637 - mean_squared_error: 586206.0000 - val_loss: 255537.6719 - val_mae: 412.9772 - val_mean_squared_error: 255537.6719
# Epoch 32/100
# 14/14 [==============================] - 1s 43ms/step - loss: 544764.5000 - mae: 584.7878 - mean_squared_error: 544764.5000 - val_loss: 415235.2812 - val_mae: 459.0650 - val_mean_squared_error: 415235.2812
# Epoch 33/100
# 14/14 [==============================] - 1s 45ms/step - loss: 567835.8125 - mae: 598.3879 - mean_squared_error: 567835.8125 - val_loss: 250505.8906 - val_mae: 413.1996 - val_mean_squared_error: 250505.8906
# Epoch 34/100
# 14/14 [==============================] - 1s 43ms/step - loss: 604002.6875 - mae: 619.8271 - mean_squared_error: 604002.6875 - val_loss: 255154.2500 - val_mae: 412.2829 - val_mean_squared_error: 255154.2500
# Epoch 35/100
# 14/14 [==============================] - 1s 51ms/step - loss: 542060.6250 - mae: 591.0262 - mean_squared_error: 542060.6250 - val_loss: 258794.5781 - val_mae: 412.5771 - val_mean_squared_error: 258794.5781
# Epoch 36/100
# 14/14 [==============================] - 1s 53ms/step - loss: 547506.3750 - mae: 585.5405 - mean_squared_error: 547506.3750 - val_loss: 266603.4375 - val_mae: 412.3715 - val_mean_squared_error: 266603.4375
# Epoch 37/100
# 14/14 [==============================] - 1s 54ms/step - loss: 556049.8750 - mae: 598.5374 - mean_squared_error: 556049.8750 - val_loss: 278607.2188 - val_mae: 413.9420 - val_mean_squared_error: 278607.2188
# Epoch 38/100
# 14/14 [==============================] - 1s 43ms/step - loss: 524839.1250 - mae: 573.2766 - mean_squared_error: 524839.1250 - val_loss: 248417.2656 - val_mae: 413.5405 - val_mean_squared_error: 248417.2656
# Epoch 39/100
# 14/14 [==============================] - 1s 47ms/step - loss: 543142.5000 - mae: 588.9781 - mean_squared_error: 543142.5000 - val_loss: 288556.9062 - val_mae: 414.4544 - val_mean_squared_error: 288556.8750
# Epoch 40/100
# 14/14 [==============================] - 1s 51ms/step - loss: 516296.7812 - mae: 570.0491 - mean_squared_error: 516296.7812 - val_loss: 278163.8125 - val_mae: 414.3085 - val_mean_squared_error: 278163.8125
# Epoch 41/100
# 14/14 [==============================] - 1s 43ms/step - loss: 535866.0625 - mae: 583.2415 - mean_squared_error: 535866.0625 - val_loss: 279573.2500 - val_mae: 414.0027 - val_mean_squared_error: 279573.2500
# Epoch 42/100
# 14/14 [==============================] - 1s 44ms/step - loss: 518445.8750 - mae: 567.0026 - mean_squared_error: 518445.8750 - val_loss: 304120.7188 - val_mae: 417.5635 - val_mean_squared_error: 304120.7188
# Epoch 43/100
# 14/14 [==============================] - 1s 43ms/step - loss: 547722.3125 - mae: 587.7457 - mean_squared_error: 547722.3125 - val_loss: 340844.5312 - val_mae: 425.4128 - val_mean_squared_error: 340844.5312
# 14/14 [==============================] - 2s 161ms/step - loss: 305618.3750 - mae: 435.4094 - mean_squared_error: 305618.3750 - val_loss: 249221.8750 - val_mae: 404.7695 - val_mean_squared_error: 249221.8750
# Epoch 99/100
# 14/14 [==============================] - 2s 174ms/step - loss: 308761.8125 - mae: 440.3330 - mean_squared_error: 308761.8125 - val_loss: 244917.9062 - val_mae: 408.0217 - val_mean_squared_error: 244917.9062
# Epoch 100/100
# 14/14 [==============================] - 2s 115ms/step - loss: 338873.5312 - mae: 457.7361 - mean_squared_error: 338873.5312 - val_loss: 250141.6250 - val_mae: 404.9927 - val_mean_squared_error: 250141.6250

# %%
# Plotar modelo em arquivo
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
# Fazendo e avaliando previsões com o melhor modelo no conjunto de teste
predictions = model.predict(x_test)
print(predictions[0:10])
# Out:
# 34/34 [==============================] - 3s 20ms/step
# [[2209.1023]
#  [2003.207 ]
#  [2405.467 ]
#  [2343.816 ]
#  [2135.6572]
#  [2052.1157]
#  [2191.9626]
#  [2103.8862]
#  [2269.0483]
#  [2156.6047]]

# %%
psize = 200
pyplot.figure(figsize=(20,3))
pyplot.plot(predictions[0:psize], label='predicted')
pyplot.plot(y_test[0:psize], label='real')
pyplot.legend()
pyplot.show()

# %%
def plot_results(y_test, predictions):
  x_lim = max(y_test.max(), predictions.max()) + 300
  y_lim = min(y_test.min(), predictions.min()) - 200
  pyplot.figure(figsize=(10,10))
  prev = pyplot.scatter(y_test, predictions, marker='x', alpha=0.5)
  real = pyplot.scatter(y_test, y_test, marker='o', alpha=0.5)
  pyplot.xlim(y_lim, x_lim)
  pyplot.ylim(y_lim, x_lim)
  pyplot.xlabel("real")
  pyplot.ylabel("previsto")
  pyplot.legend((prev, real), ("Previsto", "Real"))
  pyplot.show()
plot_results(y_test, predictions)

# %%
y_test.max()
# Out:
# 3420.0

# %%
predictions.max()
# Out:
# 2858.3452

# %%
y_test.min()
# Out:
# 1320.0

# %%
predictions.min()
# Out:
# 1700.9509

# %%
# Calculando mmre and mae para validação
from sklearn.metrics import mean_absolute_error

def mre(actual, pred):
  actual += 1
  pred += 1
  mre = (abs(actual - pred)) / actual
  return mre

def mmre(y, pred):
  sum = 0.0
  for i, actual in enumerate(y):
    sum += mre(actual, pred[i])
  mmre = (sum / (len(y))) 
  return mmre

print("PARÂMETROS")
print("--------------------------------------------------------")
print("number of docs: {}".format(len(docs)))
print("vocab size: {}".format(vocab_size))
print("docs_length = {}".format(docs_length))
print("minimum count = {}".format(mcount))
print("embedding_size = {}".format(embedding_size))
print("z_score_threshold = {}".format(z_score_threshold))
print("z_score_times = {}".format(z_score_times))
print("lstm = {}".format(lstm))
print("dense_layers = {}".format(dense_layers))
print("dropout  = {}".format(dropout ))
print("dropout_default_value = {}".format(dropout_default_value))
print("emb_model_learning_rate = {}".format(emb_model_learning_rate))
print("num_epochs = {}".format(num_epochs))
print("batch_size = {}".format(batch_size))
print(" ")
print("RESULTADO")
print("--------------------------------------------------------")
print("MMRE: {}".format(mmre(y_test, predictions)))
print("MAE: {}".format(mean_absolute_error(y_test, predictions)))
print("MSE: {}".format(math.sqrt(mean_squared_error(y_test, predictions))))
# Out:
# PARÂMETROS
# --------------------------------------------------------
# number of docs: 12041
# vocab size: 6015
# docs_length = mean
# minimum count = 5
# embedding_size = 64
# z_score_threshold = 1
# z_score_times = 5
# lstm = True
# dense_layers = False
# dropout  = True
# dropout_default_value = 0.8
# emb_model_learning_rate = 0.007
# num_epochs = 100
# batch_size = 128
#
# RESULTADO
# --------------------------------------------------------
# MMRE: [0.1749361]
# MAE: 392.9132643133072
# MSE: 481.2192275303287

# %%
mean = np.full(y_train.size, np.mean(y_train))
median = np.full(y_train.size, np.median(y_train))

# %%
mean_mae = mean_absolute_error(y_test, mean[0:y_test.size])
median_mae = mean_absolute_error(y_test, median[0:y_test.size])
model_mae = mean_absolute_error(y_test, predictions)

# %%
mean_mse = math.sqrt(mean_squared_error(y_test, mean[0:y_test.size]))
median_mse = math.sqrt(mean_squared_error(y_test, median[0:y_test.size]))
model_mse = math.sqrt(mean_squared_error(y_test, predictions))

# %%
by = 0
ly = by + 0.005
pyplot.figure(figsize=(7,2))
pyplot.axes(yticklabels=[], yticks=[])
pmean_mse = pyplot.scatter(mean_mse, by, marker='d', c='#F0B27A')
# pyplot.annotate("Mean Mse", (mean_mse, ly - 0.013))
pmedian_mse = pyplot.scatter(median_mse, by, marker='d', c='#D35400')
# pyplot.annotate("Median Mse", (median_mse, ly))
if model_mse < median_mse and model_mse < mean_mse:
  mpcolor = '#27ba02'
elif model_mse <= median_mse and model_mse >= mean_mse:
  mpcolor = '#e7eb00'
elif model_mse > median_mse and model_mse > mean_mse:
  mpcolor = '#eb1000'
pmodel_mse = pyplot.scatter(model_mse, by, marker='o', c=mpcolor)
# pyplot.annotate("Model Mse", (model_mse, ly))

pmean_mae = pyplot.scatter(mean_mae, by, marker='d', c='#2E86C1')
# pyplot.annotate("Mean Mae", (mean_mae, ly - 0.013))
pmedian_mae = pyplot.scatter(median_mae, by, marker='d', c='#7FB3D5')
# pyplot.annotate("Median Mae", (median_mae, ly))
if model_mae < mean_mae and model_mae < median_mae:
  mpcolor = '#27ba02'
elif model_mae <= mean_mae and model_mae >= median_mae:
  mpcolor = '#e7eb00'
elif model_mae > mean_mae and model_mae > median_mae:
  mpcolor = '#eb1000'
pmodel_mae = pyplot.scatter(model_mae, by, marker='o', c=mpcolor)
# pyplot.annotate("Model Mae", (model_mae, ly))
pyplot.legend((pmodel_mae, pmedian_mae, pmean_mae, pmodel_mse, pmean_mse, pmedian_mse), ("Model MAE", "Median MAE", "Mean MAE", "Model MSE", "Mean MSE", "Median MSE"), bbox_to_anchor=(1.04, 0.5), loc="center left", borderaxespad=1)
pyplot.show()

# %%
print("Mean MAE: {}".format(mean_mae))
print("Median MAE: {}".format(median_mae))
print("Model MAE: {}".format(model_mae))
print("Mean MSE: {}".format(mean_mse))
print("Median MSE: {}".format(median_mse))
print("Model MSE: {}".format(model_mse))
# Out:
# Mean MAE: 414.3029014720752
# Median MAE: 394.8348708487085
# Model MAE: 392.9132643133072
# Mean MSE: 462.95305455537
# Median MSE: 596.2245399423948
# Model MSE: 481.2192275303287

# %% [markdown]
# # Células que ainda podem ser úteis

# %%
# ta = 1.118
# td = 1.089
# base_y = 0
# leg_y = base_y + 0.005
# fa = mean_mae/model_mae
# fd = median_mae/model_mae
# pyplot.scatter([fa, fd, ta, td], np.full(4, base_y), marker='s')
# pyplot.annotate("Aa", (fa, leg_y))
# pyplot.annotate("Ad", (fd, leg_y))
# pyplot.annotate("Ta", (ta, leg_y))
# pyplot.annotate("Td", (td, leg_y))
# pyplot.show()

# %%
# from datetime import datetime
# def time_calc(date1, date2):
#   pattern = "%Y-%m-%d %I:%M %p"
#   d1 = datetime.strptime(date1, pattern)
#   d2 = datetime.strptime(date2, pattern)

#   delta = d2 - d1
#   return delta.total_seconds() / 60

# %%
# if not tubelis:  
#   path = './drive/MyDrive/ColabNotebooks/tasks/'
#   filelist = os.listdir(path)

#   pd_data = pd.read_csv(path + filelist[0])
#   for i in range(1, len(filelist)):
#     pd_data2 = pd.read_csv(path + filelist[i])
#     pd_data = pd.concat([pd_data, pd_data2], ignore_index=True)

#   # Removendo linhas com Resolvido null
#   bool_series = pd.notnull(pd_data['Resolvido']) 
#   pd_data = pd_data[bool_series]

#   # Removendo linhas com Criado null
#   bool_series = pd.notnull(pd_data['Criado']) 
#   pd_data = pd_data[bool_series]

# %%
# Abrindo dados como ndarray
# data = []
# path = './drive/MyDrive/ColabNotebooks/data/'
# filelist = os.listdir(path)
# filelist.sort()
# # filelist = ['EVL_lab_clean.json']
# repo_num = len(filelist)
# print("Numero de repositorios: {}".format(repo_num))
# for filename in filelist:
#   with open(path + filename, 'r') as file:
#     repo = json.load(file)
#     data += repo
# ndata = pd.DataFrame(data).values
# pd_data = pd.DataFrame(data)
# if debug:
#   print(ndata)
#   print(ndata.shape)

# %%
# dvc = data['timespent'].value_counts()
# dvcs = dvc.sort_index()
# dvcs.index.to_numpy().astype(str)

# pyplot.figure(figsize=(10,10))
# pyplot.bar(dvcs.index.to_numpy().astype(str), dvcs.values)
# pyplot.show()

# %%
# uniq = data['timespent'].unique()
# uniq.sort(axis=0)
# print(uniq)
# print(len(uniq))

# mode = data['timespent'].mode()[0]
# median = data['timespent'].median()
# mean = data['timespent'].describe()['mean']
# std = data['timespent'].describe()['std']

# pyplot.figure(figsize=(10,5))
# pyplot.plot(uniq, label="timespent values")
# pyplot.axhline(y=mode, label="mode", color="#e6440e", linestyle="dashed", linewidth=1.2)
# pyplot.axhline(y=median, label="median", color="#7ae60e", linestyle="dashed", linewidth=1.2)
# pyplot.axhline(y=mean, label="mean", color="#e6960e", linestyle="dashed", linewidth=1.2)
# pyplot.axhline(y=std, label="std", color="#5d0ee6", linestyle="dashed", linewidth=1.2)
# pyplot.legend()
# pyplot.show()

# %%
# Arquivos das embeddings pré-treinadas
# emb_file = dict()
# emb_file[50] = './drive/MyDrive/ColabNotebooks/glove.6B.50d.txt'
# emb_file[100] = './drive/MyDrive/ColabNotebooks/glove.6B.100d.txt'
# emb_file[200] = './drive/MyDrive/ColabNotebooks/glove.6B.200d.txt'
# emb_file[300] = './drive/MyDrive/ColabNotebooks/glove.6B.300d.txt'

# %%
# Carregando as embeddings pré-treinadas
# embeddings_index = dict()
# f = open(emb_file.get(embedding_size))
# for line in f:
# 	values = line.split()
# 	word = values[0]
# 	coefs = asarray(values[1:], dtype='float32')
# 	embeddings_index[word] = coefs
# f.close()
# print('Loaded %s word vectors.' % len(embeddings_index))

# Quantas palavras não estão na embeddings pré treinadas
# count = 0
# for word in words:
#   if word not in embeddings_index:
#     count += 1
#     #print(word)
# print(count)

# %%
# Criando a matriz de embeddings [pré-treinadas]
# words_index = dict()
# embedding_matrix = zeros((vocab_size, embedding_size))
# for i, word in enumerate(words, start=1):
# 	embedding_vector = embeddings_index.get(word)
# 	if embedding_vector is not None:
# 		embedding_matrix[i] = embedding_vector
# 		words_index[word] = i

# %%
# bool_series = dvc[data["timespent"]] >= minimum_number_of_records
# data = data[bool_series.values]

# %%
# # Treinando com kfolds
# from keras.backend import clear_session
# clear_session()

# from sklearn.model_selection import KFold

# kf = KFold(n_splits=3)
# foldn = 1
# acc_hist = []
# acc_val_hist = []
# models = []
# for train_index, val_index in kf.split(x_search):
 
#   x_search_new = x_search[train_index]
#   y_search_new = y_search[train_index]

#   x_val = x_search[val_index]
#   y_val = y_search[val_index]

#   print("Fold {} ".format(foldn))
#   foldn += 1

#   model = compile_model(print_summary=False)
#   history = model.fit(x_search_new, y_search_new, epochs=10, batch_size=256, validation_data=(x_val, y_val), verbose=1)

#   models.append(model)
#   pyplot.plot(history.history['mae'])
#   pyplot.plot(history.history['val_mae'])
#   pyplot.title('model mae')
#   pyplot.ylabel('mae')
#   pyplot.xlabel('epoch')
#   pyplot.legend(['train', 'test'], loc='upper left')
#   pyplot.show()

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt    
# from sklearn.metrics import confusion_matrix

# cm = confusion_matrix(y_val, pred_class) 

# ax = plt.subplot()
# sns.heatmap(cm, annot=True, fmt='g', ax=ax);  #annot=True to annotate cells, ftm='g' to disable scientific notation

# # labels, title and ticks
# ax.set_xlabel('Predicted labels')
# ax.set_ylabel('True labels') 
# ax.set_title('Confusion Matrix') 
# ax.xaxis.set_ticklabels(categories) 
# ax.yaxis.set_ticklabels(categories)

# %%
# dvc = data['timespent'].value_counts()
# dvcs = dvc.sort_index()
# dvcs.index.to_numpy().astype(str)

# pyplot.figure(figsize=(10,10))
# pyplot.bar(dvcs.index.to_numpy().astype(str), dvcs.values)
# pyplot.show()

# %%
# Avaliando os modelos
# for i, model in enumerate(models):
#   print("MODELO {}".format(i))
#   print('Treino')
#   loss, metric = model.evaluate(x_search, y_search)
#   print('Loss: {}'.format(loss))
#   print('Metric: {}'.format(metric))
#   print('Test')
#   loss, metric = model.evaluate(x_val, y_val)
#   print('Loss: {}'.format(loss))
#   print('Metric: {}'.format(metric))

# %%
# Old figure of confusion matrix
# fig = pyplot.figure()
# ax = fig.add_subplot(111)
# cax = ax.matshow(cm)
# pyplot.title('Confusion matrix of the classifier')
# fig.colorbar(cax)
# ax.set_xticklabels([''] + labels)
# ax.set_yticklabels([''] + labels)
# pyplot.xlabel('Predicted')
# pyplot.ylabel('True')
# pyplot.show()

# %%
# pyplot.plot(history.history['mae'])
# pyplot.plot(history.history['val_mae'])
# pyplot.title('model accuracy')
# pyplot.ylabel('mae')
# pyplot.xlabel('epoch')
# pyplot.legend(['train', 'test'], loc='upper left')
# pyplot.show()

# %%
# # Primeiro Quartil
# Q1 = pd_data['timespent'].quantile(0.25)
# print("Q1: {}".format(Q1))
# # Segundo Quartil
# Q2 = pd_data['timespent'].quantile(0.50)
# print("Q2: {}".format(Q2))
# # Terceiro Quartil
# Q3 = pd_data['timespent'].quantile(0.75)
# print("Q3: {}".format(Q3))
# # Amplitude Interquartil
# IQR = Q3 - Q1
# print("IQR: {}".format(IQR))
# # Limite Superior
# LI = Q1 - (1.5 * IQR)
# print("LI: {}".format(LI))
# # Limite Inferior
# LS = Q3 + (1.5 * IQR)
# print("LS: {}".format(LS))

# %%
# df_sem_outlier = pd.DataFrame(
#     pd_data[(
#         (pd_data['timespent'] >= LI) 
#         & (pd_data['timespent'] <= LS)
#     )])

# sns.boxplot(df_sem_outlier['timespent'])

# %%
# for pred in predictions:
#     if pred != 1089.0886 and pred != 1089.0885:
#       print(pred)

# %%
# # Visualizando o word embedding
# X = emb_model[emb_model.wv.vocab]
# pca = PCA(n_components=2)
# result = pca.fit_transform(X)
# fig, ax = pyplot.subplots()
# ax.scatter(result[:, 0], result[:, 1])
# xlim1 = -0.200
# xlim2 = -0.125
# ylim1 = -0.02
# ylim2 = 0.02
# limits = False

# words = list(emb_model.wv.vocab)
# for i, word in enumerate(words):
#   x = result[i, 0]
#   y = result[i, 1]
#   if limits:
#     if x >= xlim1 and x <= xlim2 and y >= ylim1 and y <= ylim2: 
# 	    ax.annotate(word, xy=(x, y))
#   else:
#     ax.annotate(word, xy=(x, y))

# if limits:
#   ax.set_xlim(xlim1, xlim2)
#   ax.set_ylim(ylim1, ylim2)opt_lr

# %%
# prepare tokenizer
# t = Tokenizer()
# t.fit_on_texts(summary_list)
# vocab_size = len(t.word_index) + 1
# print(vocab_size)

# %%
# integer encode the documents
# encoded_docs = t.texts_to_sequences(summary_list)
# print(encoded_docs)

# %%
# padded_docs = pad_sequences(encoded_docs, maxlen=max_summary_length, padding='post')
# print(padded_docs)

# %%
# ss = StandardScaler()
# sclWord = ss.fit(emb_model.wv.vectors)
# vectors_normalized = sclWord.transform(vocab_dict.values())

# vectors_list = []
# for word in emb_model.wv.vocab:
#   vectors_list.append(emb_model.wv.get_vector(word))

# print(type(emb_model.wv.vocab))
# embeddings_index = dict()
# for i, word in enumerate(list(emb_model.wv.vocab)[0:10]):
#   print(emb_model.wv.vectors[i])
#   print(vectors_list[i])
	#embeddings_index[word] = vectors_normalized[i]

# %%
# count = 0
# for cara in embedding_matrix:
#   if cara[0] == 0:
#     count+=1
# print(count)
