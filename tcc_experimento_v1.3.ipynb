# %%
# Importando bibliotecas necessárias
import json
import numpy as np
import pandas as pd
import math
import sys
import os
import seaborn as sns
from numpy import zeros, array, asarray
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
from matplotlib import pyplot
from matplotlib.pyplot import figure
from keras import metrics
from keras.models import Sequential
from keras.layers import Bidirectional, LSTM, Dense, Dropout, Activation, SimpleRNN
from keras.layers import Flatten
from keras.layers.embeddings import Embedding

# %%
# Parametros modificados com frequência
debug = True
col_switch = ('summary', 'description')
xcol = col_switch[1]
docs_length = 'mean'
embedding_size = 600
z_score_threshold = 3
z_score_times = 5
lstm = True
dense_layers = False
dropout = True

# %%
# Abrindo dados como ndarray
data = []
path = './drive/MyDrive/ColabNotebooks/data/'
filelist = os.listdir(path)
filelist.sort()
# filelist = ['EVL_lab_clean.json']
repo_num = len(filelist)
print("Numero de repositorios: {}".format(repo_num))
for filename in filelist:
  with open(path + filename, 'r') as file:
    repo = json.load(file)
    data += repo
ndata = pd.DataFrame(data).values
pd_data = pd.DataFrame(data)
if debug:
  print(ndata)
  print(ndata.shape)
# Out:
# Numero de repositorios: 70
# [['14161' 'ABU'
#   list(['contrib-graphic remove body attribute from example.json'])
#   list(["i know it's a core model attribute but it's not actually used in this component so it's a little misleading to list it in example.json"])
#   '1800' 96.0]
#  ['14436' 'ABU' list(['remove readme.pdf'])
#   list(["this pdf is hugely and no longer req'd"]) '120' 97.0]
#  ['14201' 'ABU' list(['unused color variables'])
#   list(['remove from colors.less file or use in theme']) '1800' 97.0]
#  ...
#  ['10102' 'ZONG' list(["andi's work in"]) nan '3589200' nan]
#  ['10010' 'ZONG'
#   list(['create diagrams showing the zong modules and their dependencies'])
#   nan '9600' nan]
#  ['10009' 'ZONG' list(['write guide how to build zong']) nan '11400' nan]]
# (97274, 6)

# %%
# Convertendo o timespent para float
pd_data['timespent'] = pd_data.timespent.astype(float)

# %%
# Removendo linhas com description null
bool_series = pd.notnull(pd_data['description']) 

pd_data = pd_data[bool_series]

# %%
# Removendo linhas com summary null
bool_series = pd.notnull(pd_data['summary']) 

pd_data = pd_data[bool_series]

# %%
# Removendo linhas com timespent null
bool_series = pd.notnull(pd_data['timespent']) 

pd_data = pd_data[bool_series]

# %%
pd_data
# Out:
#           id project  ... timespent  alpha
# 0      14161     ABU  ...    1800.0   96.0
# 1      14436     ABU  ...     120.0   97.0
# 2      14201     ABU  ...    1800.0   97.0
# 3      11902     ABU  ...   93600.0   97.0
# 4      15601     ABU  ...     900.0   98.0
# ...      ...     ...  ...       ...    ...
# 97249  10500   UTILS  ...    3600.0  100.0
# 97250  10400   UTILS  ...    7200.0  100.0
# 97251  10322   UTILS  ...   14400.0  100.0
# 97252  10321   UTILS  ...    8100.0  100.0
# 97253  10001   UTILS  ...    3600.0  100.0
#
# [72348 rows x 6 columns]

# %%
sns.boxplot(pd_data['timespent'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
def my_zscore(x):
  return ((x - x.mean())/x.std())

cara =  my_zscore(pd_data['timespent'])
df_sem_outlier_z = pd.DataFrame(
    pd_data[(abs(cara) < z_score_threshold)])
sns.boxplot(df_sem_outlier_z['timespent'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Aplicando o z score mais vezes para remover mais os outliers
for i in range(z_score_times):
  z_score_threshold = 1
  cara =  my_zscore(df_sem_outlier_z['timespent'])
  df_sem_outlier_z = pd.DataFrame(
      df_sem_outlier_z[(abs(cara) < z_score_threshold)])

sns.boxplot(df_sem_outlier_z['timespent'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df_sem_outlier_z.boxplot('timespent')

# %%
df_sem_outlier_z.hist('timespent')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1678bfdf90>]],
#       dtype=object)

# %%
df_sem_outlier_z
# Out:
#           id project  ... timespent  alpha
# 0      14161     ABU  ...    1800.0   96.0
# 2      14201     ABU  ...    1800.0   97.0
# 7      14251     ABU  ...    1800.0   98.0
# 8      14121     ABU  ...    3600.0   98.0
# 13     15506     ABU  ...    1800.0   99.0
# ...      ...     ...  ...       ...    ...
# 97240  10006    ZONG  ...    1800.0  100.0
# 97245  11500   UTILS  ...    2700.0  100.0
# 97248  10501   UTILS  ...    1890.0  100.0
# 97249  10500   UTILS  ...    3600.0  100.0
# 97253  10001   UTILS  ...    3600.0  100.0
#
# [18185 rows x 6 columns]

# %%
data = df_sem_outlier_z

# %%
data
# Out:
#           id project  ... timespent  alpha
# 0      14161     ABU  ...    1800.0   96.0
# 2      14201     ABU  ...    1800.0   97.0
# 7      14251     ABU  ...    1800.0   98.0
# 8      14121     ABU  ...    3600.0   98.0
# 13     15506     ABU  ...    1800.0   99.0
# ...      ...     ...  ...       ...    ...
# 97240  10006    ZONG  ...    1800.0  100.0
# 97245  11500   UTILS  ...    2700.0  100.0
# 97248  10501   UTILS  ...    1890.0  100.0
# 97249  10500   UTILS  ...    3600.0  100.0
# 97253  10001   UTILS  ...    3600.0  100.0
#
# [18185 rows x 6 columns]

# %%
uniq = data['timespent'].unique()
uniq.sort(axis=0)
print(uniq)
print(len(uniq))
# Out:
# [1260. 1320. 1380. 1440. 1488. 1500. 1560. 1620. 1680. 1692. 1740. 1800.
#  1815. 1830. 1860. 1890. 1920. 1980. 2040. 2052. 2088. 2100. 2160. 2220.
#  2268. 2280. 2340. 2400. 2412. 2448. 2460. 2520. 2580. 2628. 2640. 2700.
#  2715. 2760. 2820. 2880. 2940. 3000. 3012. 3048. 3060. 3120. 3168. 3180.
#  3240. 3276. 3300. 3312. 3360. 3420. 3480. 3540. 3576. 3600. 3615. 3630.
#  3636. 3660. 3672. 3708. 3720. 3780. 3795. 3840.]
# 68

# %%
data['timespent'].describe()
# Out:
# count    18185.000000
# mean      2657.068573
# std        777.283168
# min       1260.000000
# 25%       1800.000000
# 50%       2400.000000
# 75%       3600.000000
# max       3840.000000
# Name: timespent, dtype: float64

# %%
# Categorizando os dados
#data['timespent'] = data.timespent.ge(1200).astype(int)
categories = [0, 1, 2, 3]
data['timespent_cat'], bins = pd.cut(data['timespent'], bins=len(categories), include_lowest=True, labels=categories, retbins=True)

# %%
data['timespent_cat'].hist()

# %%
# Descrevendo os intervalos de cada categoria
for i in range(len(categories)):
  print("Cat {}".format(i))
  print("From {} - To {}".format(bins[i], bins[i+1]))
  bool_series = data['timespent_cat'].eq(i)
  cat = data[bool_series] 
  min = cat['timespent'].min()
  max = cat['timespent'].max()
  print("Min: {} - Max: {}".format(min, max))
  count = cat['timespent'].count()
  print("Count: {}".format(count))
# Out:
# Cat 0
# From 1257.42 - To 1905.0
# Min: 1260.0 - Max: 1890.0
# Count: 6345
# Cat 1
# From 1905.0 - To 2550.0
# Min: 1920.0 - Max: 2520.0
# Count: 3190
# Cat 2
# From 2550.0 - To 3195.0
# Min: 2580.0 - Max: 3180.0
# Count: 2419
# Cat 3
# From 3195.0 - To 3840.0
# Min: 3240.0 - Max: 3840.0
# Count: 6231

# %%
# Obtendo todas as palavras das description para serem treinadas
all_text = []
for description in data['description'].values:
  for des_str in description:
    all_text.append(des_str.split())

for summary in data['summary'].values:
  for sum_str in summary:
    all_text.append(sum_str.split())

if debug:
  print(len(all_text))
  # print(all_text)
# Out:
# 59605

# %%
# Definindo o modelo de word embeddings
emb_model = Word2Vec(all_text, min_count=5, size=embedding_size)
# Resumo do modelo
if debug:
  print(emb_model)
words = list(emb_model.wv.vocab)
if debug:
  print(words)

vocab_size = len(words) + 1
if debug:
  print(vocab_size)
  print(emb_model.wv.vectors)
# Out:
# Word2Vec(vocab=9072, size=600, alpha=0.025)
# ['i', 'know', "it's", 'a', 'core', 'model', 'attribute', 'but', 'not', 'actually', 'used', 'in', 'this', 'component', 'so', 'little', 'misleading', 'to', 'list', 'it', 'remove', 'from', 'file', 'or', 'use', 'theme', 'the', 'watch', 'task', 'that', 'runs', 'if', 'you', 'do', 'grunt', 'dev', 'will', 'for', 'changes', 'config.json', 'then', 'copy', 'into', 'build', 'when', 'is', 'changed', 'saved', 'replicate', 'run', 'make', 'change', 'and', 'save', 'observe', 'command', 'line', 'says', 'src', 'course', 'tasks', 'are', 'go', 'has', 'been', 'updated', 'on', 'page', 'any', 'of', 'options', 'an', 'mcq', 'selected', 'ends', 'up', 'being', 'read', 'out', 'times', 'once', 'before', 'twice', 'after', 'indicated', 'headings', 'each', 'item', 'top', 'other', 'see', 'buttons', 'work', 'button', "doesn't", 'also', 'occurs', 'same', 'behaviour', 'nexus', 'android', 'slider', "can't", 'be', 'user', 'unable', 'select', 'submit', 'even', 'scroll', 'must', 'closed', 'reopened', 'can', 'progress', 'iphone', 'ios', 'using', 'no', 'matter', 'what', 'number', 'chooses', 'selects', 'move', 'input', 'looks', 'like', 'broadcast', 'events', 'source', 'vimeo', 'might', 'well', 'youtube', 'needs', 'testing', 'assume', 'we', 'could', 'probably', 'hack', 'our', 'way', 'around', 'play', 'event', 'by', 'firing', 'clicks', 'video', 'completion', 'unlikely', 'easy', 'though', 'skip', 'plugins', 'with', 'schema', 'error', 'support', 'drop', 'shadow', 'icon', 'effectively', 'invisible', 'attached', 'alt', 'text', 'here', 'your', 'answer', 'both', 'as', 'requires', 'choose', 'images', 'image', 'option', 'description', 'question', 'visually', 'at', 'end', 'links', 'every', 'drawer', 'tabbing', 'whole', 'side', 'necessary', 'confuse', 'thinking', "they've", 'reached', 'contents', 'all', 'resources', 'need', 'identified', 'such', 'right', 'now', 'only', 'name', 'idea', 'indication', 'why', 'there', 'closes', 'feedback', 'popups', 'reader', 'begins', 'reading', 'should', 'return', 'next', 'navigation', 'seems', 'retain', 'position', 'submitted', 'they', 'colour', 'again', 'assessments', 'setup', 'false', 'multiple', 'assessment', 'one', 'just', 'contains', 'content', 'previous', 'render', 'review', 'accuracy', 'quality', 'goes', 'chuck', 'reassign', 'push', 'adapt', 'github', 'wiki', 'have', 'cached', 'take', 'several', 'extra', 'seconds', 'load', 'while', 'waits', 'fire', 'which', "won't", 'due', 'bug', 'does', 'eventually', 'errors', 'failed', 'hear', 'shown', 'console', 'default', 'framework', 'viewed', 'rtl', 'through', 'narrative', 'causes', 'issues', 'forward', 'back', 'arrows', 'first', 'reverts', 'would', 'ltr', 'aria', 'labels', 'moving', 'section', 'title', 'moment', 'hit', 'label', 'exit', 'graphic', 'plp', 'show', 'menu', 'granularity', 'focus', 'returns', 'opened', 'close', 'sequence', 'opens', 'dt', 'tabs', 'instead', 'hotgraphic', 'behind', 'completed', 'shift', 'moves', 'instruction', 'left', 'swipe', 'works', 'round', 'practise', 'view', 'occurred', 'merging', 'following', 'pr', 'weekly', 'documentation', 'chat', 'tries', 'tab', 'past', 'trickle', 'scrolls', 'down', 'screen', 'shows', 'white', 'cursor', 'directly', 'without', 'explanation', 'takes', 'good', 'bit', 'get', 'place', 'done', 'complete', 'preventing', 'progressing', 'mark', 'indented', 'overrun', 'visible', 'area', 'lower', 'sizes', 'indentation', 'appear', 'browsers', 'comparison', 'problem', 'desired', 'appearance', 'chrome', 'always', 'present', 'beginning', 'slide', 'arrow', 'last', 'loop', 'infinitely', 'please', 'add', 'alternative', 'version', 'switched', 'switch', 'off', 'spoor', 'setting', 'leave', 'enabled', 'running', 'connected', 'my', 'expectation', 'disabled', 'attempt', 'made', 'call', 'scorm', 'functions', 'appropriate', 'log', 'explaining', 'tracking', 'therefore', 'json', 'test', 'package', 'replaced', 'grey', 'placeholder', 'audio', 'media', 'included', 'keep', 'size', 'initial', 'download', 'small', 'possible', 'was', 'disable', 'am', 'working', 'downloaded', 'code', ' ...
# 9073
# [[-1.7741790e-01 -1.1967534e-01 -5.1391441e-01 ... -6.5387905e-02
#   -1.3502097e-01  3.6387989e-01]
#  [ 3.4042883e-01  2.3056225e-01 -1.4617771e-01 ... -2.7949694e-01
#   -9.0267368e-02  5.6536424e-01]
#  [ 2.8331348e-01 -3.4235331e-01 -1.6109802e-01 ...  6.4345443e-01
#    1.9192944e-01  8.5353017e-02]
#  ...
#  [-9.3847448e-03  2.9820965e-03 -2.2148625e-03 ... -3.8734127e-02
#    6.3607101e-03  2.2705499e-02]
#  [-3.8331905e-03 -1.3346161e-03 -1.7043147e-02 ... -1.5816763e-02
#    6.2285451e-04  2.3205830e-02]
#  [-1.2455483e-02  3.0166411e-03  2.2988033e-03 ... -2.0397898e-02
#    5.2786432e-03  1.0761646e-02]]

# %%
# Brincando com o modelo
print(emb_model.wv.similarity('java', 'code'))
emb_model.wv.most_similar(positive=['staging'], topn=10)
# Out:
# 0.49823272
# [('firebug', 0.9586324095726013),
#  ('ps', 0.9540396928787231),
#  ('cloud', 0.9524180889129639),
#  ('launcher', 0.9469583034515381),
#  ('rolling', 0.9451048374176025),
#  ('security.json', 0.9450827836990356),
#  ('webrowser', 0.9430044293403625),
#  ('env', 0.9428365230560303),
#  ('apt', 0.9375114440917969),
#  ('thirdparty', 0.936732292175293)]

# %%
# Comparando vetores de palavras
pyplot.figure(figsize=(10,3))
w1 = 'java'
w2 = 'code'
w1v = emb_model.wv.get_vector(w1)
w2v = emb_model.wv.get_vector(w2)
pyplot.plot(w1v, label=w1)
pyplot.plot(w2v, label=w2)
pyplot.legend()
pyplot.show()

# %%
# Obtendo a lista de docs concatenando summary + description
docs = []
for i in range(len(data)):
  summ = data['summary'].values[i]
  desc = data['description'].values[i]
  sentence_agg = ""
  for sum_item in summ:
    sentence_agg += sum_item
    sentence_agg += " "
  for desc_item in desc:
    sentence_agg += desc_item
    sentence_agg += " "
  sentence_agg = sentence_agg.rstrip()
  docs.append(sentence_agg)
for i in range(10):
  print(docs[i])
print(len(docs))
# Out:
# contrib-graphic remove body attribute from example.json i know it's a core model attribute but it's not actually used in this component so it's a little misleading to list it in example.json
# unused color variables remove from colors.less file or use in theme
# grunt task runner dev task does not copy json changes to the build the watch task that runs if you do grunt dev will watch for changes to config.json but then copy config.json into the build when this file is changed saved to replicate run grunt dev make a change to and save the file observe that the command line says file src course config.json changed and that the and copy:coursejson tasks are run go to observe that config.json has not been updated
# mcq option are read out times if selected on this page if any of the options for an mcq is selected it ends up being read out times once before it's selected and twice after indicated that it's been
# narrative component the headings for each component item are stacked on top of each other see buttons and work button doesn't this also occurs in same behaviour on nexus android
# slider button once the slider button is selected it can't be deselected user is then unable to select submit button or even scroll course must be closed and reopened before user can progress this also occurs on iphone ios when using the nexus android the slider can be deselected but no matter what number the user chooses when the user selects submit the slider will move to and input
# play and ended completion events don't work when the source is vimeo looks like mediaelement.js doesn't broadcast events when the source is vimeo might well be same if youtube this needs testing assume we could probably hack our way around the play event by firing it when the user clicks on the video completion event unlikely to be so easy though
# grunt fails when trying to process plugin without schema schema-defaults task needs to skip plugins with no schema error
# slider doesn't support drop shadow so the slider icon is effectively invisible see attached
# submit button alt text incorrect alt text for the mcq submit buttons on this page is select here to submit your answer and it's read out both before and after the submit button has been selected
# 18185

# %%
# Obtendo a lista de docs usando só a descrição
# docs = []
# for desc in data[xcol].values:
#   sentence_agg = ""
#   for sentence in desc:
#     sentence_agg += sentence
#     sentence_agg += " "
#   sentence_agg = sentence_agg.rstrip()
#   docs.append(sentence_agg)
# print(docs[0:10])
# print(len(docs))
# Out:
# ["i know it's a core model attribute but it's not actually used in this component so it's a little misleading to list it in example.json", 'remove from colors.less file or use in theme', 'the watch task that runs if you do grunt dev will watch for changes to config.json but then copy config.json into the build when this file is changed saved to replicate run grunt dev make a change to and save the file observe that the command line says file src course config.json changed and that the and copy:coursejson tasks are run go to observe that config.json has not been updated', "on this page if any of the options for an mcq is selected it ends up being read out times once before it's selected and twice after indicated that it's been", "the headings for each component item are stacked on top of each other see buttons and work button doesn't this also occurs in same behaviour on nexus android", "once the slider button is selected it can't be deselected user is then unable to select submit button or even scroll course must be closed and reopened before user can progress this also occurs on iphone ios when using the nexus android the slider can be deselected but no matter what number the user chooses when the user selects submit the slider will move to and input", "looks like mediaelement.js doesn't broadcast events when the source is vimeo might well be same if youtube this needs testing assume we could probably hack our way around the play event by firing it when the user clicks on the video completion event unlikely to be so easy though", 'schema-defaults task needs to skip plugins with no schema error', "doesn't support drop shadow so the slider icon is effectively invisible see attached", "alt text for the mcq submit buttons on this page is select here to submit your answer and it's read out both before and after the submit button has been selected"]
# 18188

# %%
docs_len = []
for doc in docs:
  docs_len.append(len(doc.split()))
print(docs_len[0:10])
# Out:
# [31, 11, 83, 39, 30, 69, 61, 19, 14, 36]

# %%
df_sem_outlier_z['docs_lens'] = docs_len

# %%
df_sem_outlier_z
# Out:
#           id project  ... timespent_cat docs_lens
# 0      14161     ABU  ...             0        31
# 2      14201     ABU  ...             0        11
# 7      14251     ABU  ...             0        83
# 8      14121     ABU  ...             3        39
# 13     15506     ABU  ...             0        30
# ...      ...     ...  ...           ...       ...
# 97240  10006    ZONG  ...             0        47
# 97245  11500   UTILS  ...             2        31
# 97248  10501   UTILS  ...             0        19
# 97249  10500   UTILS  ...             3        11
# 97253  10001   UTILS  ...             3        19
#
# [18185 rows x 8 columns]

# %%
df_sem_outlier_z.boxplot('docs_lens')

# %%
# Tamanho máximo dos docs
max_length_des = 0
if docs_length == 'mean':
  max_length_des = int(df_sem_outlier_z['docs_lens'].mean())
  if debug:
    print(max_length_des)
elif docs_length == 'min':
  max_length_des = int(df_sem_outlier_z['docs_lens'].min())
  if debug:
    print(max_length_des)
else:
  for desc in data[xcol].values:
    sentence_size = 0
    for sentence in desc:
      sentence_size += len(sentence.split())
    if sentence_size > max_length_des:
      max_length_des = sentence_size
  if debug:
    print(max_length_des)
# Out:
# 54

# %%
padded_docs = zeros((len(docs), max_length_des))
for i, doc in enumerate(docs):
  doc_word_list = doc.split()
  doc_encoded = zeros((max_length_des))
  for j, word in enumerate(doc_word_list):
    if j < max_length_des:
      if word in emb_model.wv.vocab:
        doc_encoded[j] = emb_model.wv.vocab[word].index + 1
  padded_docs[i] = doc_encoded
padded_docs
# Out:
# array([[0.000e+00, 9.000e+01, 1.607e+03, ..., 0.000e+00, 0.000e+00,
#         0.000e+00],
#        [1.599e+03, 7.520e+02, 1.224e+03, ..., 0.000e+00, 0.000e+00,
#         0.000e+00],
#        [5.947e+03, 1.760e+02, 1.034e+03, ..., 6.000e+00, 2.650e+02,
#         1.000e+00],
#        ...,
#        [9.300e+01, 8.300e+01, 3.660e+02, ..., 0.000e+00, 0.000e+00,
#         0.000e+00],
#        [6.240e+02, 8.800e+01, 6.810e+02, ..., 0.000e+00, 0.000e+00,
#         0.000e+00],
#        [6.600e+01, 1.770e+02, 2.455e+03, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]])

# %%
print(padded_docs.shape)
# Out:
# (18185, 54)

# %%
# Criando uma matriz de pesos para o vocabulário
embedding_matrix = zeros((vocab_size, embedding_size))
for i, word in enumerate(words):
  embedding_vector = emb_model.wv.get_vector(word)
  if embedding_vector is not None:
    embedding_matrix[i+1] = asarray(embedding_vector, dtype='float32')
  else:
    print("Vish")
if debug:
  print(len(embedding_matrix))
  print(embedding_matrix)
# Out:
# 9073
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [-4.76778805e-01  6.96372390e-01 -7.13559330e-01 ... -1.06386554e+00
#   -5.70404649e-01  5.23584604e-01]
#  [-3.37318391e-01 -2.03407973e-01 -6.23943806e-01 ... -3.67704540e-01
#   -3.01110178e-01  3.65570337e-01]
#  ...
#  [-7.40346964e-03  7.87146669e-03 -1.94721632e-02 ... -2.20615081e-02
#    7.87878409e-03  3.01875472e-02]
#  [-1.24554830e-02  3.01664113e-03  2.29880330e-03 ... -2.03978978e-02
#    5.27864322e-03  1.07616456e-02]
#  [-7.59572582e-03 -1.98305806e-05 -1.15098478e-03 ... -1.30791608e-02
#    4.02754918e-03  1.43005513e-02]]

# %%
# Particionando conjunto de teste e treino para avaliação
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(padded_docs, data['timespent_cat'].values.codes, test_size=0.1, random_state=88)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (16366, 54)
# (1819, 54)
# (16366,)
# (1819,)

# %%
ytp = pd.Series(y_train)
ytp.hist()
len(y_train)
# Out:
# 16366

# %%
ytt = pd.Series(y_test)
ytt.hist()
len(y_test)
# Out:
# 1819

# %%
# Definindo o modelo
model = Sequential()
e = Embedding(vocab_size, embedding_size, weights=[embedding_matrix], input_length=max_length_des, trainable=False)
model.add(e)
if lstm:
  model.add(Bidirectional(LSTM(max_length_des)))
  if dropout:
    model.add(Dropout(0.3))
else:
  model.add(Flatten())
  if dropout:
    model.add(Dropout(0.1))
if dense_layers:
  model.add(Dense(200, activation='relu'))
  if dropout:  
    model.add(Dropout(0.1))
  model.add(Dense(16, activation='relu'))
  if dropout:
    model.add(Dropout(0.1))
  # model.add(Dense(16, activation='relu'))
  # if dropout:
  #   model.add(Dropout(0.2))
  # model.add(Dense(4, activation='relu'))
  # if dropout:
  #   model.add(Dropout(0.1))
#model.add(Dense(1, activation='sigmoid'))
model.add(Dense(len(categories), activation='softmax'))
# Compilando o modelo
#opt = SGD(lr=0.01, momentum=0.9)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mae'])
# Resumo do modelo
print(model.input_shape)
print(model.summary())
# Out:
# (None, 54)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 54, 600)           5443800
#
#  bidirectional (Bidirectiona  (None, 108)              282960
#  l)
#
#  dropout (Dropout)           (None, 108)               0
#
#  dense (Dense)               (None, 4)                 436
#
# =================================================================
# Total params: 5,727,196
# Trainable params: 283,396
# Non-trainable params: 5,443,800
# _________________________________________________________________
# None

# %%
from keras.backend import clear_session
clear_session()
# Treinando o modelo

from sklearn.model_selection import KFold

kf = KFold(n_splits=10)
foldn = 1
acc_hist = []
acc_val_hist = []
for train_index, val_index in kf.split(x_train):
  x_train_new = x_train[train_index]
  y_train_new = y_train[train_index]

  x_val = x_train[val_index]
  y_val = y_train[val_index]

  print("Fold {} train".format(foldn))
  foldn += 1

  history = model.fit(x_train, y_train, epochs=10, batch_size=64, validation_data=(x_val, y_val), verbose=1)
  
  acc_hist.extend(history.history['accuracy'])
  acc_val_hist.extend(history.history['val_accuracy'])

pyplot.plot(acc_hist)
pyplot.plot(acc_val_hist)
pyplot.title('model accuracy')
pyplot.ylabel('accuracy')
pyplot.xlabel('epoch')
pyplot.legend(['train', 'test'], loc='upper left')
pyplot.show()
# Out:
# Fold 1 train
# Epoch 1/10
# 256/256 [==============================] - 54s 192ms/step - loss: 1.3098 - accuracy: 0.3595 - val_loss: 1.2981 - val_accuracy: 0.3897
# Epoch 2/10
# 256/256 [==============================] - 45s 176ms/step - loss: 1.2922 - accuracy: 0.3766 - val_loss: 1.2843 - val_accuracy: 0.3818
# Epoch 3/10
# 256/256 [==============================] - 44s 170ms/step - loss: 1.2819 - accuracy: 0.3805 - val_loss: 1.2745 - val_accuracy: 0.4007
# Epoch 4/10
# 256/256 [==============================] - 43s 170ms/step - loss: 1.2698 - accuracy: 0.3919 - val_loss: 1.2709 - val_accuracy: 0.3897
# Epoch 5/10
# 256/256 [==============================] - 43s 170ms/step - loss: 1.2611 - accuracy: 0.4021 - val_loss: 1.2552 - val_accuracy: 0.4154
# Epoch 6/10
# 256/256 [==============================] - 44s 170ms/step - loss: 1.2501 - accuracy: 0.4061 - val_loss: 1.2468 - val_accuracy: 0.4221
# Epoch 7/10
# 256/256 [==============================] - 43s 169ms/step - loss: 1.2392 - accuracy: 0.4130 - val_loss: 1.2343 - val_accuracy: 0.4099
# Epoch 8/10
# 256/256 [==============================] - 44s 170ms/step - loss: 1.2258 - accuracy: 0.4206 - val_loss: 1.2153 - val_accuracy: 0.4356
# Epoch 9/10
# 256/256 [==============================] - 45s 177ms/step - loss: 1.2106 - accuracy: 0.4300 - val_loss: 1.1995 - val_accuracy: 0.4484
# Epoch 10/10
# 256/256 [==============================] - 43s 170ms/step - loss: 1.1979 - accuracy: 0.4423 - val_loss: 1.1826 - val_accuracy: 0.4673
# Fold 2 train
# Epoch 1/10
# 256/256 [==============================] - 43s 169ms/step - loss: 1.1827 - accuracy: 0.4560 - val_loss: 1.1589 - val_accuracy: 0.4704
# Epoch 2/10
# 256/256 [==============================] - 43s 170ms/step - loss: 1.1640 - accuracy: 0.4631 - val_loss: 1.1080 - val_accuracy: 0.5223
# Epoch 3/10
# 256/256 [==============================] - 43s 170ms/step - loss: 1.1485 - accuracy: 0.4753 - val_loss: 1.1096 - val_accuracy: 0.5199
# Epoch 4/10
# 256/256 [==============================] - 43s 169ms/step - loss: 1.1267 - accuracy: 0.4888 - val_loss: 1.0725 - val_accuracy: 0.5290
# Epoch 5/10
# 256/256 [==============================] - 44s 170ms/step - loss: 1.1077 - accuracy: 0.4956 - val_loss: 1.0402 - val_accuracy: 0.5486
# Epoch 6/10
# 256/256 [==============================] - 44s 170ms/step - loss: 1.0784 - accuracy: 0.5174 - val_loss: 0.9983 - val_accuracy: 0.5993
# Epoch 7/10
# 256/256 [==============================] - 44s 170ms/step - loss: 1.0577 - accuracy: 0.5328 - val_loss: 0.9695 - val_accuracy: 0.6115
# Epoch 8/10
# 256/256 [==============================] - 44s 171ms/step - loss: 1.0324 - accuracy: 0.5459 - val_loss: 0.9628 - val_accuracy: 0.6255
# Epoch 9/10
# 256/256 [==============================] - 44s 171ms/step - loss: 1.0080 - accuracy: 0.5598 - val_loss: 0.9396 - val_accuracy: 0.6103
# Epoch 10/10
# 256/256 [==============================] - 44s 170ms/step - loss: 0.9834 - accuracy: 0.5723 - val_loss: 0.8772 - val_accuracy: 0.6463
# Fold 3 train
# Epoch 1/10
# 256/256 [==============================] - 44s 170ms/step - loss: 0.9605 - accuracy: 0.5850 - val_loss: 0.8721 - val_accuracy: 0.6530
# Epoch 2/10
# 256/256 [==============================] - 44s 170ms/step - loss: 0.9278 - accuracy: 0.6055 - val_loss: 0.8446 - val_accuracy: 0.6695
# Epoch 3/10
# 256/256 [==============================] - 47s 184ms/step - loss: 0.9063 - accuracy: 0.6129 - val_loss: 0.8096 - val_accuracy: 0.6756
# Epoch 4/10
# 256/256 [==============================] - 48s 188ms/step - loss: 0.8762 - accuracy: 0.6255 - val_loss: 0.7903 - val_accuracy: 0.6909
# Epoch 5/10
# 256/256 [==============================] - 45s 175ms/step - loss: 0.8565 - accuracy: 0.6385 - val_loss: 0.7604 - val_accuracy: 0.6976
# Epoch 6/10
# 256/256 [==============================] - 45s 176ms/step - loss: 0.8342 - accuracy: 0.6498 - val_loss: 0.7253 - val_accuracy: 0.7123
# Epoch 7/10
# 256/256 [==============================] - 46s 179ms/step - loss: 0.8042 - accuracy: 0.6678 - val_loss: 0.6936 - val_accuracy: 0.7330
# Epoch 8/10
# 256/256 [==============================] - 45s 175ms/step - loss: 0.7873 - accuracy: 0.6697 - val_loss: 0.6829 - val_accuracy: 0.7343
# Epoch 9/10
# 256/256 [==============================] - 45s 175ms/step - loss: 0.7585 - accuracy: 0.6836 - val_loss: 0.6312 - val_accuracy: 0.7526
# Epoch 10/10
# 256/256 [==============================] - 45s 176ms/step - loss: 0.7368 - accuracy: 0.6966 - val_loss: 0.5987 - val_accuracy: 0.7825
# Fold 4 train
# Epoch 1/10
# 256/256 [==============================] - 44s 172ms/step - loss: 0.7153 - accuracy: 0.7032 - val_loss: 0.6095 - val_accuracy: 0.7581
# Epoch 2/10
# 256/256 [==============================] - 44s 173ms/step - loss: 0.6908 - accuracy: 0.7126 - val_loss: 0.5929 - val_accuracy: 0.7789
# Epoch 3/10
# 256/256 [==============================] - 44s 173ms/step - loss: 0.6761 - accuracy: 0.7257 - val_loss: 0.5694 - val_accuracy: 0.7789
# Epoch 4/10
# 256/256 [==============================] - 46s 178ms/step - loss: 0.6637 - accuracy: 0.7293 - val_loss: 0.5302 - val_accuracy: 0.7947
# Epoch 5/10
# 256/256 [==============================] - 49s 193ms/step - loss: 0.6422 - accuracy: 0.7390 - val_loss: 0.5294 - val_accuracy: 0.8057
# Epoch 6/10
# 256/256 [==============================] - 48s 188ms/step - loss: 0.6197 - accuracy: 0.7464 - val_loss: 0.4973 - val_accuracy: 0.8345
# Epoch 7/10
# 256/256 [==============================] - 48s 187ms/step - loss: 0.5992 - accuracy: 0.7582 - val_loss: 0.4735 - val_accuracy: 0.8412
# Epoch 8/10
# 256/256 [==============================] - 49s 190ms/step - loss: 0.5895 - accuracy: 0.7665 - val_loss: 0.4765 - val_accuracy: 0.8277
# Epoch 9/10
# 256/256 [==============================] - 49s 189ms/step - loss: 0.5698 - accuracy: 0.7722 - val_loss: 0.4163 - val_accuracy: 0.8668
# Epoch 10/10
# 256/256 [==============================] - 47s 185ms/step - loss: 0.5611 - accuracy: 0.7727 - val_loss: 0.4463 - val_accuracy: 0.8387
# Fold 5 train
# Epoch 1/10
# 256/256 [==============================] - 44s 172ms/step - loss: 0.5533 - accuracy: 0.7775 - val_loss: 0.3907 - val_accuracy: 0.8644
# Epoch 2/10
# 256/256 [==============================] - 44s 171ms/step - loss: 0.5318 - accuracy: 0.7858 - val_loss: 0.3637 - val_accuracy: 0.8705
# Epoch 3/10
# 256/256 [==============================] - 44s 172ms/step - loss: 0.5251 - accuracy: 0.7894 - val_loss: 0.3382 - val_accuracy: 0.8864
# Epoch 4/10
# 256/256 [==============================] - 44s 171ms/step - loss: 0.5099 - accuracy: 0.7972 - val_loss: 0.3193 - val_accuracy: 0.8986
# Epoch 5/10
# 256/256 [==============================] - 44s 170ms/step - loss: 0.4995 - accuracy: 0.8020 - val_loss: 0.3389 - val_accuracy: 0.8870
# Epoch 6/10
# 256/256 [==============================] - 44s 171ms/step - loss: 0.5015 - accuracy: 0.8020 - val_loss: 0.3134 - val_accuracy: 0.8980
# Epoch 7/10
# 256/256 [==============================] - 44s 171ms/step - loss: 0.4762 - accuracy: 0.8129 - val_loss: 0.3158 - val_accuracy: 0.8986
# Epoch 8/10
# 256/256 [==============================] - 44s 171ms/step - loss: 0.4663 - accuracy: 0.8168 - val_loss: 0.3036 - val_accuracy: 0.9053
# Epoch 9/10
# 256/256 [==============================] - 44s 171ms/step - loss: 0.4501 - accuracy: 0.8265 - val_loss: 0.3222 - val_accuracy: 0.8858
# Epoch 10/10
# 256/256 [==============================] - 44s 171ms/step - loss: 0.4476 - accuracy: 0.8251 - val_loss: 0.2663 - val_accuracy: 0.9224
# Fold 6 train
# Epoch 1/10
# 256/256 [==============================] - 44s 171ms/step - loss: 0.4416 - accuracy: 0.8265 - val_loss: 0.3086 - val_accuracy: 0.8907
# Epoch 2/10
# 256/256 [==============================] - 44s 172ms/step - loss: 0.4410 - accuracy: 0.8247 - val_loss: 0.2801 - val_accuracy: 0.9163
# Epoch 3/10
# 256/256 [==============================] - 44s 172ms/step - loss: 0.4196 - accuracy: 0.8361 - val_loss: 0.2767 - val_accuracy: 0.9108
# Epoch 4/10
# 256/256 [==============================] - 44s 171ms/step - loss: 0.4238 - accuracy: 0.8325 - val_loss: 0.3118 - val_accuracy: 0.8955
# Epoch 5/10
# 256/256 [==============================] - 44s 171ms/step - loss: 0.4228 - accuracy: 0.8364 - val_loss: 0.2973 - val_accuracy: 0.8980
# Epoch 6/10
# 256/256 [==============================] - 44s 171ms/step - loss: 0.4168 - accuracy: 0.8345 - val_loss: 0.2711 - val_accuracy: 0.9151
# Epoch 7/10
# 256/256 [==============================] - 44s 172ms/step - loss: 0.4003 - accuracy: 0.8439 - val_loss: 0.2770 - val_accuracy: 0.9145
# Epoch 8/10
# 256/256 [==============================] - 44s 171ms/step - loss: 0.4013 - accuracy: 0.8502 - val_loss: 0.2765 - val_accuracy: 0.9023
# Epoch 9/10
# 256/256 [==============================] - 44s 173ms/step - loss: 0.3803 - accuracy: 0.8515 - val_loss: 0.2680 - val_accuracy: 0.9102
# Epoch 10/10
# 256/256 [==============================] - 44s 172ms/step - loss: 0.3905 - accuracy: 0.8489 - val_loss: 0.2463 - val_accuracy: 0.9188
# Fold 7 train
# Epoch 1/10
# 256/256 [==============================] - 45s 177ms/step - loss: 0.3719 - accuracy: 0.8560 - val_loss: 0.2412 - val_accuracy: 0.9199
# Epoch 2/10
# 256/256 [==============================] - 54s 213ms/step - loss: 0.3588 - accuracy: 0.8618 - val_loss: 0.2198 - val_accuracy: 0.9254
# Epoch 3/10
# 256/256 [==============================] - 55s 217ms/step - loss: 0.3533 - accuracy: 0.8652 - val_loss: 0.2338 - val_accuracy: 0.9205
# Epoch 4/10
# 256/256 [==============================] - 54s 210ms/step - loss: 0.3576 - accuracy: 0.8648 - val_loss: 0.2440 - val_accuracy: 0.9175
# Epoch 5/10
# 256/256 [==============================] - 44s 173ms/step - loss: 0.3508 - accuracy: 0.8659 - val_loss: 0.2141 - val_accuracy: 0.9364
# Epoch 6/10
# 256/256 [==============================] - 44s 172ms/step - loss: 0.3392 - accuracy: 0.8684 - val_loss: 0.2542 - val_accuracy: 0.9101
# Epoch 7/10
# 256/256 [==============================] - 44s 171ms/step - loss: 0.3431 - accuracy: 0.8684 - val_loss: 0.1925 - val_accuracy: 0.9340
# Epoch 8/10
# 256/256 [==============================] - 44s 171ms/step - loss: 0.3401 - accuracy: 0.8688 - val_loss: 0.2306 - val_accuracy: 0.9267
# Epoch 9/10
# 256/256 [==============================] - 44s 172ms/step - loss: 0.3436 - accuracy: 0.8689 - val_loss: 0.2107 - val_accuracy: 0.9346
# Epoch 10/10
# 256/256 [==============================] - 44s 172ms/step - loss: 0.3254 - accuracy: 0.8770 - val_loss: 0.1937 - val_accuracy: 0.9346
# Fold 8 train
# Epoch 1/10
# 256/256 [==============================] - 44s 172ms/step - loss: 0.3466 - accuracy: 0.8662 - val_loss: 0.2059 - val_accuracy: 0.9401
# Epoch 2/10
# 256/256 [==============================] - 44s 173ms/step - loss: 0.3314 - accuracy: 0.8733 - val_loss: 0.1827 - val_accuracy: 0.9407
# Epoch 3/10
# 256/256 [==============================] - 44s 172ms/step - loss: 0.2989 - accuracy: 0.8850 - val_loss: 0.1790 - val_accuracy: 0.9450
# Epoch 4/10
# 256/256 [==============================] - 44s 172ms/step - loss: 0.3176 - accuracy: 0.8822 - val_loss: 0.2025 - val_accuracy: 0.9389
# Epoch 5/10
# 256/256 [==============================] - 44s 174ms/step - loss: 0.3147 - accuracy: 0.8801 - val_loss: 0.1593 - val_accuracy: 0.9542
# Epoch 6/10
# 256/256 [==============================] - 45s 174ms/step - loss: 0.2875 - accuracy: 0.8878 - val_loss: 0.2143 - val_accuracy: 0.9315
# Epoch 7/10
# 256/256 [==============================] - 45s 176ms/step - loss: 0.3061 - accuracy: 0.8831 - val_loss: 0.1860 - val_accuracy: 0.9413
# Epoch 8/10
# 256/256 [==============================] - 46s 179ms/step - loss: 0.3128 - accuracy: 0.8826 - val_loss: 0.1759 - val_accuracy: 0.9505
# Epoch 9/10
# 256/256 [==============================] - 45s 175ms/step - loss: 0.2928 - accuracy: 0.8926 - val_loss: 0.1757 - val_accuracy: 0.9487
# Epoch 10/10
# 256/256 [==============================] - 45s 175ms/step - loss: 0.2963 - accuracy: 0.8868 - val_loss: 0.1828 - val_accuracy: 0.9474
# Fold 9 train
# Epoch 1/10
# 256/256 [==============================] - 45s 176ms/step - loss: 0.3078 - accuracy: 0.8829 - val_loss: 0.2196 - val_accuracy: 0.9267
# Epoch 2/10
# 256/256 [==============================] - 45s 175ms/step - loss: 0.3328 - accuracy: 0.8735 - val_loss: 0.1532 - val_accuracy: 0.9603
# Epoch 3/10
# 256/256 [==============================] - 45s 175ms/step - loss: 0.2735 - accuracy: 0.8983 - val_loss: 0.1445 - val_accuracy: 0.9566
# Epoch 4/10
# 256/256 [==============================] - 44s 171ms/step - loss: 0.2657 - accuracy: 0.8984 - val_loss: 0.1341 - val_accuracy: 0.9664
# Epoch 5/10
# 256/256 [==============================] - 44s 172ms/step - loss: 0.2761 - accuracy: 0.8952 - val_loss: 0.1609 - val_accuracy: 0.9554
# Epoch 6/10
# 256/256 [==============================] - 44s 172ms/step - loss: 0.3008 - accuracy: 0.8875 - val_loss: 0.1456 - val_accuracy: 0.9603
# Epoch 7/10
# 256/256 [==============================] - 44s 171ms/step - loss: 0.2687 - accuracy: 0.8993 - val_loss: 0.1297 - val_accuracy: 0.9682
# Epoch 8/10
# 256/256 [==============================] - 44s 172ms/step - loss: 0.2704 - accuracy: 0.8998 - val_loss: 0.1337 - val_accuracy: 0.9633
# Epoch 9/10
# 256/256 [==============================] - 44s 171ms/step - loss: 0.2592 - accuracy: 0.9062 - val_loss: 0.1243 - val_accuracy: 0.9664
# Epoch 10/10
# 256/256 [==============================] - 44s 171ms/step - loss: 0.2677 - accuracy: 0.8983 - val_loss: 0.1688 - val_accuracy: 0.9517
# Fold 10 train
# Epoch 1/10
# 256/256 [==============================] - 44s 171ms/step - loss: 0.2841 - accuracy: 0.8930 - val_loss: 0.1531 - val_accuracy: 0.9542
# Epoch 2/10
# 256/256 [==============================] - 44s 171ms/step - loss: 0.2821 - accuracy: 0.8945 - val_loss: 0.1706 - val_accuracy: 0.9444
# Epoch 3/10
# 256/256 [==============================] - 44s 173ms/step - loss: 0.3077 - accuracy: 0.8821 - val_loss: 0.1465 - val_accuracy: 0.9621
# Epoch 4/10
# 256/256 [==============================] - 45s 177ms/step - loss: 0.2617 - accuracy: 0.9024 - val_loss: 0.1324 - val_accuracy: 0.9658
# Epoch 5/10
# 256/256 [==============================] - 46s 178ms/step - loss: 0.2500 - accuracy: 0.9057 - val_loss: 0.1330 - val_accuracy: 0.9584
# Epoch 6/10
# 256/256 [==============================] - 45s 177ms/step - loss: 0.2380 - accuracy: 0.9109 - val_loss: 0.1145 - val_accuracy: 0.9719
# Epoch 7/10
# 256/256 [==============================] - 46s 178ms/step - loss: 0.2552 - accuracy: 0.9069 - val_loss: 0.1221 - val_accuracy: 0.9645
# Epoch 8/10
# 256/256 [==============================] - 46s 178ms/step - loss: 0.2422 - accuracy: 0.9091 - val_loss: 0.1291 - val_accuracy: 0.9627
# Epoch 9/10
# 256/256 [==============================] - 46s 178ms/step - loss: 0.2604 - accuracy: 0.9024 - val_loss: 0.1117 - val_accuracy: 0.9694
# Epoch 10/10
# 256/256 [==============================] - 46s 181ms/step - loss: 0.2605 - accuracy: 0.9028 - val_loss: 0.1359 - val_accuracy: 0.9566

# %%
# Avaliando o modelo
print('Treino')
loss, metric = model.evaluate(x_train, y_train)
print('Loss: {}'.format(loss))
print('Metric: {}'.format(metric))
print('Test')
loss, metric = model.evaluate(x_test, y_test)
print('Loss: {}'.format(loss))
print('Metric: {}'.format(metric))
# Out:
# Treino
# 512/512 [==============================] - 21s 40ms/step - loss: 0.1377 - accuracy: 0.9585
# Loss: 0.1377297043800354
# Metric: 0.9585115313529968
# Test
# 57/57 [==============================] - 2s 42ms/step - loss: 3.5972 - accuracy: 0.3474
# Loss: 3.5971803665161133
# Metric: 0.3474436402320862

# %%
# Fazendo e avaliando previsões
predictions = model.predict(x_test)
print(predictions[0])
pred_class = []
for pred in predictions:
  pred_class.append(np.argmax(pred))
# Out:
# [1.9196239e-04 4.8982048e-01 5.0996262e-01 2.4953435e-05]

# %%
pred_to_plot = pred_class
psize = 100
pyplot.figure(figsize=(20,3))
pyplot.plot(pred_to_plot[0:psize], label='predicted')
pyplot.plot(y_test[0:psize], label='real')
pyplot.legend()
pyplot.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt    
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, pred_class) 

ax = plt.subplot()
sns.heatmap(cm, annot=True, fmt='g', ax=ax);  #annot=True to annotate cells, ftm='g' to disable scientific notation

# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels') 
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(categories) 
ax.yaxis.set_ticklabels(categories)
# Out:
# [Text(0, 0.5, '0'), Text(0, 1.5, '1'), Text(0, 2.5, '2'), Text(0, 3.5, '3')]

# %%
# # Calculando mmre and mae para validação
# from sklearn.metrics import mean_absolute_error

# def mre(actual, pred):
#   actual += 1
#   pred += 1
#   mre = (abs(actual - pred)) / actual
#   return mre

# def mmre(y, pred):
#   sum = 0.0
#   for i, actual in enumerate(y):
#     sum += mre(actual, pred[i])
#   mmre = (sum / (len(y))) 
#   return mmre

# print("MMRE: {}".format(mmre(y_test, pred_class)))
# print("MAE: {}".format(mean_absolute_error(y_test, pred_class)))

# %%
# Old figure of confusion matrix
# fig = pyplot.figure()
# ax = fig.add_subplot(111)
# cax = ax.matshow(cm)
# pyplot.title('Confusion matrix of the classifier')
# fig.colorbar(cax)
# ax.set_xticklabels([''] + labels)
# ax.set_yticklabels([''] + labels)
# pyplot.xlabel('Predicted')
# pyplot.ylabel('True')
# pyplot.show()

# %%
# pyplot.plot(history.history['mae'])
# pyplot.plot(history.history['val_mae'])
# pyplot.title('model accuracy')
# pyplot.ylabel('mae')
# pyplot.xlabel('epoch')
# pyplot.legend(['train', 'test'], loc='upper left')
# pyplot.show()

# %%
# # Primeiro Quartil
# Q1 = pd_data['timespent'].quantile(0.25)
# print("Q1: {}".format(Q1))
# # Segundo Quartil
# Q2 = pd_data['timespent'].quantile(0.50)
# print("Q2: {}".format(Q2))
# # Terceiro Quartil
# Q3 = pd_data['timespent'].quantile(0.75)
# print("Q3: {}".format(Q3))
# # Amplitude Interquartil
# IQR = Q3 - Q1
# print("IQR: {}".format(IQR))
# # Limite Superior
# LI = Q1 - (1.5 * IQR)
# print("LI: {}".format(LI))
# # Limite Inferior
# LS = Q3 + (1.5 * IQR)
# print("LS: {}".format(LS))

# %%
# df_sem_outlier = pd.DataFrame(
#     pd_data[(
#         (pd_data['timespent'] >= LI) 
#         & (pd_data['timespent'] <= LS)
#     )])

# sns.boxplot(df_sem_outlier['timespent'])

# %%
# for pred in predictions:
#     if pred != 1089.0886 and pred != 1089.0885:
#       print(pred)

# %%
# # Visualizando o word embedding
# X = emb_model[emb_model.wv.vocab]
# pca = PCA(n_components=2)
# result = pca.fit_transform(X)
# fig, ax = pyplot.subplots()
# ax.scatter(result[:, 0], result[:, 1])
# xlim1 = -0.200
# xlim2 = -0.125
# ylim1 = -0.02
# ylim2 = 0.02
# limits = False

# words = list(emb_model.wv.vocab)
# for i, word in enumerate(words):
#   x = result[i, 0]
#   y = result[i, 1]
#   if limits:
#     if x >= xlim1 and x <= xlim2 and y >= ylim1 and y <= ylim2: 
# 	    ax.annotate(word, xy=(x, y))
#   else:
#     ax.annotate(word, xy=(x, y))

# if limits:
#   ax.set_xlim(xlim1, xlim2)
#   ax.set_ylim(ylim1, ylim2)

# %%
# prepare tokenizer
# t = Tokenizer()
# t.fit_on_texts(summary_list)
# vocab_size = len(t.word_index) + 1
# print(vocab_size)

# %%
# integer encode the documents
# encoded_docs = t.texts_to_sequences(summary_list)
# print(encoded_docs)

# %%
# padded_docs = pad_sequences(encoded_docs, maxlen=max_summary_length, padding='post')
# print(padded_docs)

# %%
# ss = StandardScaler()
# sclWord = ss.fit(emb_model.wv.vectors)
# vectors_normalized = sclWord.transform(vocab_dict.values())

# vectors_list = []
# for word in emb_model.wv.vocab:
#   vectors_list.append(emb_model.wv.get_vector(word))

# print(type(emb_model.wv.vocab))
# embeddings_index = dict()
# for i, word in enumerate(list(emb_model.wv.vocab)[0:10]):
#   print(emb_model.wv.vectors[i])
#   print(vectors_list[i])
	#embeddings_index[word] = vectors_normalized[i]

# %%
# count = 0
# for cara in embedding_matrix:
#   if cara[0] == 0:
#     count+=1
# print(count)
