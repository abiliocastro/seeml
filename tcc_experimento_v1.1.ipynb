# %%
# Importando bibliotecas necessárias
import json
import numpy as np
import pandas as pd
import math
import sys
import os
import seaborn as sns
from numpy import zeros, array, asarray
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
from matplotlib import pyplot
from matplotlib.pyplot import figure
from keras import metrics
from keras.models import Sequential
from keras.layers import Bidirectional, LSTM, Dense, Dropout, Activation, SimpleRNN
from keras.layers import Flatten
from keras.layers.embeddings import Embedding

# %%
# Parametros modificados com frequência
debug = True
col_switch = ('summary', 'description')
xcol = col_switch[1]
docs_length = 'mean'
embedding_size = 200
z_score_threshold = 3
z_score_times = 5
lstm = True
dense_layers = True

# %%
# Abrindo dados como ndarray
data = []
path = './drive/MyDrive/ColabNotebooks/data/'
filelist = os.listdir(path)
filelist.sort()
# filelist = ['EVL_lab_clean.json']
repo_num = len(filelist)
print("Numero de repositorios: {}".format(repo_num))
for filename in filelist:
  with open(path + filename, 'r') as file:
    repo = json.load(file)
    data += repo
ndata = pd.DataFrame(data).values
pd_data = pd.DataFrame(data)
if debug:
  print(ndata)
  print(ndata.shape)
# Out:
# Numero de repositorios: 70
# [['14161' 'ABU'
#   list(['contrib-graphic remove body attribute from example.json'])
#   list(["i know it's a core model attribute but it's not actually used in this component so it's a little misleading to list it in example.json"])
#   '1800' 96.0]
#  ['14436' 'ABU' list(['remove readme.pdf'])
#   list(["this pdf is hugely and no longer req'd"]) '120' 97.0]
#  ['14201' 'ABU' list(['unused color variables'])
#   list(['remove from colors.less file or use in theme']) '1800' 97.0]
#  ...
#  ['10102' 'ZONG' list(["andi's work in"]) nan '3589200' nan]
#  ['10010' 'ZONG'
#   list(['create diagrams showing the zong modules and their dependencies'])
#   nan '9600' nan]
#  ['10009' 'ZONG' list(['write guide how to build zong']) nan '11400' nan]]
# (97274, 6)

# %%
# Convertendo o timespent para float
pd_data['timespent'] = pd_data.timespent.astype(float)

# %%
# Removendo linhas com description null
bool_series = pd.notnull(pd_data[xcol]) 

pd_data = pd_data[bool_series]

# %%
# Removendo linhas com timespent null
bool_series = pd.notnull(pd_data['timespent']) 

pd_data = pd_data[bool_series]

# %%
pd_data
# Out:
#           id project  ... timespent  alpha
# 0      14161     ABU  ...    1800.0   96.0
# 1      14436     ABU  ...     120.0   97.0
# 2      14201     ABU  ...    1800.0   97.0
# 3      11902     ABU  ...   93600.0   97.0
# 4      15601     ABU  ...     900.0   98.0
# ...      ...     ...  ...       ...    ...
# 97249  10500   UTILS  ...    3600.0  100.0
# 97250  10400   UTILS  ...    7200.0  100.0
# 97251  10322   UTILS  ...   14400.0  100.0
# 97252  10321   UTILS  ...    8100.0  100.0
# 97253  10001   UTILS  ...    3600.0  100.0
#
# [72377 rows x 6 columns]

# %%
sns.boxplot(pd_data['timespent'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
def my_zscore(x):
  return ((x - x.mean())/x.std())

cara =  my_zscore(pd_data['timespent'])
df_sem_outlier_z = pd.DataFrame(
    pd_data[(abs(cara) < z_score_threshold)])
sns.boxplot(df_sem_outlier_z['timespent'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Aplicando o z score mais vezes para remover mais os outliers
for i in range(z_score_times):
  z_score_threshold = 1
  cara =  my_zscore(df_sem_outlier_z['timespent'])
  df_sem_outlier_z = pd.DataFrame(
      df_sem_outlier_z[(abs(cara) < z_score_threshold)])

sns.boxplot(df_sem_outlier_z['timespent'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df_sem_outlier_z.boxplot('timespent')

# %%
df_sem_outlier_z.hist('timespent')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f70e5b043d0>]],
#       dtype=object)

# %%
df_sem_outlier_z
# Out:
#           id project  ... timespent  alpha
# 0      14161     ABU  ...    1800.0   96.0
# 2      14201     ABU  ...    1800.0   97.0
# 7      14251     ABU  ...    1800.0   98.0
# 8      14121     ABU  ...    3600.0   98.0
# 13     15506     ABU  ...    1800.0   99.0
# ...      ...     ...  ...       ...    ...
# 97240  10006    ZONG  ...    1800.0  100.0
# 97245  11500   UTILS  ...    2700.0  100.0
# 97248  10501   UTILS  ...    1890.0  100.0
# 97249  10500   UTILS  ...    3600.0  100.0
# 97253  10001   UTILS  ...    3600.0  100.0
#
# [18188 rows x 6 columns]

# %%
data = df_sem_outlier_z

# %%
data
# Out:
#           id project  ... timespent  alpha
# 0      14161     ABU  ...    1800.0   96.0
# 2      14201     ABU  ...    1800.0   97.0
# 7      14251     ABU  ...    1800.0   98.0
# 8      14121     ABU  ...    3600.0   98.0
# 13     15506     ABU  ...    1800.0   99.0
# ...      ...     ...  ...       ...    ...
# 97240  10006    ZONG  ...    1800.0  100.0
# 97245  11500   UTILS  ...    2700.0  100.0
# 97248  10501   UTILS  ...    1890.0  100.0
# 97249  10500   UTILS  ...    3600.0  100.0
# 97253  10001   UTILS  ...    3600.0  100.0
#
# [18188 rows x 6 columns]

# %%
# Categorizando os dados
#data['timespent'] = data.timespent.ge(1200).astype(int)
categories = [0, 1, 2, 3, 4, 5, 6]
data['timespent'] = pd.cut(data['timespent'], bins=len(categories), include_lowest=True, labels=categories).values

# %%
data['timespent']
# Out:
# 0        1
# 2        1
# 7        1
# 8        6
# 13       1
#         ..
# 97240    1
# 97245    3
# 97248    1
# 97249    6
# 97253    6
# Name: timespent, Length: 18188, dtype: category
# Categories (7, int64): [0 < 1 < 2 < 3 < 4 < 5 < 6]

# %%
# Obtendo todas as palavras das description para serem treinadas
all_text = []
for description in data[xcol].values:
  for des_str in description:
    all_text.append(des_str.split())

if debug:
  print(len(all_text))
  # print(all_text)
# Out:
# 41156

# %%
# Definindo o modelo de word embeddings
emb_model = Word2Vec(all_text, min_count=10, size=embedding_size)
# Resumo do modelo
if debug:
  print(emb_model)
words = list(emb_model.wv.vocab)
if debug:
  print(words)

vocab_size = len(words) + 1
if debug:
  print(vocab_size)
  print(emb_model.wv.vectors)
# Out:
# Word2Vec(vocab=5282, size=200, alpha=0.025)
# ['i', 'know', "it's", 'a', 'core', 'model', 'attribute', 'but', 'not', 'actually', 'used', 'in', 'this', 'component', 'so', 'little', 'misleading', 'to', 'list', 'it', 'remove', 'from', 'file', 'or', 'use', 'theme', 'the', 'watch', 'task', 'that', 'runs', 'if', 'you', 'do', 'dev', 'will', 'for', 'changes', 'then', 'copy', 'into', 'build', 'when', 'is', 'changed', 'saved', 'replicate', 'run', 'make', 'change', 'and', 'save', 'observe', 'command', 'line', 'says', 'src', 'course', 'tasks', 'are', 'go', 'has', 'been', 'updated', 'on', 'page', 'any', 'of', 'options', 'an', 'mcq', 'selected', 'ends', 'up', 'being', 'read', 'out', 'times', 'once', 'before', 'twice', 'after', 'indicated', 'headings', 'each', 'item', 'top', 'other', 'see', 'buttons', 'work', 'button', "doesn't", 'also', 'occurs', 'same', 'behaviour', 'nexus', 'android', 'slider', "can't", 'be', 'user', 'unable', 'select', 'submit', 'even', 'scroll', 'must', 'closed', 'reopened', 'can', 'progress', 'iphone', 'ios', 'using', 'no', 'matter', 'what', 'number', 'chooses', 'selects', 'move', 'input', 'looks', 'like', 'broadcast', 'events', 'source', 'might', 'well', 'needs', 'testing', 'assume', 'we', 'could', 'probably', 'hack', 'our', 'way', 'around', 'play', 'event', 'by', 'clicks', 'video', 'completion', 'unlikely', 'easy', 'though', 'skip', 'plugins', 'with', 'schema', 'error', 'support', 'drop', 'shadow', 'icon', 'effectively', 'invisible', 'attached', 'alt', 'text', 'here', 'your', 'answer', 'both', 'as', 'requires', 'choose', 'images', 'image', 'option', 'description', 'question', 'at', 'end', 'links', 'every', 'drawer', 'tabbing', 'whole', 'side', 'necessary', 'confuse', 'thinking', 'reached', 'contents', 'all', 'resources', 'need', 'identified', 'such', 'right', 'now', 'only', 'name', 'idea', 'indication', 'why', 'there', 'closes', 'feedback', 'popups', 'reader', 'begins', 'reading', 'should', 'return', 'next', 'navigation', 'seems', 'retain', 'position', 'submitted', 'they', 'colour', 'again', 'setup', 'false', 'multiple', 'assessment', 'one', 'just', 'contains', 'content', 'previous', 'render', 'review', 'accuracy', 'quality', 'goes', 'chuck', 'reassign', 'push', 'adapt', 'github', 'wiki', 'have', 'cached', 'take', 'several', 'extra', 'seconds', 'load', 'while', 'waits', 'fire', 'which', "won't", 'due', 'bug', 'does', 'eventually', 'errors', 'failed', 'shown', 'console', 'default', 'framework', 'viewed', 'through', 'causes', 'issues', 'forward', 'back', 'arrows', 'first', 'would', 'aria', 'labels', 'moving', 'section', 'title', 'moment', 'hit', 'label', 'exit', 'graphic', 'plp', 'show', 'menu', 'focus', 'returns', 'opened', 'close', 'sequence', 'opens', 'tabs', 'instead', 'behind', 'completed', 'shift', 'moves', 'instruction', 'left', 'works', 'round', 'view', 'occurred', 'merging', 'following', 'pr', 'weekly', 'documentation', 'chat', 'tries', 'tab', 'past', 'scrolls', 'down', 'screen', 'shows', 'white', 'cursor', 'directly', 'without', 'explanation', 'takes', 'good', 'bit', 'get', 'place', 'done', 'complete', 'preventing', 'progressing', 'mark', 'visible', 'area', 'lower', 'sizes', 'appear', 'browsers', 'comparison', 'problem', 'desired', 'appearance', 'chrome', 'always', 'present', 'beginning', 'arrow', 'last', 'loop', 'please', 'add', 'alternative', 'version', 'switched', 'switch', 'off', 'setting', 'leave', 'enabled', 'running', 'connected', 'my', 'expectation', 'disabled', 'attempt', 'made', 'call', 'functions', 'appropriate', 'log', 'tracking', 'therefore', 'json', 'test', 'package', 'replaced', 'grey', 'placeholder', 'audio', 'media', 'included', 'keep', 'size', 'initial', 'download', 'small', 'possible', 'was', 'disable', 'am', 'working', 'downloaded', 'code', 'realized', 'missing', 'added', 'ran', 'verified', 'server', 'window', 'pops', 'tried', 'many', 'including', 'mac', 'terminal', 'deleting', 'folder', 'cleared', 'cache', 'single', 'time', 'wrong', 'validation', 'colors', 'variable', 'vertically', 'center', 'aligned', 'variables', 'navigate', 'dropd ...
# 5283
# [[-0.2320824  -0.12213754  0.61723423 ...  0.5721068  -0.05559122
#   -0.0774988 ]
#  [ 0.82428765  0.06605081 -0.5255269  ... -0.02641014  0.25941664
#    0.7344065 ]
#  [ 0.07724133  0.19517753  0.51383746 ... -0.00879222 -0.5545678
#    0.42836684]
#  ...
#  [ 0.08776283 -0.05527842  0.10037728 ...  0.05426548 -0.00586902
#    0.0028906 ]
#  [ 0.09804922 -0.06574455  0.08813668 ...  0.03465982  0.02066597
#   -0.00236959]
#  [ 0.06212742 -0.04520461  0.06322026 ...  0.01240511 -0.00226032
#   -0.01416366]]

# %%
# Brincando com o modelo
print(emb_model.wv.similarity('java', 'code'))
emb_model.wv.most_similar(positive=['staging'], topn=10)
# Out:
# 0.45981687
# [('debugger', 0.9550450444221497),
#  ('dskiptests', 0.9476001262664795),
#  ('goals', 0.9464520812034607),
#  ('compose', 0.931922972202301),
#  ("here's", 0.9317753911018372),
#  ('establish', 0.9317233562469482),
#  ('rolling', 0.9310857057571411),
#  ('pyarrow', 0.9304643273353577),
#  ('reopened', 0.9302266836166382),
#  ('emp', 0.9293289184570312)]

# %%
# Comparando vetores de palavras
pyplot.figure(figsize=(10,3))
w1 = 'java'
w2 = 'code'
w1v = emb_model.wv.get_vector(w1)
w2v = emb_model.wv.get_vector(w2)
pyplot.plot(w1v, label=w1)
pyplot.plot(w2v, label=w2)
pyplot.legend()
pyplot.show()

# %%
# Obtendo a lista de docs
docs = []
for desc in data[xcol].values:
  sentence_agg = ""
  for sentence in desc:
    sentence_agg += sentence
    sentence_agg += " "
  sentence_agg = sentence_agg.rstrip()
  docs.append(sentence_agg)
print(docs[0:10])
print(len(docs))
# Out:
# ["i know it's a core model attribute but it's not actually used in this component so it's a little misleading to list it in example.json", 'remove from colors.less file or use in theme', 'the watch task that runs if you do grunt dev will watch for changes to config.json but then copy config.json into the build when this file is changed saved to replicate run grunt dev make a change to and save the file observe that the command line says file src course config.json changed and that the and copy:coursejson tasks are run go to observe that config.json has not been updated', "on this page if any of the options for an mcq is selected it ends up being read out times once before it's selected and twice after indicated that it's been", "the headings for each component item are stacked on top of each other see buttons and work button doesn't this also occurs in same behaviour on nexus android", "once the slider button is selected it can't be deselected user is then unable to select submit button or even scroll course must be closed and reopened before user can progress this also occurs on iphone ios when using the nexus android the slider can be deselected but no matter what number the user chooses when the user selects submit the slider will move to and input", "looks like mediaelement.js doesn't broadcast events when the source is vimeo might well be same if youtube this needs testing assume we could probably hack our way around the play event by firing it when the user clicks on the video completion event unlikely to be so easy though", 'schema-defaults task needs to skip plugins with no schema error', "doesn't support drop shadow so the slider icon is effectively invisible see attached", "alt text for the mcq submit buttons on this page is select here to submit your answer and it's read out both before and after the submit button has been selected"]
# 18188

# %%
docs_len = []
for doc in docs:
  docs_len.append(len(doc.split()))
print(docs_len[0:10])
# Out:
# [25, 8, 70, 31, 28, 67, 49, 10, 13, 31]

# %%
df_sem_outlier_z['lens_sumary'] = docs_len

# %%
df_sem_outlier_z
# Out:
#           id project  ...  alpha lens_sumary
# 0      14161     ABU  ...   96.0          25
# 2      14201     ABU  ...   97.0           8
# 7      14251     ABU  ...   98.0          70
# 8      14121     ABU  ...   98.0          31
# 13     15506     ABU  ...   99.0          28
# ...      ...     ...  ...    ...         ...
# 97240  10006    ZONG  ...  100.0          41
# 97245  11500   UTILS  ...  100.0          26
# 97248  10501   UTILS  ...  100.0          16
# 97249  10500   UTILS  ...  100.0           9
# 97253  10001   UTILS  ...  100.0          16
#
# [18188 rows x 7 columns]

# %%
df_sem_outlier_z.boxplot('lens_sumary')

# %%
# Tamanho máximo dos docs
max_length_des = 0
if docs_length == 'mean':
  max_length_des = int(df_sem_outlier_z['lens_sumary'].mean())
  if debug:
    print(max_length_des)
elif docs_length == 'min':
  max_length_des = int(df_sem_outlier_z['lens_sumary'].min())
  if debug:
    print(max_length_des)
else:
  for desc in data[xcol].values:
    sentence_size = 0
    for sentence in desc:
      sentence_size += len(sentence.split())
    if sentence_size > max_length_des:
      max_length_des = sentence_size
  if debug:
    print(max_length_des)
# Out:
# 46

# %%
padded_docs = zeros((len(docs), max_length_des))
for i, doc in enumerate(docs):
  doc_word_list = doc.split()
  doc_encoded = zeros((max_length_des))
  for j, word in enumerate(doc_word_list):
    if j < max_length_des:
      if word in emb_model.wv.vocab:
        doc_encoded[j] = emb_model.wv.vocab[word].index + 1
  padded_docs[i] = doc_encoded
padded_docs
# Out:
# array([[1.900e+01, 3.640e+02, 2.020e+02, ..., 0.000e+00, 0.000e+00,
#         0.000e+00],
#        [1.380e+02, 2.200e+01, 0.000e+00, ..., 0.000e+00, 0.000e+00,
#         0.000e+00],
#        [1.000e+00, 2.878e+03, 1.820e+02, ..., 1.400e+01, 1.000e+00,
#         2.440e+02],
#        ...,
#        [1.070e+02, 9.100e+01, 7.300e+01, ..., 0.000e+00, 0.000e+00,
#         0.000e+00],
#        [7.550e+02, 8.400e+01, 3.440e+02, ..., 0.000e+00, 0.000e+00,
#         0.000e+00],
#        [1.040e+02, 1.000e+00, 3.053e+03, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]])

# %%
print(padded_docs.shape)
# Out:
# (18188, 46)

# %%
# Criando uma matriz de pesos para o vocabulário
embedding_matrix = zeros((vocab_size, embedding_size))
for i, word in enumerate(words):
  embedding_vector = emb_model.wv.get_vector(word)
  if embedding_vector is not None:
    embedding_matrix[i+1] = asarray(embedding_vector, dtype='float32')
  else:
    print("Vish")
if debug:
  print(len(embedding_matrix))
  print(embedding_matrix)
# Out:
# 5283
# [[ 0.          0.          0.         ...  0.          0.
#    0.        ]
#  [ 0.33911166 -0.38875344  0.80171645 ... -0.44842947 -0.07870384
#    0.24714456]
#  [-0.37138504  0.04599576  0.97360694 ...  0.09607606 -0.37280774
#    0.56778628]
#  ...
#  [ 0.11187257 -0.08672452  0.09468634 ...  0.05500475  0.02861542
#   -0.02193964]
#  [ 0.08924548 -0.08062065  0.10087335 ...  0.03848129  0.02350101
#    0.00851378]
#  [ 0.08218858 -0.06869315  0.13263588 ...  0.07366771 -0.01977134
#    0.01275168]]

# %%
dropout = True
lstm = True
dense_layers = True

# %%
# Particionando conjunto de teste e treino para avaliação
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(padded_docs, data['timespent'].values.codes, test_size=0.2, random_state=8)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (14550, 46)
# (3638, 46)
# (14550,)
# (3638,)

# %%
# Definindo o modelo
model = Sequential()
e = Embedding(vocab_size, embedding_size, weights=[embedding_matrix], input_length=max_length_des, trainable=False)
model.add(e)
if lstm:
  model.add(Bidirectional(LSTM(max_length_des)))
  if dropout:
    model.add(Dropout(0.3))
else:
  model.add(Flatten())
  if dropout:
    model.add(Dropout(0.1))
if dense_layers:
  model.add(Dense(200, activation='relu'))
  if dropout:  
    model.add(Dropout(0.1))
  model.add(Dense(16, activation='relu'))
  if dropout:
    model.add(Dropout(0.1))
  # model.add(Dense(16, activation='relu'))
  # if dropout:
  #   model.add(Dropout(0.2))
  # model.add(Dense(4, activation='relu'))
  # if dropout:
  #   model.add(Dropout(0.1))
#model.add(Dense(1, activation='sigmoid'))
model.add(Dense(len(categories), activation='softmax'))
# Compilando o modelo
#opt = SGD(lr=0.01, momentum=0.9)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mae'])
# Resumo do modelo
print(model.input_shape)
print(model.summary())
# Out:
# (None, 46)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 46, 200)           1056600
# _________________________________________________________________
# bidirectional (Bidirectional (None, 92)                90896
# _________________________________________________________________
# dropout (Dropout)            (None, 92)                0
# _________________________________________________________________
# dense (Dense)                (None, 200)               18600
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                3216
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 119
# =================================================================
# Total params: 1,169,431
# Trainable params: 112,831
# Non-trainable params: 1,056,600
# _________________________________________________________________
# None

# %%
from keras.backend import clear_session
clear_session()
# Treinando o modelo

from sklearn.model_selection import KFold

kf = KFold(n_splits=10)
foldn = 1
acc_hist = []
acc_val_hist = []
for train_index, val_index in kf.split(x_train):
  x_train_new = x_train[train_index]
  y_train_new = y_train[train_index]

  x_val = x_train[val_index]
  y_val = y_train[val_index]

  print("Fold {} train".format(foldn))
  foldn += 1

  history = model.fit(x_train, y_train, epochs=10, batch_size=64, validation_data=(x_val, y_val), verbose=1)
  
  acc_hist.extend(history.history['accuracy'])
  acc_val_hist.extend(history.history['val_accuracy'])

pyplot.plot(acc_hist)
pyplot.plot(acc_val_hist)
pyplot.title('model accuracy'),
pyplot.ylabel('accuracy')
pyplot.xlabel('epoch')
pyplot.legend(['train', 'test'], loc='upper left')
pyplot.show()
# Out:
# Fold 1 train
# Epoch 1/10
# 228/228 [==============================] - 19s 67ms/step - loss: 1.5015 - accuracy: 0.3238 - val_loss: 1.4111 - val_accuracy: 0.3780
# Epoch 2/10
# 228/228 [==============================] - 15s 64ms/step - loss: 1.4524 - accuracy: 0.3408 - val_loss: 1.3939 - val_accuracy: 0.4000
# Epoch 3/10
# 228/228 [==============================] - 15s 64ms/step - loss: 1.4375 - accuracy: 0.3522 - val_loss: 1.3994 - val_accuracy: 0.3863
# Epoch 4/10
# 228/228 [==============================] - 15s 64ms/step - loss: 1.4282 - accuracy: 0.3511 - val_loss: 1.3806 - val_accuracy: 0.4158
# Epoch 5/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.4182 - accuracy: 0.3564 - val_loss: 1.3875 - val_accuracy: 0.3876
# Epoch 6/10
# 228/228 [==============================] - 15s 64ms/step - loss: 1.4098 - accuracy: 0.3616 - val_loss: 1.3729 - val_accuracy: 0.3973
# Epoch 7/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.4025 - accuracy: 0.3607 - val_loss: 1.3563 - val_accuracy: 0.3938
# Epoch 8/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.3913 - accuracy: 0.3749 - val_loss: 1.3422 - val_accuracy: 0.4069
# Epoch 9/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.3866 - accuracy: 0.3709 - val_loss: 1.3360 - val_accuracy: 0.4199
# Epoch 10/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.3783 - accuracy: 0.3714 - val_loss: 1.3282 - val_accuracy: 0.4254
# Fold 2 train
# Epoch 1/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.3689 - accuracy: 0.3796 - val_loss: 1.3625 - val_accuracy: 0.3656
# Epoch 2/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.3592 - accuracy: 0.3767 - val_loss: 1.3479 - val_accuracy: 0.3801
# Epoch 3/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.3505 - accuracy: 0.3843 - val_loss: 1.3406 - val_accuracy: 0.3814
# Epoch 4/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.3383 - accuracy: 0.3872 - val_loss: 1.3231 - val_accuracy: 0.3924
# Epoch 5/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.3312 - accuracy: 0.3881 - val_loss: 1.2958 - val_accuracy: 0.3986
# Epoch 6/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.3164 - accuracy: 0.3958 - val_loss: 1.2899 - val_accuracy: 0.3966
# Epoch 7/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.3077 - accuracy: 0.3963 - val_loss: 1.2759 - val_accuracy: 0.4172
# Epoch 8/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.2962 - accuracy: 0.4047 - val_loss: 1.2439 - val_accuracy: 0.4344
# Epoch 9/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.2838 - accuracy: 0.4070 - val_loss: 1.2284 - val_accuracy: 0.4426
# Epoch 10/10
# 228/228 [==============================] - 15s 64ms/step - loss: 1.2710 - accuracy: 0.4165 - val_loss: 1.2127 - val_accuracy: 0.4392
# Fold 3 train
# Epoch 1/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.2543 - accuracy: 0.4223 - val_loss: 1.1647 - val_accuracy: 0.4866
# Epoch 2/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.2407 - accuracy: 0.4265 - val_loss: 1.1395 - val_accuracy: 0.5024
# Epoch 3/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.2290 - accuracy: 0.4344 - val_loss: 1.1259 - val_accuracy: 0.5251
# Epoch 4/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.2195 - accuracy: 0.4390 - val_loss: 1.1193 - val_accuracy: 0.5416
# Epoch 5/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.2088 - accuracy: 0.4465 - val_loss: 1.1014 - val_accuracy: 0.5299
# Epoch 6/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.1882 - accuracy: 0.4591 - val_loss: 1.0801 - val_accuracy: 0.5306
# Epoch 7/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.1782 - accuracy: 0.4592 - val_loss: 1.0574 - val_accuracy: 0.5588
# Epoch 8/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.1634 - accuracy: 0.4709 - val_loss: 1.0480 - val_accuracy: 0.5478
# Epoch 9/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.1526 - accuracy: 0.4664 - val_loss: 1.0306 - val_accuracy: 0.5739
# Epoch 10/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.1454 - accuracy: 0.4783 - val_loss: 1.0144 - val_accuracy: 0.5711
# Fold 4 train
# Epoch 1/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.1338 - accuracy: 0.4793 - val_loss: 1.0058 - val_accuracy: 0.5540
# Epoch 2/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.1186 - accuracy: 0.4896 - val_loss: 1.0034 - val_accuracy: 0.5629
# Epoch 3/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.1118 - accuracy: 0.4894 - val_loss: 0.9802 - val_accuracy: 0.5890
# Epoch 4/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.0930 - accuracy: 0.4995 - val_loss: 0.9551 - val_accuracy: 0.5973
# Epoch 5/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.0810 - accuracy: 0.5062 - val_loss: 0.9514 - val_accuracy: 0.5814
# Epoch 6/10
# 228/228 [==============================] - 15s 66ms/step - loss: 1.0681 - accuracy: 0.5056 - val_loss: 0.9388 - val_accuracy: 0.5918
# Epoch 7/10
# 228/228 [==============================] - 15s 66ms/step - loss: 1.0543 - accuracy: 0.5183 - val_loss: 0.9231 - val_accuracy: 0.6227
# Epoch 8/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.0391 - accuracy: 0.5265 - val_loss: 0.9100 - val_accuracy: 0.6213
# Epoch 9/10
# 228/228 [==============================] - 15s 66ms/step - loss: 1.0320 - accuracy: 0.5295 - val_loss: 0.8925 - val_accuracy: 0.6344
# Epoch 10/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.0278 - accuracy: 0.5357 - val_loss: 0.8696 - val_accuracy: 0.6426
# Fold 5 train
# Epoch 1/10
# 228/228 [==============================] - 15s 66ms/step - loss: 1.0169 - accuracy: 0.5391 - val_loss: 0.8881 - val_accuracy: 0.6110
# Epoch 2/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.0056 - accuracy: 0.5423 - val_loss: 0.8674 - val_accuracy: 0.6289
# Epoch 3/10
# 228/228 [==============================] - 15s 65ms/step - loss: 1.0013 - accuracy: 0.5463 - val_loss: 0.8640 - val_accuracy: 0.6371
# Epoch 4/10
# 228/228 [==============================] - 15s 65ms/step - loss: 0.9794 - accuracy: 0.5551 - val_loss: 0.8695 - val_accuracy: 0.6337
# Epoch 5/10
# 228/228 [==============================] - 15s 65ms/step - loss: 0.9650 - accuracy: 0.5715 - val_loss: 0.8401 - val_accuracy: 0.6495
# Epoch 6/10
# 228/228 [==============================] - 15s 65ms/step - loss: 0.9660 - accuracy: 0.5649 - val_loss: 0.8276 - val_accuracy: 0.6612
# Epoch 7/10
# 228/228 [==============================] - 15s 65ms/step - loss: 0.9465 - accuracy: 0.5725 - val_loss: 0.8306 - val_accuracy: 0.6412
# Epoch 8/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.9395 - accuracy: 0.5757 - val_loss: 0.7870 - val_accuracy: 0.6756
# Epoch 9/10
# 228/228 [==============================] - 15s 65ms/step - loss: 0.9373 - accuracy: 0.5800 - val_loss: 0.7864 - val_accuracy: 0.6735
# Epoch 10/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.9313 - accuracy: 0.5810 - val_loss: 0.8050 - val_accuracy: 0.6625
# Fold 6 train
# Epoch 1/10
# 228/228 [==============================] - 15s 65ms/step - loss: 0.9217 - accuracy: 0.5929 - val_loss: 0.7554 - val_accuracy: 0.6935
# Epoch 2/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.9113 - accuracy: 0.5968 - val_loss: 0.7481 - val_accuracy: 0.7134
# Epoch 3/10
# 228/228 [==============================] - 15s 65ms/step - loss: 0.8968 - accuracy: 0.5991 - val_loss: 0.7384 - val_accuracy: 0.6948
# Epoch 4/10
# 228/228 [==============================] - 15s 65ms/step - loss: 0.8882 - accuracy: 0.6086 - val_loss: 0.7143 - val_accuracy: 0.7210
# Epoch 5/10
# 228/228 [==============================] - 15s 65ms/step - loss: 0.8782 - accuracy: 0.6155 - val_loss: 0.7155 - val_accuracy: 0.7072
# Epoch 6/10
# 228/228 [==============================] - 15s 65ms/step - loss: 0.8679 - accuracy: 0.6146 - val_loss: 0.7175 - val_accuracy: 0.7113
# Epoch 7/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.8649 - accuracy: 0.6174 - val_loss: 0.6951 - val_accuracy: 0.7436
# Epoch 8/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.8568 - accuracy: 0.6266 - val_loss: 0.6917 - val_accuracy: 0.7320
# Epoch 9/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.8451 - accuracy: 0.6280 - val_loss: 0.6740 - val_accuracy: 0.7526
# Epoch 10/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.8406 - accuracy: 0.6312 - val_loss: 0.6762 - val_accuracy: 0.7333
# Fold 7 train
# Epoch 1/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.8346 - accuracy: 0.6387 - val_loss: 0.6691 - val_accuracy: 0.7471
# Epoch 2/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.8192 - accuracy: 0.6400 - val_loss: 0.6748 - val_accuracy: 0.7361
# Epoch 3/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.8266 - accuracy: 0.6462 - val_loss: 0.6578 - val_accuracy: 0.7608
# Epoch 4/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.8092 - accuracy: 0.6476 - val_loss: 0.6469 - val_accuracy: 0.7649
# Epoch 5/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.8096 - accuracy: 0.6490 - val_loss: 0.6545 - val_accuracy: 0.7560
# Epoch 6/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.8042 - accuracy: 0.6511 - val_loss: 0.6413 - val_accuracy: 0.7622
# Epoch 7/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.7938 - accuracy: 0.6608 - val_loss: 0.6322 - val_accuracy: 0.7801
# Epoch 8/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.7770 - accuracy: 0.6678 - val_loss: 0.6162 - val_accuracy: 0.7766
# Epoch 9/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.7725 - accuracy: 0.6663 - val_loss: 0.5923 - val_accuracy: 0.7931
# Epoch 10/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.7686 - accuracy: 0.6732 - val_loss: 0.5991 - val_accuracy: 0.7924
# Fold 8 train
# Epoch 1/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.7575 - accuracy: 0.6753 - val_loss: 0.5418 - val_accuracy: 0.8014
# Epoch 2/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.7620 - accuracy: 0.6718 - val_loss: 0.5348 - val_accuracy: 0.8034
# Epoch 3/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.7416 - accuracy: 0.6873 - val_loss: 0.5224 - val_accuracy: 0.7979
# Epoch 4/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.7336 - accuracy: 0.6875 - val_loss: 0.5487 - val_accuracy: 0.7849
# Epoch 5/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.7435 - accuracy: 0.6863 - val_loss: 0.5346 - val_accuracy: 0.7986
# Epoch 6/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.7323 - accuracy: 0.6881 - val_loss: 0.5178 - val_accuracy: 0.8089
# Epoch 7/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.7220 - accuracy: 0.6972 - val_loss: 0.4927 - val_accuracy: 0.8296
# Epoch 8/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.7294 - accuracy: 0.6951 - val_loss: 0.5196 - val_accuracy: 0.7945
# Epoch 9/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.7175 - accuracy: 0.6937 - val_loss: 0.4797 - val_accuracy: 0.8296
# Epoch 10/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.7069 - accuracy: 0.7011 - val_loss: 0.4880 - val_accuracy: 0.8399
# Fold 9 train
# Epoch 1/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.6963 - accuracy: 0.7103 - val_loss: 0.4808 - val_accuracy: 0.8241
# Epoch 2/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.7002 - accuracy: 0.7083 - val_loss: 0.4702 - val_accuracy: 0.8344
# Epoch 3/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.6968 - accuracy: 0.7072 - val_loss: 0.4897 - val_accuracy: 0.8289
# Epoch 4/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.6838 - accuracy: 0.7128 - val_loss: 0.4957 - val_accuracy: 0.8117
# Epoch 5/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.6902 - accuracy: 0.7129 - val_loss: 0.4881 - val_accuracy: 0.8302
# Epoch 6/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.6775 - accuracy: 0.7166 - val_loss: 0.4667 - val_accuracy: 0.8316
# Epoch 7/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.6637 - accuracy: 0.7233 - val_loss: 0.4919 - val_accuracy: 0.8172
# Epoch 8/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.6646 - accuracy: 0.7258 - val_loss: 0.4601 - val_accuracy: 0.8371
# Epoch 9/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.6524 - accuracy: 0.7285 - val_loss: 0.4589 - val_accuracy: 0.8392
# Epoch 10/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.6559 - accuracy: 0.7281 - val_loss: 0.4464 - val_accuracy: 0.8412
# Fold 10 train
# Epoch 1/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.6505 - accuracy: 0.7318 - val_loss: 0.4194 - val_accuracy: 0.8550
# Epoch 2/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.6509 - accuracy: 0.7276 - val_loss: 0.4162 - val_accuracy: 0.8612
# Epoch 3/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.6403 - accuracy: 0.7351 - val_loss: 0.4392 - val_accuracy: 0.8344
# Epoch 4/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.6442 - accuracy: 0.7328 - val_loss: 0.4214 - val_accuracy: 0.8564
# Epoch 5/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.6389 - accuracy: 0.7365 - val_loss: 0.4108 - val_accuracy: 0.8488
# Epoch 6/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.6313 - accuracy: 0.7375 - val_loss: 0.4077 - val_accuracy: 0.8598
# Epoch 7/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.6330 - accuracy: 0.7403 - val_loss: 0.3871 - val_accuracy: 0.8577
# Epoch 8/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.6160 - accuracy: 0.7496 - val_loss: 0.4064 - val_accuracy: 0.8722
# Epoch 9/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.6137 - accuracy: 0.7493 - val_loss: 0.3926 - val_accuracy: 0.8715
# Epoch 10/10
# 228/228 [==============================] - 15s 66ms/step - loss: 0.6040 - accuracy: 0.7526 - val_loss: 0.4151 - val_accuracy: 0.8509

# %%
# Avaliando o modelo
print('Treino')
loss, metric = model.evaluate(x_train, y_train)
print('Loss: {}'.format(loss))
print('Metric: {}'.format(metric))
print('Test')
loss, metric = model.evaluate(x_test, y_test)
print('Loss: {}'.format(loss))
print('Metric: {}'.format(metric))
# Out:
# Treino
# 455/455 [==============================] - 6s 14ms/step - loss: 0.4103 - accuracy: 0.8649
# Loss: 0.41028687357902527
# Metric: 0.8649484515190125
# Test
# 114/114 [==============================] - 2s 14ms/step - loss: 3.1781 - accuracy: 0.3211
# Loss: 3.178112268447876
# Metric: 0.32105553150177

# %%
# Fazendo e avaliando previsões
predictions = model.predict(x_test)
print(predictions[0])
pred_class = []
for pred in predictions:
  pred_class.append(np.argmax(pred))
# Out:
# [0.00414121 0.56228197 0.00514462 0.10352226 0.20897317 0.00428178
#  0.111655  ]

# %%
pred_to_plot = pred_class
psize = 100
pyplot.figure(figsize=(20,3))
pyplot.plot(pred_to_plot[0:psize], label='predicted')
pyplot.plot(y_test[0:psize], label='real')
pyplot.legend()
pyplot.show()

# %%
# Calculando mmre and mae para validação
from sklearn.metrics import mean_absolute_error

def mre(actual, pred):
  actual += 1
  pred += 1
  mre = (abs(actual - pred)) / actual
  return mre

def mmre(y, pred):
  sum = 0.0
  for i, actual in enumerate(y):
    sum += mre(actual, pred[i])
  mmre = (sum / (len(y))) 
  return mmre

print("MMRE: {}".format(mmre(y_test, pred_class)))
print("MAE: {}".format(mean_absolute_error(y_test, pred_class)))
# Out:
# MMRE: 0.6749293175214022
# MAE: 2.182242990654206

# %%
import seaborn as sns
import matplotlib.pyplot as plt    
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, pred_class, categories) 

ax = plt.subplot()
sns.heatmap(cm, annot=True, fmt='g', ax=ax);  #annot=True to annotate cells, ftm='g' to disable scientific notation

# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels') 
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(categories) 
ax.yaxis.set_ticklabels(categories)
# Out:
# [Text(0, 0.5, '0'),
#  Text(0, 1.5, '1'),
#  Text(0, 2.5, '2'),
#  Text(0, 3.5, '3'),
#  Text(0, 4.5, '4'),
#  Text(0, 5.5, '5'),
#  Text(0, 6.5, '6')]

# %%
# Old figure of confusion matrix
# fig = pyplot.figure()
# ax = fig.add_subplot(111)
# cax = ax.matshow(cm)
# pyplot.title('Confusion matrix of the classifier')
# fig.colorbar(cax)
# ax.set_xticklabels([''] + labels)
# ax.set_yticklabels([''] + labels)
# pyplot.xlabel('Predicted')
# pyplot.ylabel('True')
# pyplot.show()

# %%
# pyplot.plot(history.history['mae'])
# pyplot.plot(history.history['val_mae'])
# pyplot.title('model accuracy')
# pyplot.ylabel('mae')
# pyplot.xlabel('epoch')
# pyplot.legend(['train', 'test'], loc='upper left')
# pyplot.show()

# %%
# # Primeiro Quartil
# Q1 = pd_data['timespent'].quantile(0.25)
# print("Q1: {}".format(Q1))
# # Segundo Quartil
# Q2 = pd_data['timespent'].quantile(0.50)
# print("Q2: {}".format(Q2))
# # Terceiro Quartil
# Q3 = pd_data['timespent'].quantile(0.75)
# print("Q3: {}".format(Q3))
# # Amplitude Interquartil
# IQR = Q3 - Q1
# print("IQR: {}".format(IQR))
# # Limite Superior
# LI = Q1 - (1.5 * IQR)
# print("LI: {}".format(LI))
# # Limite Inferior
# LS = Q3 + (1.5 * IQR)
# print("LS: {}".format(LS))

# %%
# df_sem_outlier = pd.DataFrame(
#     pd_data[(
#         (pd_data['timespent'] >= LI) 
#         & (pd_data['timespent'] <= LS)
#     )])

# sns.boxplot(df_sem_outlier['timespent'])

# %%
# for pred in predictions:
#     if pred != 1089.0886 and pred != 1089.0885:
#       print(pred)

# %%
# # Visualizando o word embedding
# X = emb_model[emb_model.wv.vocab]
# pca = PCA(n_components=2)
# result = pca.fit_transform(X)
# fig, ax = pyplot.subplots()
# ax.scatter(result[:, 0], result[:, 1])
# xlim1 = -0.200
# xlim2 = -0.125
# ylim1 = -0.02
# ylim2 = 0.02
# limits = False

# words = list(emb_model.wv.vocab)
# for i, word in enumerate(words):
#   x = result[i, 0]
#   y = result[i, 1]
#   if limits:
#     if x >= xlim1 and x <= xlim2 and y >= ylim1 and y <= ylim2: 
# 	    ax.annotate(word, xy=(x, y))
#   else:
#     ax.annotate(word, xy=(x, y))

# if limits:
#   ax.set_xlim(xlim1, xlim2)
#   ax.set_ylim(ylim1, ylim2)

# %%
# prepare tokenizer
# t = Tokenizer()
# t.fit_on_texts(summary_list)
# vocab_size = len(t.word_index) + 1
# print(vocab_size)

# %%
# integer encode the documents
# encoded_docs = t.texts_to_sequences(summary_list)
# print(encoded_docs)

# %%
# padded_docs = pad_sequences(encoded_docs, maxlen=max_summary_length, padding='post')
# print(padded_docs)

# %%
# ss = StandardScaler()
# sclWord = ss.fit(emb_model.wv.vectors)
# vectors_normalized = sclWord.transform(vocab_dict.values())

# vectors_list = []
# for word in emb_model.wv.vocab:
#   vectors_list.append(emb_model.wv.get_vector(word))

# print(type(emb_model.wv.vocab))
# embeddings_index = dict()
# for i, word in enumerate(list(emb_model.wv.vocab)[0:10]):
#   print(emb_model.wv.vectors[i])
#   print(vectors_list[i])
	#embeddings_index[word] = vectors_normalized[i]

# %%
# count = 0
# for cara in embedding_matrix:
#   if cara[0] == 0:
#     count+=1
# print(count)
